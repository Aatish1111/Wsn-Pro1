# %%
import random
import matplotlib.pyplot as plt

# Constants for protocols
PROTOCOL_CAMELLIA = "Camellia"
PROTOCOL_LEACH = "LEACH"

# Function to simulate Camellia-specific data transmission
def send_data_camellia(node_id):
    print(f"Node {node_id} is sending data using {PROTOCOL_CAMELLIA}")
    # Simulate energy consumption for Camellia (replace with actual energy calculation)
    energy_consumption[node_id - 1] += random.uniform(1.0, 3.0)

# Function to simulate LEACH-specific data transmission
def send_data_leach(node_id):
    print(f"Node {node_id} is sending data using {PROTOCOL_LEACH}")
    # Simulate energy consumption for LEACH (replace with actual energy calculation)
    energy_consumption[node_id - 1] += random.uniform(0.5, 2.0)

# Simulated WSN parameters
num_nodes = 10  # Initial number of nodes
max_nodes = 100  # Maximum number of nodes for the simulation

# Lists to store energy consumption data
energy_consumption = [0] * max_nodes

# Lists to store the number of nodes and energy efficiency
num_nodes_list = []
energy_efficiency_list = []

# Main simulation loop
while num_nodes <= max_nodes:
    for node_id in range(1, num_nodes + 1):
        # Generate random data for the node
        sensor_data = random.randint(0, 100)

        # Determine which protocol to use based on the number of nodes
        if num_nodes <= 50:
            send_data_camellia(node_id)
        else:
            send_data_leach(node_id)

    # Calculate energy efficiency (total data sent per unit energy)
    total_data_sent = num_nodes * 100  # Assuming each node sends 100 units of data
    total_energy_consumed = sum(energy_consumption[:num_nodes])
    energy_efficiency = total_data_sent / total_energy_consumed

    # Store data for plotting
    num_nodes_list.append(num_nodes)
    energy_efficiency_list.append(energy_efficiency)

    # Increase the number of nodes (you can adjust this as needed)
    num_nodes += 10

# Plot energy efficiency vs. number of nodes
plt.figure(figsize=(8, 6))
plt.plot(num_nodes_list, energy_efficiency_list, marker='o', linestyle='-')
plt.title('Energy Efficiency vs. Number of Nodes')
plt.xlabel('Number of Nodes')
plt.ylabel('Energy Efficiency')
plt.grid(True)
plt.show()
# Out:
# Node 1 is sending data using Camellia
# Node 2 is sending data using Camellia
# Node 3 is sending data using Camellia
# Node 4 is sending data using Camellia
# Node 5 is sending data using Camellia
# Node 6 is sending data using Camellia
# Node 7 is sending data using Camellia
# Node 8 is sending data using Camellia
# Node 9 is sending data using Camellia
# Node 10 is sending data using Camellia
# Node 1 is sending data using Camellia
# Node 2 is sending data using Camellia
# Node 3 is sending data using Camellia
# Node 4 is sending data using Camellia
# Node 5 is sending data using Camellia
# Node 6 is sending data using Camellia
# Node 7 is sending data using Camellia
# Node 8 is sending data using Camellia
# Node 9 is sending data using Camellia
# Node 10 is sending data using Camellia
# Node 11 is sending data using Camellia
# Node 12 is sending data using Camellia
# Node 13 is sending data using Camellia
# Node 14 is sending data using Camellia
# Node 15 is sending data using Camellia
# Node 16 is sending data using Camellia
# Node 17 is sending data using Camellia
# Node 18 is sending data using Camellia
# Node 19 is sending data using Camellia
# Node 20 is sending data using Camellia
# Node 1 is sending data using Camellia
# Node 2 is sending data using Camellia
# Node 3 is sending data using Camellia
# Node 4 is sending data using Camellia
# Node 5 is sending data using Camellia
# Node 6 is sending data using Camellia
# Node 7 is sending data using Camellia
# Node 8 is sending data using Camellia
# Node 9 is sending data using Camellia
# Node 10 is sending data using Camellia
# Node 11 is sending data using Camellia
# Node 12 is sending data using Camellia
# Node 13 is sending data using Camellia
# Node 14 is sending data using Camellia
# Node 15 is sending data using Camellia
# Node 16 is sending data using Camellia
# Node 17 is sending data using Camellia
# Node 18 is sending data using Camellia
# Node 19 is sending data using Camellia
# Node 20 is sending data using Camellia
# Node 21 is sending data using Camellia
# Node 22 is sending data using Camellia
# Node 23 is sending data using Camellia
# Node 24 is sending data using Camellia
# Node 25 is sending data using Camellia
# Node 26 is sending data using Camellia
# Node 27 is sending data using Camellia
# Node 28 is sending data using Camellia
# Node 29 is sending data using Camellia
# Node 30 is sending data using Camellia
# Node 1 is sending data using Camellia
# Node 2 is sending data using Camellia
# Node 3 is sending data using Camellia
# Node 4 is sending data using Camellia
# Node 5 is sending data using Camellia
# Node 6 is sending data using Camellia
# Node 7 is sending data using Camellia
# Node 8 is sending data using Camellia
# Node 9 is sending data using Camellia
# Node 10 is sending data using Camellia
# Node 11 is sending data using Camellia
# Node 12 is sending data using Camellia
# Node 13 is sending data using Camellia
# Node 14 is sending data using Camellia
# Node 15 is sending data using Camellia
# Node 16 is sending data using Camellia
# Node 17 is sending data using Camellia
# Node 18 is sending data using Camellia
# Node 19 is sending data using Camellia
# Node 20 is sending data using Camellia
# Node 21 is sending data using Camellia
# Node 22 is sending data using Camellia
# Node 23 is sending data using Camellia
# Node 24 is sending data using Camellia
# Node 25 is sending data using Camellia
# Node 26 is sending data using Camellia
# Node 27 is sending data using Camellia
# Node 28 is sending data using Camellia
# Node 29 is sending data using Camellia
# Node 30 is sending data using Camellia
# Node 31 is sending data using Camellia
# Node 32 is sending data using Camellia
# Node 33 is sending data using Camellia
# Node 34 is sending data using Camellia
# Node 35 is sending data using Camellia
# Node 36 is sending data using Camellia
# Node 37 is sending data using Camellia
# Node 38 is sending data using Camellia
# Node 39 is sending data using Camellia
# Node 40 is sending data using Camellia
# Node 1 is sending data using Camellia
# Node 2 is sending data using Camellia
# Node 3 is sending data using Camellia
# Node 4 is sending data using Camellia
# Node 5 is sending data using Camellia
# Node 6 is sending data using Camellia
# Node 7 is sending data using Camellia
# Node 8 is sending data using Camellia
# Node 9 is sending data using Camellia
# Node 10 is sending data using Camellia
# Node 11 is sending data using Camellia
# Node 12 is sending data using Camellia
# Node 13 is sending data using Camellia
# Node 14 is sending data using Camellia
# Node 15 is sending data using Camellia
# Node 16 is sending data using Camellia
# Node 17 is sending data using Camellia
# Node 18 is sending data using Camellia
# Node 19 is sending data using Camellia
# Node 20 is sending data using Camellia
# Node 21 is sending data using Camellia
# Node 22 is sending data using Camellia
# Node 23 is sending data using Camellia
# Node 24 is sending data using Camellia
# Node 25 is sending data using Camellia
# Node 26 is sending data using Camellia
# Node 27 is sending data using Camellia
# Node 28 is sending data using Camellia
# Node 29 is sending data using Camellia
# Node 30 is sending data using Camellia
# Node 31 is sending data using Camellia
# Node 32 is sending data using Camellia
# Node 33 is sending data using Camellia
# Node 34 is sending data using Camellia
# Node 35 is sending data using Camellia
# Node 36 is sending data using Camellia
# Node 37 is sending data using Camellia
# Node 38 is sending data using Camellia
# Node 39 is sending data using Camellia
# Node 40 is sending data using Camellia
# Node 41 is sending data using Camellia
# Node 42 is sending data using Camellia
# Node 43 is sending data using Camellia
# Node 44 is sending data using Camellia
# Node 45 is sending data using Camellia
# Node 46 is sending data using Camellia
# Node 47 is sending data using Camellia
# Node 48 is sending data using Camellia
# Node 49 is sending data using Camellia
# Node 50 is sending data using Camellia
# Node 1 is sending data using LEACH
# Node 2 is sending data using LEACH
# Node 3 is sending data using LEACH
# Node 4 is sending data using LEACH
# Node 5 is sending data using LEACH
# Node 6 is sending data using LEACH
# Node 7 is sending data using LEACH
# Node 8 is sending data using LEACH
# Node 9 is sending data using LEACH
# Node 10 is sending data using LEACH
# Node 11 is sending data using LEACH
# Node 12 is sending data using LEACH
# Node 13 is sending data using LEACH
# Node 14 is sending data using LEACH
# Node 15 is sending data using LEACH
# Node 16 is sending data using LEACH
# Node 17 is sending data using LEACH
# Node 18 is sending data using LEACH
# Node 19 is sending data using LEACH
# Node 20 is sending data using LEACH
# Node 21 is sending data using LEACH
# Node 22 is sending data using LEACH
# Node 23 is sending data using LEACH
# Node 24 is sending data using LEACH
# Node 25 is sending data using LEACH
# Node 26 is sending data using LEACH
# Node 27 is sending data using LEACH
# Node 28 is sending data using LEACH
# Node 29 is sending data using LEACH
# Node 30 is sending data using LEACH
# Node 31 is sending data using LEACH
# Node 32 is sending data using LEACH
# Node 33 is sending data using LEACH
# Node 34 is sending data using LEACH
# Node 35 is sending data using LEACH
# Node 36 is sending data using LEACH
# Node 37 is sending data using LEACH
# Node 38 is sending data using LEACH
# Node 39 is sending data using LEACH
# Node 40 is sending data using LEACH
# Node 41 is sending data using LEACH
# Node 42 is sending data using LEACH
# Node 43 is sending data using LEACH
# Node 44 is sending data using LEACH
# Node 45 is sending data using LEACH
# Node 46 is sending data using LEACH
# Node 47 is sending data using LEACH
# Node 48 is sending data using LEACH
# Node 49 is sending data using LEACH
# Node 50 is sending data using LEACH
# Node 51 is sending data using LEACH
# Node 52 is sending data using LEACH
# Node 53 is sending data using LEACH
# Node 54 is sending data using LEACH
# Node 55 is sending data using LEACH
# Node 56 is sending data using LEACH
# Node 57 is sending data using LEACH
# Node 58 is sending data using LEACH
# Node 59 is sending data using LEACH
# Node 60 is sending data using LEACH
# Node 1 is sending data using LEACH
# Node 2 is sending data using LEACH
# Node 3 is sending data using LEACH
# Node 4 is sending data using LEACH
# Node 5 is sending data using LEACH
# Node 6 is sending data using LEACH
# Node 7 is sending data using LEACH
# Node 8 is sending data using LEACH
# Node 9 is sending data using LEACH
# Node 10 is sending data using LEACH
# Node 11 is sending data using LEACH
# Node 12 is sending data using LEACH
# Node 13 is sending data using LEACH
# Node 14 is sending data using LEACH
# Node 15 is sending data using LEACH
# Node 16 is sending data using LEACH
# Node 17 is sending data using LEACH
# Node 18 is sending data using LEACH
# Node 19 is sending data using LEACH
# Node 20 is sending data using LEACH
# Node 21 is sending data using LEACH
# Node 22 is sending data using LEACH
# Node 23 is sending data using LEACH
# Node 24 is sending data using LEACH
# Node 25 is sending data using LEACH
# Node 26 is sending data using LEACH
# Node 27 is sending data using LEACH
# Node 28 is sending data using LEACH
# Node 29 is sending data using LEACH
# Node 30 is sending data using LEACH
# Node 31 is sending data using LEACH
# Node 32 is sending data using LEACH
# Node 33 is sending data using LEACH
# Node 34 is sending data using LEACH
# Node 35 is sending data using LEACH
# Node 36 is sending data using LEACH
# Node 37 is sending data using LEACH
# Node 38 is sending data using LEACH
# Node 39 is sending data using LEACH
# Node 40 is sending data using LEACH
# Node 41 is sending data using LEACH
# Node 42 is sending data using LEACH
# Node 43 is sending data using LEACH
# Node 44 is sending data using LEACH
# Node 45 is sending data using LEACH
# Node 46 is sending data using LEACH
# Node 47 is sending data using LEACH
# Node 48 is sending data using LEACH
# Node 49 is sending data using LEACH
# Node 50 is sending data using LEACH
# Node 51 is sending data using LEACH
# Node 52 is sending data using LEACH
# Node 53 is sending data using LEACH
# Node 54 is sending data using LEACH
# Node 55 is sending data using LEACH
# Node 56 is sending data using LEACH
# Node 57 is sending data using LEACH
# Node 58 is sending data using LEACH
# Node 59 is sending data using LEACH
# Node 60 is sending data using LEACH
# Node 61 is sending data using LEACH
# Node 62 is sending data using LEACH
# Node 63 is sending data using LEACH
# Node 64 is sending data using LEACH
# Node 65 is sending data using LEACH
# Node 66 is sending data using LEACH
# Node 67 is sending data using LEACH
# Node 68 is sending data using LEACH
# Node 69 is sending data using LEACH
# Node 70 is sending data using LEACH
# Node 1 is sending data using LEACH
# Node 2 is sending data using LEACH
# Node 3 is sending data using LEACH
# Node 4 is sending data using LEACH
# Node 5 is sending data using LEACH
# Node 6 is sending data using LEACH
# Node 7 is sending data using LEACH
# Node 8 is sending data using LEACH
# Node 9 is sending data using LEACH
# Node 10 is sending data using LEACH
# Node 11 is sending data using LEACH
# Node 12 is sending data using LEACH
# Node 13 is sending data using LEACH
# Node 14 is sending data using LEACH
# Node 15 is sending data using LEACH
# Node 16 is sending data using LEACH
# Node 17 is sending data using LEACH
# Node 18 is sending data using LEACH
# Node 19 is sending data using LEACH
# Node 20 is sending data using LEACH
# Node 21 is sending data using LEACH
# Node 22 is sending data using LEACH
# Node 23 is sending data using LEACH
# Node 24 is sending data using LEACH
# Node 25 is sending data using LEACH
# Node 26 is sending data using LEACH
# Node 27 is sending data using LEACH
# Node 28 is sending data using LEACH
# Node 29 is sending data using LEACH
# Node 30 is sending data using LEACH
# Node 31 is sending data using LEACH
# Node 32 is sending data using LEACH
# Node 33 is sending data using LEACH
# Node 34 is sending data using LEACH
# Node 35 is sending data using LEACH
# Node 36 is sending data using LEACH
# Node 37 is sending data using LEACH
# Node 38 is sending data using LEACH
# Node 39 is sending data using LEACH
# Node 40 is sending data using LEACH
# Node 41 is sending data using LEACH
# Node 42 is sending data using LEACH
# Node 43 is sending data using LEACH
# Node 44 is sending data using LEACH
# Node 45 is sending data using LEACH
# Node 46 is sending data using LEACH
# Node 47 is sending data using LEACH
# Node 48 is sending data using LEACH
# Node 49 is sending data using LEACH
# Node 50 is sending data using LEACH
# Node 51 is sending data using LEACH
# Node 52 is sending data using LEACH
# Node 53 is sending data using LEACH
# Node 54 is sending data using LEACH
# Node 55 is sending data using LEACH
# Node 56 is sending data using LEACH
# Node 57 is sending data using LEACH
# Node 58 is sending data using LEACH
# Node 59 is sending data using LEACH
# Node 60 is sending data using LEACH
# Node 61 is sending data using LEACH
# Node 62 is sending data using LEACH
# Node 63 is sending data using LEACH
# Node 64 is sending data using LEACH
# Node 65 is sending data using LEACH
# Node 66 is sending data using LEACH
# Node 67 is sending data using LEACH
# Node 68 is sending data using LEACH
# Node 69 is sending data using LEACH
# Node 70 is sending data using LEACH
# Node 71 is sending data using LEACH
# Node 72 is sending data using LEACH
# Node 73 is sending data using LEACH
# Node 74 is sending data using LEACH
# Node 75 is sending data using LEACH
# Node 76 is sending data using LEACH
# Node 77 is sending data using LEACH
# Node 78 is sending data using LEACH
# Node 79 is sending data using LEACH
# Node 80 is sending data using LEACH
# Node 1 is sending data using LEACH
# Node 2 is sending data using LEACH
# Node 3 is sending data using LEACH
# Node 4 is sending data using LEACH
# Node 5 is sending data using LEACH
# Node 6 is sending data using LEACH
# Node 7 is sending data using LEACH
# Node 8 is sending data using LEACH
# Node 9 is sending data using LEACH
# Node 10 is sending data using LEACH
# Node 11 is sending data using LEACH
# Node 12 is sending data using LEACH
# Node 13 is sending data using LEACH
# Node 14 is sending data using LEACH
# Node 15 is sending data using LEACH
# Node 16 is sending data using LEACH
# Node 17 is sending data using LEACH
# Node 18 is sending data using LEACH
# Node 19 is sending data using LEACH
# Node 20 is sending data using LEACH
# Node 21 is sending data using LEACH
# Node 22 is sending data using LEACH
# Node 23 is sending data using LEACH
# Node 24 is sending data using LEACH
# Node 25 is sending data using LEACH
# Node 26 is sending data using LEACH
# Node 27 is sending data using LEACH
# Node 28 is sending data using LEACH
# Node 29 is sending data using LEACH
# Node 30 is sending data using LEACH
# Node 31 is sending data using LEACH
# Node 32 is sending data using LEACH
# Node 33 is sending data using LEACH
# Node 34 is sending data using LEACH
# Node 35 is sending data using LEACH
# Node 36 is sending data using LEACH
# Node 37 is sending data using LEACH
# Node 38 is sending data using LEACH
# Node 39 is sending data using LEACH
# Node 40 is sending data using LEACH
# Node 41 is sending data using LEACH
# Node 42 is sending data using LEACH
# Node 43 is sending data using LEACH
# Node 44 is sending data using LEACH
# Node 45 is sending data using LEACH
# Node 46 is sending data using LEACH
# Node 47 is sending data using LEACH
# Node 48 is sending data using LEACH
# Node 49 is sending data using LEACH
# Node 50 is sending data using LEACH
# Node 51 is sending data using LEACH
# Node 52 is sending data using LEACH
# Node 53 is sending data using LEACH
# Node 54 is sending data using LEACH
# Node 55 is sending data using LEACH
# Node 56 is sending data using LEACH
# Node 57 is sending data using LEACH
# Node 58 is sending data using LEACH
# Node 59 is sending data using LEACH
# Node 60 is sending data using LEACH
# Node 61 is sending data using LEACH
# Node 62 is sending data using LEACH
# Node 63 is sending data using LEACH
# Node 64 is sending data using LEACH
# Node 65 is sending data using LEACH
# Node 66 is sending data using LEACH
# Node 67 is sending data using LEACH
# Node 68 is sending data using LEACH
# Node 69 is sending data using LEACH
# Node 70 is sending data using LEACH
# Node 71 is sending data using LEACH
# Node 72 is sending data using LEACH
# Node 73 is sending data using LEACH
# Node 74 is sending data using LEACH
# Node 75 is sending data using LEACH
# Node 76 is sending data using LEACH
# Node 77 is sending data using LEACH
# Node 78 is sending data using LEACH
# Node 79 is sending data using LEACH
# Node 80 is sending data using LEACH
# Node 81 is sending data using LEACH
# Node 82 is sending data using LEACH
# Node 83 is sending data using LEACH
# Node 84 is sending data using LEACH
# Node 85 is sending data using LEACH
# Node 86 is sending data using LEACH
# Node 87 is sending data using LEACH
# Node 88 is sending data using LEACH
# Node 89 is sending data using LEACH
# Node 90 is sending data using LEACH
# Node 1 is sending data using LEACH
# Node 2 is sending data using LEACH
# Node 3 is sending data using LEACH
# Node 4 is sending data using LEACH
# Node 5 is sending data using LEACH
# Node 6 is sending data using LEACH
# Node 7 is sending data using LEACH
# Node 8 is sending data using LEACH
# Node 9 is sending data using LEACH
# Node 10 is sending data using LEACH
# Node 11 is sending data using LEACH
# Node 12 is sending data using LEACH
# Node 13 is sending data using LEACH
# Node 14 is sending data using LEACH
# Node 15 is sending data using LEACH
# Node 16 is sending data using LEACH
# Node 17 is sending data using LEACH
# Node 18 is sending data using LEACH
# Node 19 is sending data using LEACH
# Node 20 is sending data using LEACH
# Node 21 is sending data using LEACH
# Node 22 is sending data using LEACH
# Node 23 is sending data using LEACH
# Node 24 is sending data using LEACH
# Node 25 is sending data using LEACH
# Node 26 is sending data using LEACH
# Node 27 is sending data using LEACH
# Node 28 is sending data using LEACH
# Node 29 is sending data using LEACH
# Node 30 is sending data using LEACH
# Node 31 is sending data using LEACH
# Node 32 is sending data using LEACH
# Node 33 is sending data using LEACH
# Node 34 is sending data using LEACH
# Node 35 is sending data using LEACH
# Node 36 is sending data using LEACH
# Node 37 is sending data using LEACH
# Node 38 is sending data using LEACH
# Node 39 is sending data using LEACH
# Node 40 is sending data using LEACH
# Node 41 is sending data using LEACH
# Node 42 is sending data using LEACH
# Node 43 is sending data using LEACH
# Node 44 is sending data using LEACH
# Node 45 is sending data using LEACH
# Node 46 is sending data using LEACH
# Node 47 is sending data using LEACH
# Node 48 is sending data using LEACH
# Node 49 is sending data using LEACH
# Node 50 is sending data using LEACH
# Node 51 is sending data using LEACH
# Node 52 is sending data using LEACH
# Node 53 is sending data using LEACH
# Node 54 is sending data using LEACH
# Node 55 is sending data using LEACH
# Node 56 is sending data using LEACH
# Node 57 is sending data using LEACH
# Node 58 is sending data using LEACH
# Node 59 is sending data using LEACH
# Node 60 is sending data using LEACH
# Node 61 is sending data using LEACH
# Node 62 is sending data using LEACH
# Node 63 is sending data using LEACH
# Node 64 is sending data using LEACH
# Node 65 is sending data using LEACH
# Node 66 is sending data using LEACH
# Node 67 is sending data using LEACH
# Node 68 is sending data using LEACH
# Node 69 is sending data using LEACH
# Node 70 is sending data using LEACH
# Node 71 is sending data using LEACH
# Node 72 is sending data using LEACH
# Node 73 is sending data using LEACH
# Node 74 is sending data using LEACH
# Node 75 is sending data using LEACH
# Node 76 is sending data using LEACH
# Node 77 is sending data using LEACH
# Node 78 is sending data using LEACH
# Node 79 is sending data using LEACH
# Node 80 is sending data using LEACH
# Node 81 is sending data using LEACH
# Node 82 is sending data using LEACH
# Node 83 is sending data using LEACH
# Node 84 is sending data using LEACH
# Node 85 is sending data using LEACH
# Node 86 is sending data using LEACH
# Node 87 is sending data using LEACH
# Node 88 is sending data using LEACH
# Node 89 is sending data using LEACH
# Node 90 is sending data using LEACH
# Node 91 is sending data using LEACH
# Node 92 is sending data using LEACH
# Node 93 is sending data using LEACH
# Node 94 is sending data using LEACH
# Node 95 is sending data using LEACH
# Node 96 is sending data using LEACH
# Node 97 is sending data using LEACH
# Node 98 is sending data using LEACH
# Node 99 is sending data using LEACH
# Node 100 is sending data using LEACH

# %%
import random
import matplotlib.pyplot as plt

# Constants for protocols
PROTOCOL_CAMELLIA = "Camellia"
PROTOCOL_LEACH = "LEACH"

# Function to simulate Camellia-specific data transmission
def send_data_camellia(node_id):
    print(f"Node {node_id} is sending data using {PROTOCOL_CAMELLIA}")
    # Simulate energy consumption for Camellia (replace with actual energy calculation)
    energy_consumption[node_id - 1] += random.uniform(1.0, 3.0)

# Function to simulate LEACH-specific data transmission
def send_data_leach(node_id):
    print(f"Node {node_id} is sending data using {PROTOCOL_LEACH}")
    # Simulate energy consumption for LEACH (replace with actual energy calculation)
    energy_consumption[node_id - 1] += random.uniform(0.5, 2.0)

# Simulated WSN parameters
num_nodes = 10  # Initial number of nodes
max_nodes = 100  # Maximum number of nodes for the simulation

# Lists to store energy consumption data for Camellia and LEACH
energy_consumption_camellia = [0] * max_nodes
energy_consumption_leach = [0] * max_nodes

# Lists to store the number of nodes and energy efficiency for each protocol
num_nodes_list = []
energy_efficiency_camellia_list = []
energy_efficiency_leach_list = []

# Main simulation loop
while num_nodes <= max_nodes:
    for node_id in range(1, num_nodes + 1):
        # Generate random data for the node
        sensor_data = random.randint(0, 100)

        # Determine which protocol to use based on the number of nodes
        if num_nodes <= 50:
            send_data_camellia(node_id)
        else:
            send_data_leach(node_id)

    # Calculate energy efficiency (total data sent per unit energy) for each protocol
    total_data_sent = num_nodes * 100  # Assuming each node sends 100 units of data
    total_energy_consumed_camellia = sum(energy_consumption[:num_nodes])
    total_energy_consumed_leach = sum(energy_consumption[:num_nodes])

    energy_efficiency_camellia = total_data_sent / total_energy_consumed_camellia
    energy_efficiency_leach = total_data_sent / total_energy_consumed_leach

    # Store data for plotting
    num_nodes_list.append(num_nodes)
    energy_efficiency_camellia_list.append(energy_efficiency_camellia)
    energy_efficiency_leach_list.append(energy_efficiency_leach)

    # Increase the number of nodes (you can adjust this as needed)
    num_nodes += 10

# Plot energy efficiency vs. number of nodes for Camellia
plt.figure(figsize=(8, 6))
plt.plot(num_nodes_list, energy_efficiency_camellia_list, marker='o', linestyle='-', label=PROTOCOL_CAMELLIA)
plt.title(f'Energy Efficiency vs. Number of Nodes ({PROTOCOL_CAMELLIA})')
plt.xlabel('Number of Nodes')
plt.ylabel('Energy Efficiency')
plt.grid(True)
plt.legend()
plt.show()

# Plot energy efficiency vs. number of nodes for LEACH
plt.figure(figsize=(8, 6))
plt.plot(num_nodes_list, energy_efficiency_leach_list, marker='o', linestyle='-', label=PROTOCOL_LEACH)
plt.title(f'Energy Efficiency vs. Number of Nodes ({PROTOCOL_LEACH})')
plt.xlabel('Number of Nodes')
plt.ylabel('Energy Efficiency')
plt.grid(True)
plt.legend()
plt.show()
# Out:
# Node 1 is sending data using Camellia
# Node 2 is sending data using Camellia
# Node 3 is sending data using Camellia
# Node 4 is sending data using Camellia
# Node 5 is sending data using Camellia
# Node 6 is sending data using Camellia
# Node 7 is sending data using Camellia
# Node 8 is sending data using Camellia
# Node 9 is sending data using Camellia
# Node 10 is sending data using Camellia
# Node 1 is sending data using Camellia
# Node 2 is sending data using Camellia
# Node 3 is sending data using Camellia
# Node 4 is sending data using Camellia
# Node 5 is sending data using Camellia
# Node 6 is sending data using Camellia
# Node 7 is sending data using Camellia
# Node 8 is sending data using Camellia
# Node 9 is sending data using Camellia
# Node 10 is sending data using Camellia
# Node 11 is sending data using Camellia
# Node 12 is sending data using Camellia
# Node 13 is sending data using Camellia
# Node 14 is sending data using Camellia
# Node 15 is sending data using Camellia
# Node 16 is sending data using Camellia
# Node 17 is sending data using Camellia
# Node 18 is sending data using Camellia
# Node 19 is sending data using Camellia
# Node 20 is sending data using Camellia
# Node 1 is sending data using Camellia
# Node 2 is sending data using Camellia
# Node 3 is sending data using Camellia
# Node 4 is sending data using Camellia
# Node 5 is sending data using Camellia
# Node 6 is sending data using Camellia
# Node 7 is sending data using Camellia
# Node 8 is sending data using Camellia
# Node 9 is sending data using Camellia
# Node 10 is sending data using Camellia
# Node 11 is sending data using Camellia
# Node 12 is sending data using Camellia
# Node 13 is sending data using Camellia
# Node 14 is sending data using Camellia
# Node 15 is sending data using Camellia
# Node 16 is sending data using Camellia
# Node 17 is sending data using Camellia
# Node 18 is sending data using Camellia
# Node 19 is sending data using Camellia
# Node 20 is sending data using Camellia
# Node 21 is sending data using Camellia
# Node 22 is sending data using Camellia
# Node 23 is sending data using Camellia
# Node 24 is sending data using Camellia
# Node 25 is sending data using Camellia
# Node 26 is sending data using Camellia
# Node 27 is sending data using Camellia
# Node 28 is sending data using Camellia
# Node 29 is sending data using Camellia
# Node 30 is sending data using Camellia
# Node 1 is sending data using Camellia
# Node 2 is sending data using Camellia
# Node 3 is sending data using Camellia
# Node 4 is sending data using Camellia
# Node 5 is sending data using Camellia
# Node 6 is sending data using Camellia
# Node 7 is sending data using Camellia
# Node 8 is sending data using Camellia
# Node 9 is sending data using Camellia
# Node 10 is sending data using Camellia
# Node 11 is sending data using Camellia
# Node 12 is sending data using Camellia
# Node 13 is sending data using Camellia
# Node 14 is sending data using Camellia
# Node 15 is sending data using Camellia
# Node 16 is sending data using Camellia
# Node 17 is sending data using Camellia
# Node 18 is sending data using Camellia
# Node 19 is sending data using Camellia
# Node 20 is sending data using Camellia
# Node 21 is sending data using Camellia
# Node 22 is sending data using Camellia
# Node 23 is sending data using Camellia
# Node 24 is sending data using Camellia
# Node 25 is sending data using Camellia
# Node 26 is sending data using Camellia
# Node 27 is sending data using Camellia
# Node 28 is sending data using Camellia
# Node 29 is sending data using Camellia
# Node 30 is sending data using Camellia
# Node 31 is sending data using Camellia
# Node 32 is sending data using Camellia
# Node 33 is sending data using Camellia
# Node 34 is sending data using Camellia
# Node 35 is sending data using Camellia
# Node 36 is sending data using Camellia
# Node 37 is sending data using Camellia
# Node 38 is sending data using Camellia
# Node 39 is sending data using Camellia
# Node 40 is sending data using Camellia
# Node 1 is sending data using Camellia
# Node 2 is sending data using Camellia
# Node 3 is sending data using Camellia
# Node 4 is sending data using Camellia
# Node 5 is sending data using Camellia
# Node 6 is sending data using Camellia
# Node 7 is sending data using Camellia
# Node 8 is sending data using Camellia
# Node 9 is sending data using Camellia
# Node 10 is sending data using Camellia
# Node 11 is sending data using Camellia
# Node 12 is sending data using Camellia
# Node 13 is sending data using Camellia
# Node 14 is sending data using Camellia
# Node 15 is sending data using Camellia
# Node 16 is sending data using Camellia
# Node 17 is sending data using Camellia
# Node 18 is sending data using Camellia
# Node 19 is sending data using Camellia
# Node 20 is sending data using Camellia
# Node 21 is sending data using Camellia
# Node 22 is sending data using Camellia
# Node 23 is sending data using Camellia
# Node 24 is sending data using Camellia
# Node 25 is sending data using Camellia
# Node 26 is sending data using Camellia
# Node 27 is sending data using Camellia
# Node 28 is sending data using Camellia
# Node 29 is sending data using Camellia
# Node 30 is sending data using Camellia
# Node 31 is sending data using Camellia
# Node 32 is sending data using Camellia
# Node 33 is sending data using Camellia
# Node 34 is sending data using Camellia
# Node 35 is sending data using Camellia
# Node 36 is sending data using Camellia
# Node 37 is sending data using Camellia
# Node 38 is sending data using Camellia
# Node 39 is sending data using Camellia
# Node 40 is sending data using Camellia
# Node 41 is sending data using Camellia
# Node 42 is sending data using Camellia
# Node 43 is sending data using Camellia
# Node 44 is sending data using Camellia
# Node 45 is sending data using Camellia
# Node 46 is sending data using Camellia
# Node 47 is sending data using Camellia
# Node 48 is sending data using Camellia
# Node 49 is sending data using Camellia
# Node 50 is sending data using Camellia
# Node 1 is sending data using LEACH
# Node 2 is sending data using LEACH
# Node 3 is sending data using LEACH
# Node 4 is sending data using LEACH
# Node 5 is sending data using LEACH
# Node 6 is sending data using LEACH
# Node 7 is sending data using LEACH
# Node 8 is sending data using LEACH
# Node 9 is sending data using LEACH
# Node 10 is sending data using LEACH
# Node 11 is sending data using LEACH
# Node 12 is sending data using LEACH
# Node 13 is sending data using LEACH
# Node 14 is sending data using LEACH
# Node 15 is sending data using LEACH
# Node 16 is sending data using LEACH
# Node 17 is sending data using LEACH
# Node 18 is sending data using LEACH
# Node 19 is sending data using LEACH
# Node 20 is sending data using LEACH
# Node 21 is sending data using LEACH
# Node 22 is sending data using LEACH
# Node 23 is sending data using LEACH
# Node 24 is sending data using LEACH
# Node 25 is sending data using LEACH
# Node 26 is sending data using LEACH
# Node 27 is sending data using LEACH
# Node 28 is sending data using LEACH
# Node 29 is sending data using LEACH
# Node 30 is sending data using LEACH
# Node 31 is sending data using LEACH
# Node 32 is sending data using LEACH
# Node 33 is sending data using LEACH
# Node 34 is sending data using LEACH
# Node 35 is sending data using LEACH
# Node 36 is sending data using LEACH
# Node 37 is sending data using LEACH
# Node 38 is sending data using LEACH
# Node 39 is sending data using LEACH
# Node 40 is sending data using LEACH
# Node 41 is sending data using LEACH
# Node 42 is sending data using LEACH
# Node 43 is sending data using LEACH
# Node 44 is sending data using LEACH
# Node 45 is sending data using LEACH
# Node 46 is sending data using LEACH
# Node 47 is sending data using LEACH
# Node 48 is sending data using LEACH
# Node 49 is sending data using LEACH
# Node 50 is sending data using LEACH
# Node 51 is sending data using LEACH
# Node 52 is sending data using LEACH
# Node 53 is sending data using LEACH
# Node 54 is sending data using LEACH
# Node 55 is sending data using LEACH
# Node 56 is sending data using LEACH
# Node 57 is sending data using LEACH
# Node 58 is sending data using LEACH
# Node 59 is sending data using LEACH
# Node 60 is sending data using LEACH
# Node 1 is sending data using LEACH
# Node 2 is sending data using LEACH
# Node 3 is sending data using LEACH
# Node 4 is sending data using LEACH
# Node 5 is sending data using LEACH
# Node 6 is sending data using LEACH
# Node 7 is sending data using LEACH
# Node 8 is sending data using LEACH
# Node 9 is sending data using LEACH
# Node 10 is sending data using LEACH
# Node 11 is sending data using LEACH
# Node 12 is sending data using LEACH
# Node 13 is sending data using LEACH
# Node 14 is sending data using LEACH
# Node 15 is sending data using LEACH
# Node 16 is sending data using LEACH
# Node 17 is sending data using LEACH
# Node 18 is sending data using LEACH
# Node 19 is sending data using LEACH
# Node 20 is sending data using LEACH
# Node 21 is sending data using LEACH
# Node 22 is sending data using LEACH
# Node 23 is sending data using LEACH
# Node 24 is sending data using LEACH
# Node 25 is sending data using LEACH
# Node 26 is sending data using LEACH
# Node 27 is sending data using LEACH
# Node 28 is sending data using LEACH
# Node 29 is sending data using LEACH
# Node 30 is sending data using LEACH
# Node 31 is sending data using LEACH
# Node 32 is sending data using LEACH
# Node 33 is sending data using LEACH
# Node 34 is sending data using LEACH
# Node 35 is sending data using LEACH
# Node 36 is sending data using LEACH
# Node 37 is sending data using LEACH
# Node 38 is sending data using LEACH
# Node 39 is sending data using LEACH
# Node 40 is sending data using LEACH
# Node 41 is sending data using LEACH
# Node 42 is sending data using LEACH
# Node 43 is sending data using LEACH
# Node 44 is sending data using LEACH
# Node 45 is sending data using LEACH
# Node 46 is sending data using LEACH
# Node 47 is sending data using LEACH
# Node 48 is sending data using LEACH
# Node 49 is sending data using LEACH
# Node 50 is sending data using LEACH
# Node 51 is sending data using LEACH
# Node 52 is sending data using LEACH
# Node 53 is sending data using LEACH
# Node 54 is sending data using LEACH
# Node 55 is sending data using LEACH
# Node 56 is sending data using LEACH
# Node 57 is sending data using LEACH
# Node 58 is sending data using LEACH
# Node 59 is sending data using LEACH
# Node 60 is sending data using LEACH
# Node 61 is sending data using LEACH
# Node 62 is sending data using LEACH
# Node 63 is sending data using LEACH
# Node 64 is sending data using LEACH
# Node 65 is sending data using LEACH
# Node 66 is sending data using LEACH
# Node 67 is sending data using LEACH
# Node 68 is sending data using LEACH
# Node 69 is sending data using LEACH
# Node 70 is sending data using LEACH
# Node 1 is sending data using LEACH
# Node 2 is sending data using LEACH
# Node 3 is sending data using LEACH
# Node 4 is sending data using LEACH
# Node 5 is sending data using LEACH
# Node 6 is sending data using LEACH
# Node 7 is sending data using LEACH
# Node 8 is sending data using LEACH
# Node 9 is sending data using LEACH
# Node 10 is sending data using LEACH
# Node 11 is sending data using LEACH
# Node 12 is sending data using LEACH
# Node 13 is sending data using LEACH
# Node 14 is sending data using LEACH
# Node 15 is sending data using LEACH
# Node 16 is sending data using LEACH
# Node 17 is sending data using LEACH
# Node 18 is sending data using LEACH
# Node 19 is sending data using LEACH
# Node 20 is sending data using LEACH
# Node 21 is sending data using LEACH
# Node 22 is sending data using LEACH
# Node 23 is sending data using LEACH
# Node 24 is sending data using LEACH
# Node 25 is sending data using LEACH
# Node 26 is sending data using LEACH
# Node 27 is sending data using LEACH
# Node 28 is sending data using LEACH
# Node 29 is sending data using LEACH
# Node 30 is sending data using LEACH
# Node 31 is sending data using LEACH
# Node 32 is sending data using LEACH
# Node 33 is sending data using LEACH
# Node 34 is sending data using LEACH
# Node 35 is sending data using LEACH
# Node 36 is sending data using LEACH
# Node 37 is sending data using LEACH
# Node 38 is sending data using LEACH
# Node 39 is sending data using LEACH
# Node 40 is sending data using LEACH
# Node 41 is sending data using LEACH
# Node 42 is sending data using LEACH
# Node 43 is sending data using LEACH
# Node 44 is sending data using LEACH
# Node 45 is sending data using LEACH
# Node 46 is sending data using LEACH
# Node 47 is sending data using LEACH
# Node 48 is sending data using LEACH
# Node 49 is sending data using LEACH
# Node 50 is sending data using LEACH
# Node 51 is sending data using LEACH
# Node 52 is sending data using LEACH
# Node 53 is sending data using LEACH
# Node 54 is sending data using LEACH
# Node 55 is sending data using LEACH
# Node 56 is sending data using LEACH
# Node 57 is sending data using LEACH
# Node 58 is sending data using LEACH
# Node 59 is sending data using LEACH
# Node 60 is sending data using LEACH
# Node 61 is sending data using LEACH
# Node 62 is sending data using LEACH
# Node 63 is sending data using LEACH
# Node 64 is sending data using LEACH
# Node 65 is sending data using LEACH
# Node 66 is sending data using LEACH
# Node 67 is sending data using LEACH
# Node 68 is sending data using LEACH
# Node 69 is sending data using LEACH
# Node 70 is sending data using LEACH
# Node 71 is sending data using LEACH
# Node 72 is sending data using LEACH
# Node 73 is sending data using LEACH
# Node 74 is sending data using LEACH
# Node 75 is sending data using LEACH
# Node 76 is sending data using LEACH
# Node 77 is sending data using LEACH
# Node 78 is sending data using LEACH
# Node 79 is sending data using LEACH
# Node 80 is sending data using LEACH
# Node 1 is sending data using LEACH
# Node 2 is sending data using LEACH
# Node 3 is sending data using LEACH
# Node 4 is sending data using LEACH
# Node 5 is sending data using LEACH
# Node 6 is sending data using LEACH
# Node 7 is sending data using LEACH
# Node 8 is sending data using LEACH
# Node 9 is sending data using LEACH
# Node 10 is sending data using LEACH
# Node 11 is sending data using LEACH
# Node 12 is sending data using LEACH
# Node 13 is sending data using LEACH
# Node 14 is sending data using LEACH
# Node 15 is sending data using LEACH
# Node 16 is sending data using LEACH
# Node 17 is sending data using LEACH
# Node 18 is sending data using LEACH
# Node 19 is sending data using LEACH
# Node 20 is sending data using LEACH
# Node 21 is sending data using LEACH
# Node 22 is sending data using LEACH
# Node 23 is sending data using LEACH
# Node 24 is sending data using LEACH
# Node 25 is sending data using LEACH
# Node 26 is sending data using LEACH
# Node 27 is sending data using LEACH
# Node 28 is sending data using LEACH
# Node 29 is sending data using LEACH
# Node 30 is sending data using LEACH
# Node 31 is sending data using LEACH
# Node 32 is sending data using LEACH
# Node 33 is sending data using LEACH
# Node 34 is sending data using LEACH
# Node 35 is sending data using LEACH
# Node 36 is sending data using LEACH
# Node 37 is sending data using LEACH
# Node 38 is sending data using LEACH
# Node 39 is sending data using LEACH
# Node 40 is sending data using LEACH
# Node 41 is sending data using LEACH
# Node 42 is sending data using LEACH
# Node 43 is sending data using LEACH
# Node 44 is sending data using LEACH
# Node 45 is sending data using LEACH
# Node 46 is sending data using LEACH
# Node 47 is sending data using LEACH
# Node 48 is sending data using LEACH
# Node 49 is sending data using LEACH
# Node 50 is sending data using LEACH
# Node 51 is sending data using LEACH
# Node 52 is sending data using LEACH
# Node 53 is sending data using LEACH
# Node 54 is sending data using LEACH
# Node 55 is sending data using LEACH
# Node 56 is sending data using LEACH
# Node 57 is sending data using LEACH
# Node 58 is sending data using LEACH
# Node 59 is sending data using LEACH
# Node 60 is sending data using LEACH
# Node 61 is sending data using LEACH
# Node 62 is sending data using LEACH
# Node 63 is sending data using LEACH
# Node 64 is sending data using LEACH
# Node 65 is sending data using LEACH
# Node 66 is sending data using LEACH
# Node 67 is sending data using LEACH
# Node 68 is sending data using LEACH
# Node 69 is sending data using LEACH
# Node 70 is sending data using LEACH
# Node 71 is sending data using LEACH
# Node 72 is sending data using LEACH
# Node 73 is sending data using LEACH
# Node 74 is sending data using LEACH
# Node 75 is sending data using LEACH
# Node 76 is sending data using LEACH
# Node 77 is sending data using LEACH
# Node 78 is sending data using LEACH
# Node 79 is sending data using LEACH
# Node 80 is sending data using LEACH
# Node 81 is sending data using LEACH
# Node 82 is sending data using LEACH
# Node 83 is sending data using LEACH
# Node 84 is sending data using LEACH
# Node 85 is sending data using LEACH
# Node 86 is sending data using LEACH
# Node 87 is sending data using LEACH
# Node 88 is sending data using LEACH
# Node 89 is sending data using LEACH
# Node 90 is sending data using LEACH
# Node 1 is sending data using LEACH
# Node 2 is sending data using LEACH
# Node 3 is sending data using LEACH
# Node 4 is sending data using LEACH
# Node 5 is sending data using LEACH
# Node 6 is sending data using LEACH
# Node 7 is sending data using LEACH
# Node 8 is sending data using LEACH
# Node 9 is sending data using LEACH
# Node 10 is sending data using LEACH
# Node 11 is sending data using LEACH
# Node 12 is sending data using LEACH
# Node 13 is sending data using LEACH
# Node 14 is sending data using LEACH
# Node 15 is sending data using LEACH
# Node 16 is sending data using LEACH
# Node 17 is sending data using LEACH
# Node 18 is sending data using LEACH
# Node 19 is sending data using LEACH
# Node 20 is sending data using LEACH
# Node 21 is sending data using LEACH
# Node 22 is sending data using LEACH
# Node 23 is sending data using LEACH
# Node 24 is sending data using LEACH
# Node 25 is sending data using LEACH
# Node 26 is sending data using LEACH
# Node 27 is sending data using LEACH
# Node 28 is sending data using LEACH
# Node 29 is sending data using LEACH
# Node 30 is sending data using LEACH
# Node 31 is sending data using LEACH
# Node 32 is sending data using LEACH
# Node 33 is sending data using LEACH
# Node 34 is sending data using LEACH
# Node 35 is sending data using LEACH
# Node 36 is sending data using LEACH
# Node 37 is sending data using LEACH
# Node 38 is sending data using LEACH
# Node 39 is sending data using LEACH
# Node 40 is sending data using LEACH
# Node 41 is sending data using LEACH
# Node 42 is sending data using LEACH
# Node 43 is sending data using LEACH
# Node 44 is sending data using LEACH
# Node 45 is sending data using LEACH
# Node 46 is sending data using LEACH
# Node 47 is sending data using LEACH
# Node 48 is sending data using LEACH
# Node 49 is sending data using LEACH
# Node 50 is sending data using LEACH
# Node 51 is sending data using LEACH
# Node 52 is sending data using LEACH
# Node 53 is sending data using LEACH
# Node 54 is sending data using LEACH
# Node 55 is sending data using LEACH
# Node 56 is sending data using LEACH
# Node 57 is sending data using LEACH
# Node 58 is sending data using LEACH
# Node 59 is sending data using LEACH
# Node 60 is sending data using LEACH
# Node 61 is sending data using LEACH
# Node 62 is sending data using LEACH
# Node 63 is sending data using LEACH
# Node 64 is sending data using LEACH
# Node 65 is sending data using LEACH
# Node 66 is sending data using LEACH
# Node 67 is sending data using LEACH
# Node 68 is sending data using LEACH
# Node 69 is sending data using LEACH
# Node 70 is sending data using LEACH
# Node 71 is sending data using LEACH
# Node 72 is sending data using LEACH
# Node 73 is sending data using LEACH
# Node 74 is sending data using LEACH
# Node 75 is sending data using LEACH
# Node 76 is sending data using LEACH
# Node 77 is sending data using LEACH
# Node 78 is sending data using LEACH
# Node 79 is sending data using LEACH
# Node 80 is sending data using LEACH
# Node 81 is sending data using LEACH
# Node 82 is sending data using LEACH
# Node 83 is sending data using LEACH
# Node 84 is sending data using LEACH
# Node 85 is sending data using LEACH
# Node 86 is sending data using LEACH
# Node 87 is sending data using LEACH
# Node 88 is sending data using LEACH
# Node 89 is sending data using LEACH
# Node 90 is sending data using LEACH
# Node 91 is sending data using LEACH
# Node 92 is sending data using LEACH
# Node 93 is sending data using LEACH
# Node 94 is sending data using LEACH
# Node 95 is sending data using LEACH
# Node 96 is sending data using LEACH
# Node 97 is sending data using LEACH
# Node 98 is sending data using LEACH
# Node 99 is sending data using LEACH
# Node 100 is sending data using LEACH

# %%
import random
import matplotlib.pyplot as plt

# Constants for protocols
PROTOCOL_CAMELLIA = "Camellia"
PROTOCOL_LEACH = "LEACH"

# Function to simulate Camellia-specific data transmission
def send_data_camellia(node_id):
    print(f"Node {node_id} is sending data using {PROTOCOL_CAMELLIA}")
    # Simulate energy consumption for Camellia (replace with actual energy calculation)
    energy_consumption[node_id - 1] += random.uniform(1.0, 3.0)

# Function to simulate LEACH-specific data transmission
def send_data_leach(node_id):
    print(f"Node {node_id} is sending data using {PROTOCOL_LEACH}")
    # Simulate energy consumption for LEACH (replace with actual energy calculation)
    energy_consumption[node_id - 1] += random.uniform(0.5, 2.0)

# Simulated WSN parameters
num_nodes = 10  # Initial number of nodes
max_nodes = 100  # Maximum number of nodes for the simulation

# Lists to store energy consumption data for Camellia and LEACH
energy_consumption_camellia = [0] * max_nodes
energy_consumption_leach = [0] * max_nodes

# Lists to store the number of nodes and energy efficiency for each protocol
num_nodes_list = []
energy_efficiency_camellia_list = []
energy_efficiency_leach_list = []

# Main simulation loop
while num_nodes <= max_nodes:
    for node_id in range(1, num_nodes + 1):
        # Generate random data for the node
        sensor_data = random.randint(0, 100)

        # Determine which protocol to use based on the number of nodes
        if num_nodes <= 50:
            send_data_camellia(node_id)
        else:
            send_data_leach(node_id)

    # Calculate energy efficiency (total data sent per unit energy) for each protocol
    total_data_sent = num_nodes * 100  # Assuming each node sends 100 units of data
    total_energy_consumed_camellia = sum(energy_consumption[:num_nodes])
    total_energy_consumed_leach = sum(energy_consumption[:num_nodes])

    energy_efficiency_camellia = total_data_sent / total_energy_consumed_camellia
    energy_efficiency_leach = total_data_sent / total_energy_consumed_leach

    # Store data for plotting
    num_nodes_list.append(num_nodes)
    energy_efficiency_camellia_list.append(energy_efficiency_camellia)
    energy_efficiency_leach_list.append(energy_efficiency_leach)

    # Increase the number of nodes (you can adjust this as needed)
    num_nodes += 10

# Plot energy efficiency vs. number of nodes for Camellia and LEACH on the same page
plt.figure(figsize=(12, 6))

# Plot for Camellia
plt.subplot(1, 2, 1)
plt.plot(num_nodes_list, energy_efficiency_camellia_list, marker='o', linestyle='-', label=PROTOCOL_CAMELLIA)
plt.title(f'Energy Efficiency vs. Number of Nodes ({PROTOCOL_CAMELLIA})')
plt.xlabel('Number of Nodes')
plt.ylabel('Energy Efficiency')
plt.grid(True)
plt.legend()

# Plot for LEACH
plt.subplot(1, 2, 2)
plt.plot(num_nodes_list, energy_efficiency_leach_list, marker='o', linestyle='-', label=PROTOCOL_LEACH)
plt.title(f'Energy Efficiency vs. Number of Nodes ({PROTOCOL_LEACH})')
plt.xlabel('Number of Nodes')
plt.ylabel('Energy Efficiency')
plt.grid(True)
plt.legend()

plt.tight_layout()  # Ensures subplots do not overlap
plt.show()
# Out:
# Node 1 is sending data using Camellia
# Node 2 is sending data using Camellia
# Node 3 is sending data using Camellia
# Node 4 is sending data using Camellia
# Node 5 is sending data using Camellia
# Node 6 is sending data using Camellia
# Node 7 is sending data using Camellia
# Node 8 is sending data using Camellia
# Node 9 is sending data using Camellia
# Node 10 is sending data using Camellia
# Node 1 is sending data using Camellia
# Node 2 is sending data using Camellia
# Node 3 is sending data using Camellia
# Node 4 is sending data using Camellia
# Node 5 is sending data using Camellia
# Node 6 is sending data using Camellia
# Node 7 is sending data using Camellia
# Node 8 is sending data using Camellia
# Node 9 is sending data using Camellia
# Node 10 is sending data using Camellia
# Node 11 is sending data using Camellia
# Node 12 is sending data using Camellia
# Node 13 is sending data using Camellia
# Node 14 is sending data using Camellia
# Node 15 is sending data using Camellia
# Node 16 is sending data using Camellia
# Node 17 is sending data using Camellia
# Node 18 is sending data using Camellia
# Node 19 is sending data using Camellia
# Node 20 is sending data using Camellia
# Node 1 is sending data using Camellia
# Node 2 is sending data using Camellia
# Node 3 is sending data using Camellia
# Node 4 is sending data using Camellia
# Node 5 is sending data using Camellia
# Node 6 is sending data using Camellia
# Node 7 is sending data using Camellia
# Node 8 is sending data using Camellia
# Node 9 is sending data using Camellia
# Node 10 is sending data using Camellia
# Node 11 is sending data using Camellia
# Node 12 is sending data using Camellia
# Node 13 is sending data using Camellia
# Node 14 is sending data using Camellia
# Node 15 is sending data using Camellia
# Node 16 is sending data using Camellia
# Node 17 is sending data using Camellia
# Node 18 is sending data using Camellia
# Node 19 is sending data using Camellia
# Node 20 is sending data using Camellia
# Node 21 is sending data using Camellia
# Node 22 is sending data using Camellia
# Node 23 is sending data using Camellia
# Node 24 is sending data using Camellia
# Node 25 is sending data using Camellia
# Node 26 is sending data using Camellia
# Node 27 is sending data using Camellia
# Node 28 is sending data using Camellia
# Node 29 is sending data using Camellia
# Node 30 is sending data using Camellia
# Node 1 is sending data using Camellia
# Node 2 is sending data using Camellia
# Node 3 is sending data using Camellia
# Node 4 is sending data using Camellia
# Node 5 is sending data using Camellia
# Node 6 is sending data using Camellia
# Node 7 is sending data using Camellia
# Node 8 is sending data using Camellia
# Node 9 is sending data using Camellia
# Node 10 is sending data using Camellia
# Node 11 is sending data using Camellia
# Node 12 is sending data using Camellia
# Node 13 is sending data using Camellia
# Node 14 is sending data using Camellia
# Node 15 is sending data using Camellia
# Node 16 is sending data using Camellia
# Node 17 is sending data using Camellia
# Node 18 is sending data using Camellia
# Node 19 is sending data using Camellia
# Node 20 is sending data using Camellia
# Node 21 is sending data using Camellia
# Node 22 is sending data using Camellia
# Node 23 is sending data using Camellia
# Node 24 is sending data using Camellia
# Node 25 is sending data using Camellia
# Node 26 is sending data using Camellia
# Node 27 is sending data using Camellia
# Node 28 is sending data using Camellia
# Node 29 is sending data using Camellia
# Node 30 is sending data using Camellia
# Node 31 is sending data using Camellia
# Node 32 is sending data using Camellia
# Node 33 is sending data using Camellia
# Node 34 is sending data using Camellia
# Node 35 is sending data using Camellia
# Node 36 is sending data using Camellia
# Node 37 is sending data using Camellia
# Node 38 is sending data using Camellia
# Node 39 is sending data using Camellia
# Node 40 is sending data using Camellia
# Node 1 is sending data using Camellia
# Node 2 is sending data using Camellia
# Node 3 is sending data using Camellia
# Node 4 is sending data using Camellia
# Node 5 is sending data using Camellia
# Node 6 is sending data using Camellia
# Node 7 is sending data using Camellia
# Node 8 is sending data using Camellia
# Node 9 is sending data using Camellia
# Node 10 is sending data using Camellia
# Node 11 is sending data using Camellia
# Node 12 is sending data using Camellia
# Node 13 is sending data using Camellia
# Node 14 is sending data using Camellia
# Node 15 is sending data using Camellia
# Node 16 is sending data using Camellia
# Node 17 is sending data using Camellia
# Node 18 is sending data using Camellia
# Node 19 is sending data using Camellia
# Node 20 is sending data using Camellia
# Node 21 is sending data using Camellia
# Node 22 is sending data using Camellia
# Node 23 is sending data using Camellia
# Node 24 is sending data using Camellia
# Node 25 is sending data using Camellia
# Node 26 is sending data using Camellia
# Node 27 is sending data using Camellia
# Node 28 is sending data using Camellia
# Node 29 is sending data using Camellia
# Node 30 is sending data using Camellia
# Node 31 is sending data using Camellia
# Node 32 is sending data using Camellia
# Node 33 is sending data using Camellia
# Node 34 is sending data using Camellia
# Node 35 is sending data using Camellia
# Node 36 is sending data using Camellia
# Node 37 is sending data using Camellia
# Node 38 is sending data using Camellia
# Node 39 is sending data using Camellia
# Node 40 is sending data using Camellia
# Node 41 is sending data using Camellia
# Node 42 is sending data using Camellia
# Node 43 is sending data using Camellia
# Node 44 is sending data using Camellia
# Node 45 is sending data using Camellia
# Node 46 is sending data using Camellia
# Node 47 is sending data using Camellia
# Node 48 is sending data using Camellia
# Node 49 is sending data using Camellia
# Node 50 is sending data using Camellia
# Node 1 is sending data using LEACH
# Node 2 is sending data using LEACH
# Node 3 is sending data using LEACH
# Node 4 is sending data using LEACH
# Node 5 is sending data using LEACH
# Node 6 is sending data using LEACH
# Node 7 is sending data using LEACH
# Node 8 is sending data using LEACH
# Node 9 is sending data using LEACH
# Node 10 is sending data using LEACH
# Node 11 is sending data using LEACH
# Node 12 is sending data using LEACH
# Node 13 is sending data using LEACH
# Node 14 is sending data using LEACH
# Node 15 is sending data using LEACH
# Node 16 is sending data using LEACH
# Node 17 is sending data using LEACH
# Node 18 is sending data using LEACH
# Node 19 is sending data using LEACH
# Node 20 is sending data using LEACH
# Node 21 is sending data using LEACH
# Node 22 is sending data using LEACH
# Node 23 is sending data using LEACH
# Node 24 is sending data using LEACH
# Node 25 is sending data using LEACH
# Node 26 is sending data using LEACH
# Node 27 is sending data using LEACH
# Node 28 is sending data using LEACH
# Node 29 is sending data using LEACH
# Node 30 is sending data using LEACH
# Node 31 is sending data using LEACH
# Node 32 is sending data using LEACH
# Node 33 is sending data using LEACH
# Node 34 is sending data using LEACH
# Node 35 is sending data using LEACH
# Node 36 is sending data using LEACH
# Node 37 is sending data using LEACH
# Node 38 is sending data using LEACH
# Node 39 is sending data using LEACH
# Node 40 is sending data using LEACH
# Node 41 is sending data using LEACH
# Node 42 is sending data using LEACH
# Node 43 is sending data using LEACH
# Node 44 is sending data using LEACH
# Node 45 is sending data using LEACH
# Node 46 is sending data using LEACH
# Node 47 is sending data using LEACH
# Node 48 is sending data using LEACH
# Node 49 is sending data using LEACH
# Node 50 is sending data using LEACH
# Node 51 is sending data using LEACH
# Node 52 is sending data using LEACH
# Node 53 is sending data using LEACH
# Node 54 is sending data using LEACH
# Node 55 is sending data using LEACH
# Node 56 is sending data using LEACH
# Node 57 is sending data using LEACH
# Node 58 is sending data using LEACH
# Node 59 is sending data using LEACH
# Node 60 is sending data using LEACH
# Node 1 is sending data using LEACH
# Node 2 is sending data using LEACH
# Node 3 is sending data using LEACH
# Node 4 is sending data using LEACH
# Node 5 is sending data using LEACH
# Node 6 is sending data using LEACH
# Node 7 is sending data using LEACH
# Node 8 is sending data using LEACH
# Node 9 is sending data using LEACH
# Node 10 is sending data using LEACH
# Node 11 is sending data using LEACH
# Node 12 is sending data using LEACH
# Node 13 is sending data using LEACH
# Node 14 is sending data using LEACH
# Node 15 is sending data using LEACH
# Node 16 is sending data using LEACH
# Node 17 is sending data using LEACH
# Node 18 is sending data using LEACH
# Node 19 is sending data using LEACH
# Node 20 is sending data using LEACH
# Node 21 is sending data using LEACH
# Node 22 is sending data using LEACH
# Node 23 is sending data using LEACH
# Node 24 is sending data using LEACH
# Node 25 is sending data using LEACH
# Node 26 is sending data using LEACH
# Node 27 is sending data using LEACH
# Node 28 is sending data using LEACH
# Node 29 is sending data using LEACH
# Node 30 is sending data using LEACH
# Node 31 is sending data using LEACH
# Node 32 is sending data using LEACH
# Node 33 is sending data using LEACH
# Node 34 is sending data using LEACH
# Node 35 is sending data using LEACH
# Node 36 is sending data using LEACH
# Node 37 is sending data using LEACH
# Node 38 is sending data using LEACH
# Node 39 is sending data using LEACH
# Node 40 is sending data using LEACH
# Node 41 is sending data using LEACH
# Node 42 is sending data using LEACH
# Node 43 is sending data using LEACH
# Node 44 is sending data using LEACH
# Node 45 is sending data using LEACH
# Node 46 is sending data using LEACH
# Node 47 is sending data using LEACH
# Node 48 is sending data using LEACH
# Node 49 is sending data using LEACH
# Node 50 is sending data using LEACH
# Node 51 is sending data using LEACH
# Node 52 is sending data using LEACH
# Node 53 is sending data using LEACH
# Node 54 is sending data using LEACH
# Node 55 is sending data using LEACH
# Node 56 is sending data using LEACH
# Node 57 is sending data using LEACH
# Node 58 is sending data using LEACH
# Node 59 is sending data using LEACH
# Node 60 is sending data using LEACH
# Node 61 is sending data using LEACH
# Node 62 is sending data using LEACH
# Node 63 is sending data using LEACH
# Node 64 is sending data using LEACH
# Node 65 is sending data using LEACH
# Node 66 is sending data using LEACH
# Node 67 is sending data using LEACH
# Node 68 is sending data using LEACH
# Node 69 is sending data using LEACH
# Node 70 is sending data using LEACH
# Node 1 is sending data using LEACH
# Node 2 is sending data using LEACH
# Node 3 is sending data using LEACH
# Node 4 is sending data using LEACH
# Node 5 is sending data using LEACH
# Node 6 is sending data using LEACH
# Node 7 is sending data using LEACH
# Node 8 is sending data using LEACH
# Node 9 is sending data using LEACH
# Node 10 is sending data using LEACH
# Node 11 is sending data using LEACH
# Node 12 is sending data using LEACH
# Node 13 is sending data using LEACH
# Node 14 is sending data using LEACH
# Node 15 is sending data using LEACH
# Node 16 is sending data using LEACH
# Node 17 is sending data using LEACH
# Node 18 is sending data using LEACH
# Node 19 is sending data using LEACH
# Node 20 is sending data using LEACH
# Node 21 is sending data using LEACH
# Node 22 is sending data using LEACH
# Node 23 is sending data using LEACH
# Node 24 is sending data using LEACH
# Node 25 is sending data using LEACH
# Node 26 is sending data using LEACH
# Node 27 is sending data using LEACH
# Node 28 is sending data using LEACH
# Node 29 is sending data using LEACH
# Node 30 is sending data using LEACH
# Node 31 is sending data using LEACH
# Node 32 is sending data using LEACH
# Node 33 is sending data using LEACH
# Node 34 is sending data using LEACH
# Node 35 is sending data using LEACH
# Node 36 is sending data using LEACH
# Node 37 is sending data using LEACH
# Node 38 is sending data using LEACH
# Node 39 is sending data using LEACH
# Node 40 is sending data using LEACH
# Node 41 is sending data using LEACH
# Node 42 is sending data using LEACH
# Node 43 is sending data using LEACH
# Node 44 is sending data using LEACH
# Node 45 is sending data using LEACH
# Node 46 is sending data using LEACH
# Node 47 is sending data using LEACH
# Node 48 is sending data using LEACH
# Node 49 is sending data using LEACH
# Node 50 is sending data using LEACH
# Node 51 is sending data using LEACH
# Node 52 is sending data using LEACH
# Node 53 is sending data using LEACH
# Node 54 is sending data using LEACH
# Node 55 is sending data using LEACH
# Node 56 is sending data using LEACH
# Node 57 is sending data using LEACH
# Node 58 is sending data using LEACH
# Node 59 is sending data using LEACH
# Node 60 is sending data using LEACH
# Node 61 is sending data using LEACH
# Node 62 is sending data using LEACH
# Node 63 is sending data using LEACH
# Node 64 is sending data using LEACH
# Node 65 is sending data using LEACH
# Node 66 is sending data using LEACH
# Node 67 is sending data using LEACH
# Node 68 is sending data using LEACH
# Node 69 is sending data using LEACH
# Node 70 is sending data using LEACH
# Node 71 is sending data using LEACH
# Node 72 is sending data using LEACH
# Node 73 is sending data using LEACH
# Node 74 is sending data using LEACH
# Node 75 is sending data using LEACH
# Node 76 is sending data using LEACH
# Node 77 is sending data using LEACH
# Node 78 is sending data using LEACH
# Node 79 is sending data using LEACH
# Node 80 is sending data using LEACH
# Node 1 is sending data using LEACH
# Node 2 is sending data using LEACH
# Node 3 is sending data using LEACH
# Node 4 is sending data using LEACH
# Node 5 is sending data using LEACH
# Node 6 is sending data using LEACH
# Node 7 is sending data using LEACH
# Node 8 is sending data using LEACH
# Node 9 is sending data using LEACH
# Node 10 is sending data using LEACH
# Node 11 is sending data using LEACH
# Node 12 is sending data using LEACH
# Node 13 is sending data using LEACH
# Node 14 is sending data using LEACH
# Node 15 is sending data using LEACH
# Node 16 is sending data using LEACH
# Node 17 is sending data using LEACH
# Node 18 is sending data using LEACH
# Node 19 is sending data using LEACH
# Node 20 is sending data using LEACH
# Node 21 is sending data using LEACH
# Node 22 is sending data using LEACH
# Node 23 is sending data using LEACH
# Node 24 is sending data using LEACH
# Node 25 is sending data using LEACH
# Node 26 is sending data using LEACH
# Node 27 is sending data using LEACH
# Node 28 is sending data using LEACH
# Node 29 is sending data using LEACH
# Node 30 is sending data using LEACH
# Node 31 is sending data using LEACH
# Node 32 is sending data using LEACH
# Node 33 is sending data using LEACH
# Node 34 is sending data using LEACH
# Node 35 is sending data using LEACH
# Node 36 is sending data using LEACH
# Node 37 is sending data using LEACH
# Node 38 is sending data using LEACH
# Node 39 is sending data using LEACH
# Node 40 is sending data using LEACH
# Node 41 is sending data using LEACH
# Node 42 is sending data using LEACH
# Node 43 is sending data using LEACH
# Node 44 is sending data using LEACH
# Node 45 is sending data using LEACH
# Node 46 is sending data using LEACH
# Node 47 is sending data using LEACH
# Node 48 is sending data using LEACH
# Node 49 is sending data using LEACH
# Node 50 is sending data using LEACH
# Node 51 is sending data using LEACH
# Node 52 is sending data using LEACH
# Node 53 is sending data using LEACH
# Node 54 is sending data using LEACH
# Node 55 is sending data using LEACH
# Node 56 is sending data using LEACH
# Node 57 is sending data using LEACH
# Node 58 is sending data using LEACH
# Node 59 is sending data using LEACH
# Node 60 is sending data using LEACH
# Node 61 is sending data using LEACH
# Node 62 is sending data using LEACH
# Node 63 is sending data using LEACH
# Node 64 is sending data using LEACH
# Node 65 is sending data using LEACH
# Node 66 is sending data using LEACH
# Node 67 is sending data using LEACH
# Node 68 is sending data using LEACH
# Node 69 is sending data using LEACH
# Node 70 is sending data using LEACH
# Node 71 is sending data using LEACH
# Node 72 is sending data using LEACH
# Node 73 is sending data using LEACH
# Node 74 is sending data using LEACH
# Node 75 is sending data using LEACH
# Node 76 is sending data using LEACH
# Node 77 is sending data using LEACH
# Node 78 is sending data using LEACH
# Node 79 is sending data using LEACH
# Node 80 is sending data using LEACH
# Node 81 is sending data using LEACH
# Node 82 is sending data using LEACH
# Node 83 is sending data using LEACH
# Node 84 is sending data using LEACH
# Node 85 is sending data using LEACH
# Node 86 is sending data using LEACH
# Node 87 is sending data using LEACH
# Node 88 is sending data using LEACH
# Node 89 is sending data using LEACH
# Node 90 is sending data using LEACH
# Node 1 is sending data using LEACH
# Node 2 is sending data using LEACH
# Node 3 is sending data using LEACH
# Node 4 is sending data using LEACH
# Node 5 is sending data using LEACH
# Node 6 is sending data using LEACH
# Node 7 is sending data using LEACH
# Node 8 is sending data using LEACH
# Node 9 is sending data using LEACH
# Node 10 is sending data using LEACH
# Node 11 is sending data using LEACH
# Node 12 is sending data using LEACH
# Node 13 is sending data using LEACH
# Node 14 is sending data using LEACH
# Node 15 is sending data using LEACH
# Node 16 is sending data using LEACH
# Node 17 is sending data using LEACH
# Node 18 is sending data using LEACH
# Node 19 is sending data using LEACH
# Node 20 is sending data using LEACH
# Node 21 is sending data using LEACH
# Node 22 is sending data using LEACH
# Node 23 is sending data using LEACH
# Node 24 is sending data using LEACH
# Node 25 is sending data using LEACH
# Node 26 is sending data using LEACH
# Node 27 is sending data using LEACH
# Node 28 is sending data using LEACH
# Node 29 is sending data using LEACH
# Node 30 is sending data using LEACH
# Node 31 is sending data using LEACH
# Node 32 is sending data using LEACH
# Node 33 is sending data using LEACH
# Node 34 is sending data using LEACH
# Node 35 is sending data using LEACH
# Node 36 is sending data using LEACH
# Node 37 is sending data using LEACH
# Node 38 is sending data using LEACH
# Node 39 is sending data using LEACH
# Node 40 is sending data using LEACH
# Node 41 is sending data using LEACH
# Node 42 is sending data using LEACH
# Node 43 is sending data using LEACH
# Node 44 is sending data using LEACH
# Node 45 is sending data using LEACH
# Node 46 is sending data using LEACH
# Node 47 is sending data using LEACH
# Node 48 is sending data using LEACH
# Node 49 is sending data using LEACH
# Node 50 is sending data using LEACH
# Node 51 is sending data using LEACH
# Node 52 is sending data using LEACH
# Node 53 is sending data using LEACH
# Node 54 is sending data using LEACH
# Node 55 is sending data using LEACH
# Node 56 is sending data using LEACH
# Node 57 is sending data using LEACH
# Node 58 is sending data using LEACH
# Node 59 is sending data using LEACH
# Node 60 is sending data using LEACH
# Node 61 is sending data using LEACH
# Node 62 is sending data using LEACH
# Node 63 is sending data using LEACH
# Node 64 is sending data using LEACH
# Node 65 is sending data using LEACH
# Node 66 is sending data using LEACH
# Node 67 is sending data using LEACH
# Node 68 is sending data using LEACH
# Node 69 is sending data using LEACH
# Node 70 is sending data using LEACH
# Node 71 is sending data using LEACH
# Node 72 is sending data using LEACH
# Node 73 is sending data using LEACH
# Node 74 is sending data using LEACH
# Node 75 is sending data using LEACH
# Node 76 is sending data using LEACH
# Node 77 is sending data using LEACH
# Node 78 is sending data using LEACH
# Node 79 is sending data using LEACH
# Node 80 is sending data using LEACH
# Node 81 is sending data using LEACH
# Node 82 is sending data using LEACH
# Node 83 is sending data using LEACH
# Node 84 is sending data using LEACH
# Node 85 is sending data using LEACH
# Node 86 is sending data using LEACH
# Node 87 is sending data using LEACH
# Node 88 is sending data using LEACH
# Node 89 is sending data using LEACH
# Node 90 is sending data using LEACH
# Node 91 is sending data using LEACH
# Node 92 is sending data using LEACH
# Node 93 is sending data using LEACH
# Node 94 is sending data using LEACH
# Node 95 is sending data using LEACH
# Node 96 is sending data using LEACH
# Node 97 is sending data using LEACH
# Node 98 is sending data using LEACH
# Node 99 is sending data using LEACH
# Node 100 is sending data using LEACH

# %%
import random
import matplotlib.pyplot as plt

# Constants for protocols
PROTOCOL_CAMELLIA = "Camellia"
PROTOCOL_LWM2M = "LwM2M"

# Function to simulate Camellia-specific data transmission
def send_data_camellia(node_id):
    print(f"Node {node_id} is sending data using {PROTOCOL_CAMELLIA}")
    # Simulate energy consumption for Camellia (replace with actual energy calculation)
    energy_consumption_camellia[node_id - 1] += random.uniform(1.0, 3.0)

# Function to simulate LwM2M-specific data transmission
def send_data_lwm2m(node_id):
    print(f"Node {node_id} is sending data using {PROTOCOL_LWM2M}")
    # Simulate energy consumption for LwM2M (replace with actual energy calculation)
    energy_consumption_lwm2m[node_id - 1] += random.uniform(0.5, 2.0)

# Simulated WSN parameters
num_nodes = 10  # Initial number of nodes
max_nodes = 100  # Maximum number of nodes for the simulation

# Lists to store energy consumption data for Camellia and LwM2M
energy_consumption_camellia = [0] * max_nodes
energy_consumption_lwm2m = [0] * max_nodes

# Lists to store the number of nodes and energy consumption for each protocol
num_nodes_list = []
energy_consumption_camellia_list = []
energy_consumption_lwm2m_list = []

# Main simulation loop
while num_nodes <= max_nodes:
    for node_id in range(1, num_nodes + 1):
        # Generate random data for the node
        sensor_data = random.randint(0, 100)

        # Determine which protocol to use based on the number of nodes
        if num_nodes <= 50:
            send_data_camellia(node_id)
        else:
            send_data_lwm2m(node_id)

    # Calculate total energy consumption for each protocol
    total_energy_consumed_camellia = sum(energy_consumption_camellia[:num_nodes])
    total_energy_consumed_lwm2m = sum(energy_consumption_lwm2m[:num_nodes])

    # Store data for plotting
    num_nodes_list.append(num_nodes)
    energy_consumption_camellia_list.append(total_energy_consumed_camellia)
    energy_consumption_lwm2m_list.append(total_energy_consumed_lwm2m)

    # Increase the number of nodes (you can adjust this as needed)
    num_nodes += 10

# Plot energy consumption vs. number of nodes for Camellia and LwM2M
plt.figure(figsize=(10, 6))

# Plot for Camellia
plt.plot(num_nodes_list, energy_consumption_camellia_list, marker='o', linestyle='-', label=PROTOCOL_CAMELLIA, color='b')
plt.xlabel('Number of Nodes')
plt.ylabel(f'Energy Consumption ({PROTOCOL_CAMELLIA})')
plt.grid(True)
plt.legend(loc='upper left')

# Plot for LwM2M
plt.plot(num_nodes_list, energy_consumption_lwm2m_list, marker='s', linestyle='-', label=PROTOCOL_LWM2M, color='r')
plt.ylabel(f'Energy Consumption ({PROTOCOL_LWM2M})')
plt.legend(loc='upper right')

plt.title('Energy Consumption vs. Number of Nodes')

# Show the combined plot
plt.show()
# Out:
# Node 1 is sending data using Camellia
# Node 2 is sending data using Camellia
# Node 3 is sending data using Camellia
# Node 4 is sending data using Camellia
# Node 5 is sending data using Camellia
# Node 6 is sending data using Camellia
# Node 7 is sending data using Camellia
# Node 8 is sending data using Camellia
# Node 9 is sending data using Camellia
# Node 10 is sending data using Camellia
# Node 1 is sending data using Camellia
# Node 2 is sending data using Camellia
# Node 3 is sending data using Camellia
# Node 4 is sending data using Camellia
# Node 5 is sending data using Camellia
# Node 6 is sending data using Camellia
# Node 7 is sending data using Camellia
# Node 8 is sending data using Camellia
# Node 9 is sending data using Camellia
# Node 10 is sending data using Camellia
# Node 11 is sending data using Camellia
# Node 12 is sending data using Camellia
# Node 13 is sending data using Camellia
# Node 14 is sending data using Camellia
# Node 15 is sending data using Camellia
# Node 16 is sending data using Camellia
# Node 17 is sending data using Camellia
# Node 18 is sending data using Camellia
# Node 19 is sending data using Camellia
# Node 20 is sending data using Camellia
# Node 1 is sending data using Camellia
# Node 2 is sending data using Camellia
# Node 3 is sending data using Camellia
# Node 4 is sending data using Camellia
# Node 5 is sending data using Camellia
# Node 6 is sending data using Camellia
# Node 7 is sending data using Camellia
# Node 8 is sending data using Camellia
# Node 9 is sending data using Camellia
# Node 10 is sending data using Camellia
# Node 11 is sending data using Camellia
# Node 12 is sending data using Camellia
# Node 13 is sending data using Camellia
# Node 14 is sending data using Camellia
# Node 15 is sending data using Camellia
# Node 16 is sending data using Camellia
# Node 17 is sending data using Camellia
# Node 18 is sending data using Camellia
# Node 19 is sending data using Camellia
# Node 20 is sending data using Camellia
# Node 21 is sending data using Camellia
# Node 22 is sending data using Camellia
# Node 23 is sending data using Camellia
# Node 24 is sending data using Camellia
# Node 25 is sending data using Camellia
# Node 26 is sending data using Camellia
# Node 27 is sending data using Camellia
# Node 28 is sending data using Camellia
# Node 29 is sending data using Camellia
# Node 30 is sending data using Camellia
# Node 1 is sending data using Camellia
# Node 2 is sending data using Camellia
# Node 3 is sending data using Camellia
# Node 4 is sending data using Camellia
# Node 5 is sending data using Camellia
# Node 6 is sending data using Camellia
# Node 7 is sending data using Camellia
# Node 8 is sending data using Camellia
# Node 9 is sending data using Camellia
# Node 10 is sending data using Camellia
# Node 11 is sending data using Camellia
# Node 12 is sending data using Camellia
# Node 13 is sending data using Camellia
# Node 14 is sending data using Camellia
# Node 15 is sending data using Camellia
# Node 16 is sending data using Camellia
# Node 17 is sending data using Camellia
# Node 18 is sending data using Camellia
# Node 19 is sending data using Camellia
# Node 20 is sending data using Camellia
# Node 21 is sending data using Camellia
# Node 22 is sending data using Camellia
# Node 23 is sending data using Camellia
# Node 24 is sending data using Camellia
# Node 25 is sending data using Camellia
# Node 26 is sending data using Camellia
# Node 27 is sending data using Camellia
# Node 28 is sending data using Camellia
# Node 29 is sending data using Camellia
# Node 30 is sending data using Camellia
# Node 31 is sending data using Camellia
# Node 32 is sending data using Camellia
# Node 33 is sending data using Camellia
# Node 34 is sending data using Camellia
# Node 35 is sending data using Camellia
# Node 36 is sending data using Camellia
# Node 37 is sending data using Camellia
# Node 38 is sending data using Camellia
# Node 39 is sending data using Camellia
# Node 40 is sending data using Camellia
# Node 1 is sending data using Camellia
# Node 2 is sending data using Camellia
# Node 3 is sending data using Camellia
# Node 4 is sending data using Camellia
# Node 5 is sending data using Camellia
# Node 6 is sending data using Camellia
# Node 7 is sending data using Camellia
# Node 8 is sending data using Camellia
# Node 9 is sending data using Camellia
# Node 10 is sending data using Camellia
# Node 11 is sending data using Camellia
# Node 12 is sending data using Camellia
# Node 13 is sending data using Camellia
# Node 14 is sending data using Camellia
# Node 15 is sending data using Camellia
# Node 16 is sending data using Camellia
# Node 17 is sending data using Camellia
# Node 18 is sending data using Camellia
# Node 19 is sending data using Camellia
# Node 20 is sending data using Camellia
# Node 21 is sending data using Camellia
# Node 22 is sending data using Camellia
# Node 23 is sending data using Camellia
# Node 24 is sending data using Camellia
# Node 25 is sending data using Camellia
# Node 26 is sending data using Camellia
# Node 27 is sending data using Camellia
# Node 28 is sending data using Camellia
# Node 29 is sending data using Camellia
# Node 30 is sending data using Camellia
# Node 31 is sending data using Camellia
# Node 32 is sending data using Camellia
# Node 33 is sending data using Camellia
# Node 34 is sending data using Camellia
# Node 35 is sending data using Camellia
# Node 36 is sending data using Camellia
# Node 37 is sending data using Camellia
# Node 38 is sending data using Camellia
# Node 39 is sending data using Camellia
# Node 40 is sending data using Camellia
# Node 41 is sending data using Camellia
# Node 42 is sending data using Camellia
# Node 43 is sending data using Camellia
# Node 44 is sending data using Camellia
# Node 45 is sending data using Camellia
# Node 46 is sending data using Camellia
# Node 47 is sending data using Camellia
# Node 48 is sending data using Camellia
# Node 49 is sending data using Camellia
# Node 50 is sending data using Camellia
# Node 1 is sending data using LwM2M
# Node 2 is sending data using LwM2M
# Node 3 is sending data using LwM2M
# Node 4 is sending data using LwM2M
# Node 5 is sending data using LwM2M
# Node 6 is sending data using LwM2M
# Node 7 is sending data using LwM2M
# Node 8 is sending data using LwM2M
# Node 9 is sending data using LwM2M
# Node 10 is sending data using LwM2M
# Node 11 is sending data using LwM2M
# Node 12 is sending data using LwM2M
# Node 13 is sending data using LwM2M
# Node 14 is sending data using LwM2M
# Node 15 is sending data using LwM2M
# Node 16 is sending data using LwM2M
# Node 17 is sending data using LwM2M
# Node 18 is sending data using LwM2M
# Node 19 is sending data using LwM2M
# Node 20 is sending data using LwM2M
# Node 21 is sending data using LwM2M
# Node 22 is sending data using LwM2M
# Node 23 is sending data using LwM2M
# Node 24 is sending data using LwM2M
# Node 25 is sending data using LwM2M
# Node 26 is sending data using LwM2M
# Node 27 is sending data using LwM2M
# Node 28 is sending data using LwM2M
# Node 29 is sending data using LwM2M
# Node 30 is sending data using LwM2M
# Node 31 is sending data using LwM2M
# Node 32 is sending data using LwM2M
# Node 33 is sending data using LwM2M
# Node 34 is sending data using LwM2M
# Node 35 is sending data using LwM2M
# Node 36 is sending data using LwM2M
# Node 37 is sending data using LwM2M
# Node 38 is sending data using LwM2M
# Node 39 is sending data using LwM2M
# Node 40 is sending data using LwM2M
# Node 41 is sending data using LwM2M
# Node 42 is sending data using LwM2M
# Node 43 is sending data using LwM2M
# Node 44 is sending data using LwM2M
# Node 45 is sending data using LwM2M
# Node 46 is sending data using LwM2M
# Node 47 is sending data using LwM2M
# Node 48 is sending data using LwM2M
# Node 49 is sending data using LwM2M
# Node 50 is sending data using LwM2M
# Node 51 is sending data using LwM2M
# Node 52 is sending data using LwM2M
# Node 53 is sending data using LwM2M
# Node 54 is sending data using LwM2M
# Node 55 is sending data using LwM2M
# Node 56 is sending data using LwM2M
# Node 57 is sending data using LwM2M
# Node 58 is sending data using LwM2M
# Node 59 is sending data using LwM2M
# Node 60 is sending data using LwM2M
# Node 1 is sending data using LwM2M
# Node 2 is sending data using LwM2M
# Node 3 is sending data using LwM2M
# Node 4 is sending data using LwM2M
# Node 5 is sending data using LwM2M
# Node 6 is sending data using LwM2M
# Node 7 is sending data using LwM2M
# Node 8 is sending data using LwM2M
# Node 9 is sending data using LwM2M
# Node 10 is sending data using LwM2M
# Node 11 is sending data using LwM2M
# Node 12 is sending data using LwM2M
# Node 13 is sending data using LwM2M
# Node 14 is sending data using LwM2M
# Node 15 is sending data using LwM2M
# Node 16 is sending data using LwM2M
# Node 17 is sending data using LwM2M
# Node 18 is sending data using LwM2M
# Node 19 is sending data using LwM2M
# Node 20 is sending data using LwM2M
# Node 21 is sending data using LwM2M
# Node 22 is sending data using LwM2M
# Node 23 is sending data using LwM2M
# Node 24 is sending data using LwM2M
# Node 25 is sending data using LwM2M
# Node 26 is sending data using LwM2M
# Node 27 is sending data using LwM2M
# Node 28 is sending data using LwM2M
# Node 29 is sending data using LwM2M
# Node 30 is sending data using LwM2M
# Node 31 is sending data using LwM2M
# Node 32 is sending data using LwM2M
# Node 33 is sending data using LwM2M
# Node 34 is sending data using LwM2M
# Node 35 is sending data using LwM2M
# Node 36 is sending data using LwM2M
# Node 37 is sending data using LwM2M
# Node 38 is sending data using LwM2M
# Node 39 is sending data using LwM2M
# Node 40 is sending data using LwM2M
# Node 41 is sending data using LwM2M
# Node 42 is sending data using LwM2M
# Node 43 is sending data using LwM2M
# Node 44 is sending data using LwM2M
# Node 45 is sending data using LwM2M
# Node 46 is sending data using LwM2M
# Node 47 is sending data using LwM2M
# Node 48 is sending data using LwM2M
# Node 49 is sending data using LwM2M
# Node 50 is sending data using LwM2M
# Node 51 is sending data using LwM2M
# Node 52 is sending data using LwM2M
# Node 53 is sending data using LwM2M
# Node 54 is sending data using LwM2M
# Node 55 is sending data using LwM2M
# Node 56 is sending data using LwM2M
# Node 57 is sending data using LwM2M
# Node 58 is sending data using LwM2M
# Node 59 is sending data using LwM2M
# Node 60 is sending data using LwM2M
# Node 61 is sending data using LwM2M
# Node 62 is sending data using LwM2M
# Node 63 is sending data using LwM2M
# Node 64 is sending data using LwM2M
# Node 65 is sending data using LwM2M
# Node 66 is sending data using LwM2M
# Node 67 is sending data using LwM2M
# Node 68 is sending data using LwM2M
# Node 69 is sending data using LwM2M
# Node 70 is sending data using LwM2M
# Node 1 is sending data using LwM2M
# Node 2 is sending data using LwM2M
# Node 3 is sending data using LwM2M
# Node 4 is sending data using LwM2M
# Node 5 is sending data using LwM2M
# Node 6 is sending data using LwM2M
# Node 7 is sending data using LwM2M
# Node 8 is sending data using LwM2M
# Node 9 is sending data using LwM2M
# Node 10 is sending data using LwM2M
# Node 11 is sending data using LwM2M
# Node 12 is sending data using LwM2M
# Node 13 is sending data using LwM2M
# Node 14 is sending data using LwM2M
# Node 15 is sending data using LwM2M
# Node 16 is sending data using LwM2M
# Node 17 is sending data using LwM2M
# Node 18 is sending data using LwM2M
# Node 19 is sending data using LwM2M
# Node 20 is sending data using LwM2M
# Node 21 is sending data using LwM2M
# Node 22 is sending data using LwM2M
# Node 23 is sending data using LwM2M
# Node 24 is sending data using LwM2M
# Node 25 is sending data using LwM2M
# Node 26 is sending data using LwM2M
# Node 27 is sending data using LwM2M
# Node 28 is sending data using LwM2M
# Node 29 is sending data using LwM2M
# Node 30 is sending data using LwM2M
# Node 31 is sending data using LwM2M
# Node 32 is sending data using LwM2M
# Node 33 is sending data using LwM2M
# Node 34 is sending data using LwM2M
# Node 35 is sending data using LwM2M
# Node 36 is sending data using LwM2M
# Node 37 is sending data using LwM2M
# Node 38 is sending data using LwM2M
# Node 39 is sending data using LwM2M
# Node 40 is sending data using LwM2M
# Node 41 is sending data using LwM2M
# Node 42 is sending data using LwM2M
# Node 43 is sending data using LwM2M
# Node 44 is sending data using LwM2M
# Node 45 is sending data using LwM2M
# Node 46 is sending data using LwM2M
# Node 47 is sending data using LwM2M
# Node 48 is sending data using LwM2M
# Node 49 is sending data using LwM2M
# Node 50 is sending data using LwM2M
# Node 51 is sending data using LwM2M
# Node 52 is sending data using LwM2M
# Node 53 is sending data using LwM2M
# Node 54 is sending data using LwM2M
# Node 55 is sending data using LwM2M
# Node 56 is sending data using LwM2M
# Node 57 is sending data using LwM2M
# Node 58 is sending data using LwM2M
# Node 59 is sending data using LwM2M
# Node 60 is sending data using LwM2M
# Node 61 is sending data using LwM2M
# Node 62 is sending data using LwM2M
# Node 63 is sending data using LwM2M
# Node 64 is sending data using LwM2M
# Node 65 is sending data using LwM2M
# Node 66 is sending data using LwM2M
# Node 67 is sending data using LwM2M
# Node 68 is sending data using LwM2M
# Node 69 is sending data using LwM2M
# Node 70 is sending data using LwM2M
# Node 71 is sending data using LwM2M
# Node 72 is sending data using LwM2M
# Node 73 is sending data using LwM2M
# Node 74 is sending data using LwM2M
# Node 75 is sending data using LwM2M
# Node 76 is sending data using LwM2M
# Node 77 is sending data using LwM2M
# Node 78 is sending data using LwM2M
# Node 79 is sending data using LwM2M
# Node 80 is sending data using LwM2M
# Node 1 is sending data using LwM2M
# Node 2 is sending data using LwM2M
# Node 3 is sending data using LwM2M
# Node 4 is sending data using LwM2M
# Node 5 is sending data using LwM2M
# Node 6 is sending data using LwM2M
# Node 7 is sending data using LwM2M
# Node 8 is sending data using LwM2M
# Node 9 is sending data using LwM2M
# Node 10 is sending data using LwM2M
# Node 11 is sending data using LwM2M
# Node 12 is sending data using LwM2M
# Node 13 is sending data using LwM2M
# Node 14 is sending data using LwM2M
# Node 15 is sending data using LwM2M
# Node 16 is sending data using LwM2M
# Node 17 is sending data using LwM2M
# Node 18 is sending data using LwM2M
# Node 19 is sending data using LwM2M
# Node 20 is sending data using LwM2M
# Node 21 is sending data using LwM2M
# Node 22 is sending data using LwM2M
# Node 23 is sending data using LwM2M
# Node 24 is sending data using LwM2M
# Node 25 is sending data using LwM2M
# Node 26 is sending data using LwM2M
# Node 27 is sending data using LwM2M
# Node 28 is sending data using LwM2M
# Node 29 is sending data using LwM2M
# Node 30 is sending data using LwM2M
# Node 31 is sending data using LwM2M
# Node 32 is sending data using LwM2M
# Node 33 is sending data using LwM2M
# Node 34 is sending data using LwM2M
# Node 35 is sending data using LwM2M
# Node 36 is sending data using LwM2M
# Node 37 is sending data using LwM2M
# Node 38 is sending data using LwM2M
# Node 39 is sending data using LwM2M
# Node 40 is sending data using LwM2M
# Node 41 is sending data using LwM2M
# Node 42 is sending data using LwM2M
# Node 43 is sending data using LwM2M
# Node 44 is sending data using LwM2M
# Node 45 is sending data using LwM2M
# Node 46 is sending data using LwM2M
# Node 47 is sending data using LwM2M
# Node 48 is sending data using LwM2M
# Node 49 is sending data using LwM2M
# Node 50 is sending data using LwM2M
# Node 51 is sending data using LwM2M
# Node 52 is sending data using LwM2M
# Node 53 is sending data using LwM2M
# Node 54 is sending data using LwM2M
# Node 55 is sending data using LwM2M
# Node 56 is sending data using LwM2M
# Node 57 is sending data using LwM2M
# Node 58 is sending data using LwM2M
# Node 59 is sending data using LwM2M
# Node 60 is sending data using LwM2M
# Node 61 is sending data using LwM2M
# Node 62 is sending data using LwM2M
# Node 63 is sending data using LwM2M
# Node 64 is sending data using LwM2M
# Node 65 is sending data using LwM2M
# Node 66 is sending data using LwM2M
# Node 67 is sending data using LwM2M
# Node 68 is sending data using LwM2M
# Node 69 is sending data using LwM2M
# Node 70 is sending data using LwM2M
# Node 71 is sending data using LwM2M
# Node 72 is sending data using LwM2M
# Node 73 is sending data using LwM2M
# Node 74 is sending data using LwM2M
# Node 75 is sending data using LwM2M
# Node 76 is sending data using LwM2M
# Node 77 is sending data using LwM2M
# Node 78 is sending data using LwM2M
# Node 79 is sending data using LwM2M
# Node 80 is sending data using LwM2M
# Node 81 is sending data using LwM2M
# Node 82 is sending data using LwM2M
# Node 83 is sending data using LwM2M
# Node 84 is sending data using LwM2M
# Node 85 is sending data using LwM2M
# Node 86 is sending data using LwM2M
# Node 87 is sending data using LwM2M
# Node 88 is sending data using LwM2M
# Node 89 is sending data using LwM2M
# Node 90 is sending data using LwM2M
# Node 1 is sending data using LwM2M
# Node 2 is sending data using LwM2M
# Node 3 is sending data using LwM2M
# Node 4 is sending data using LwM2M
# Node 5 is sending data using LwM2M
# Node 6 is sending data using LwM2M
# Node 7 is sending data using LwM2M
# Node 8 is sending data using LwM2M
# Node 9 is sending data using LwM2M
# Node 10 is sending data using LwM2M
# Node 11 is sending data using LwM2M
# Node 12 is sending data using LwM2M
# Node 13 is sending data using LwM2M
# Node 14 is sending data using LwM2M
# Node 15 is sending data using LwM2M
# Node 16 is sending data using LwM2M
# Node 17 is sending data using LwM2M
# Node 18 is sending data using LwM2M
# Node 19 is sending data using LwM2M
# Node 20 is sending data using LwM2M
# Node 21 is sending data using LwM2M
# Node 22 is sending data using LwM2M
# Node 23 is sending data using LwM2M
# Node 24 is sending data using LwM2M
# Node 25 is sending data using LwM2M
# Node 26 is sending data using LwM2M
# Node 27 is sending data using LwM2M
# Node 28 is sending data using LwM2M
# Node 29 is sending data using LwM2M
# Node 30 is sending data using LwM2M
# Node 31 is sending data using LwM2M
# Node 32 is sending data using LwM2M
# Node 33 is sending data using LwM2M
# Node 34 is sending data using LwM2M
# Node 35 is sending data using LwM2M
# Node 36 is sending data using LwM2M
# Node 37 is sending data using LwM2M
# Node 38 is sending data using LwM2M
# Node 39 is sending data using LwM2M
# Node 40 is sending data using LwM2M
# Node 41 is sending data using LwM2M
# Node 42 is sending data using LwM2M
# Node 43 is sending data using LwM2M
# Node 44 is sending data using LwM2M
# Node 45 is sending data using LwM2M
# Node 46 is sending data using LwM2M
# Node 47 is sending data using LwM2M
# Node 48 is sending data using LwM2M
# Node 49 is sending data using LwM2M
# Node 50 is sending data using LwM2M
# Node 51 is sending data using LwM2M
# Node 52 is sending data using LwM2M
# Node 53 is sending data using LwM2M
# Node 54 is sending data using LwM2M
# Node 55 is sending data using LwM2M
# Node 56 is sending data using LwM2M
# Node 57 is sending data using LwM2M
# Node 58 is sending data using LwM2M
# Node 59 is sending data using LwM2M
# Node 60 is sending data using LwM2M
# Node 61 is sending data using LwM2M
# Node 62 is sending data using LwM2M
# Node 63 is sending data using LwM2M
# Node 64 is sending data using LwM2M
# Node 65 is sending data using LwM2M
# Node 66 is sending data using LwM2M
# Node 67 is sending data using LwM2M
# Node 68 is sending data using LwM2M
# Node 69 is sending data using LwM2M
# Node 70 is sending data using LwM2M
# Node 71 is sending data using LwM2M
# Node 72 is sending data using LwM2M
# Node 73 is sending data using LwM2M
# Node 74 is sending data using LwM2M
# Node 75 is sending data using LwM2M
# Node 76 is sending data using LwM2M
# Node 77 is sending data using LwM2M
# Node 78 is sending data using LwM2M
# Node 79 is sending data using LwM2M
# Node 80 is sending data using LwM2M
# Node 81 is sending data using LwM2M
# Node 82 is sending data using LwM2M
# Node 83 is sending data using LwM2M
# Node 84 is sending data using LwM2M
# Node 85 is sending data using LwM2M
# Node 86 is sending data using LwM2M
# Node 87 is sending data using LwM2M
# Node 88 is sending data using LwM2M
# Node 89 is sending data using LwM2M
# Node 90 is sending data using LwM2M
# Node 91 is sending data using LwM2M
# Node 92 is sending data using LwM2M
# Node 93 is sending data using LwM2M
# Node 94 is sending data using LwM2M
# Node 95 is sending data using LwM2M
# Node 96 is sending data using LwM2M
# Node 97 is sending data using LwM2M
# Node 98 is sending data using LwM2M
# Node 99 is sending data using LwM2M
# Node 100 is sending data using LwM2M

# %%
import random
import matplotlib.pyplot as plt

# Constants for protocols
PROTOCOL_CAMELLIA = "Camellia"
PROTOCOL_LWM2M = "LwM2M"

# Function to simulate Camellia-specific data transmission
def send_data_camellia(node_id):
    print(f"Node {node_id} is sending data using {PROTOCOL_CAMELLIA}")
    # Simulate energy consumption for Camellia (replace with actual energy calculation)
    energy_consumption_camellia[node_id - 1] += random.uniform(1.0, 3.0)

# Function to simulate LwM2M-specific data transmission
def send_data_lwm2m(node_id):
    print(f"Node {node_id} is sending data using {PROTOCOL_LWM2M}")
    # Simulate energy consumption for LwM2M (replace with actual energy calculation)
    energy_consumption_lwm2m[node_id - 1] += random.uniform(0.5, 2.0)

# Simulated WSN parameters
num_nodes = 10  # Initial number of nodes
max_nodes = 100  # Maximum number of nodes for the simulation

# Lists to store energy consumption data for Camellia and LwM2M
energy_consumption_camellia = [0] * max_nodes
energy_consumption_lwm2m = [0] * max_nodes

# Lists to store the number of nodes and energy efficiency for each protocol
num_nodes_list = []
energy_efficiency_camellia_list = []
energy_efficiency_lwm2m_list = []

# Main simulation loop
while num_nodes <= max_nodes:
    for node_id in range(1, num_nodes + 1):
        # Generate random data for the node
        sensor_data = random.randint(0, 100)

        # Determine which protocol to use based on the number of nodes
        if num_nodes <= 50:
            send_data_camellia(node_id)
        else:
            send_data_lwm2m(node_id)

    # Calculate energy efficiency (total data sent per unit energy) for each protocol
    total_data_sent = num_nodes * 100  # Assuming each node sends 100 units of data
    total_energy_consumed_camellia = sum(energy_consumption_camellia[:num_nodes])
    total_energy_consumed_lwm2m = sum(energy_consumption_lwm2m[:num_nodes])

    energy_efficiency_camellia = total_data_sent / total_energy_consumed_camellia
    energy_efficiency_lwm2m = total_data_sent / total_energy_consumed_lwm2m

    # Store data for plotting
    num_nodes_list.append(num_nodes)
    energy_efficiency_camellia_list.append(energy_efficiency_camellia)
    energy_efficiency_lwm2m_list.append(energy_efficiency_lwm2m)

    # Increase the number of nodes (you can adjust this as needed)
    num_nodes += 10

# Plot energy efficiency vs. number of nodes for Camellia and LwM2M
plt.figure(figsize=(10, 6))

# Plot for Camellia
plt.plot(num_nodes_list, energy_efficiency_camellia_list, marker='o', linestyle='-', label=PROTOCOL_CAMELLIA, color='b')
plt.xlabel('Number of Nodes')
plt.ylabel(f'Energy Efficiency ({PROTOCOL_CAMELLIA})')
plt.grid(True)
plt.legend(loc='upper left')

# Plot for LwM2M
plt.plot(num_nodes_list, energy_efficiency_lwm2m_list, marker='s', linestyle='-', label=PROTOCOL_LWM2M, color='r')
plt.ylabel(f'Energy Efficiency ({PROTOCOL_LWM2M})')
plt.legend(loc='upper right')

plt.title('Energy Efficiency vs. Number of Nodes')

# Show the combined plot
plt.show()
# Out:
# Node 1 is sending data using Camellia
# Node 2 is sending data using Camellia
# Node 3 is sending data using Camellia
# Node 4 is sending data using Camellia
# Node 5 is sending data using Camellia
# Node 6 is sending data using Camellia
# Node 7 is sending data using Camellia
# Node 8 is sending data using Camellia
# Node 9 is sending data using Camellia
# Node 10 is sending data using Camellia
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_2612\2375119672.py in <module>
#      49
#      50     energy_efficiency_camellia = total_data_sent / total_energy_consumed_camellia
# ---> 51     energy_efficiency_lwm2m = total_data_sent / total_energy_consumed_lwm2m
#      52
#      53     # Store data for plotting
#
# ZeroDivisionError: division by zero

# %%
import random
import matplotlib.pyplot as plt

# Constants for protocols
PROTOCOL_CAMELLIA = "Camellia"
PROTOCOL_LWM2M = "LwM2M"

# Function to simulate Camellia-specific data transmission
def send_data_camellia(node_id):
    print(f"Node {node_id} is sending data using {PROTOCOL_CAMELLIA}")
    # Simulate energy consumption for Camellia (replace with actual energy calculation)
    energy_consumption_camellia[node_id - 1] += random.uniform(1.0, 3.0)

# Function to simulate LwM2M-specific data transmission
def send_data_lwm2m(node_id):
    print(f"Node {node_id} is sending data using {PROTOCOL_LWM2M}")
    # Simulate energy consumption for LwM2M (replace with actual energy calculation)
    energy_consumption_lwm2m[node_id - 1] += random.uniform(0.5, 2.0)

# Simulated WSN parameters
num_nodes = 10  # Initial number of nodes
max_nodes = 100  # Maximum number of nodes for the simulation

# Lists to store energy consumption data for Camellia and LwM2M
energy_consumption_camellia = [0] * max_nodes
energy_consumption_lwm2m = [0] * max_nodes

# Lists to store the number of nodes and energy consumption for each protocol
num_nodes_list = []
energy_consumption_camellia_list = []
energy_consumption_lwm2m_list = []

# Main simulation loop
while num_nodes <= max_nodes:
    for node_id in range(1, num_nodes + 1):
        # Generate random data for the node
        sensor_data = random.randint(0, 100)

        # Determine which protocol to use based on the number of nodes
        send_data_camellia(node_id)
        send_data_lwm2m(node_id)

    # Calculate total energy consumption for each protocol
    total_energy_consumed_camellia = sum(energy_consumption_camellia[:num_nodes])
    total_energy_consumed_lwm2m = sum(energy_consumption_lwm2m[:num_nodes])

    # Store data for plotting
    num_nodes_list.append(num_nodes)
    energy_consumption_camellia_list.append(total_energy_consumed_camellia)
    energy_consumption_lwm2m_list.append(total_energy_consumed_lwm2m)

    # Increase the number of nodes (you can adjust this as needed)
    num_nodes += 10

# Plot energy consumption vs. number of nodes for Camellia and LwM2M
plt.figure(figsize=(10, 6))

# Plot for Camellia
plt.plot(num_nodes_list, energy_consumption_camellia_list, marker='o', linestyle='-', label=PROTOCOL_CAMELLIA, color='b')
plt.xlabel('Number of Nodes')
plt.ylabel(f'Energy Consumption ({PROTOCOL_CAMELLIA})')
plt.grid(True)
plt.legend(loc='upper left')

# Plot for LwM2M
plt.plot(num_nodes_list, energy_consumption_lwm2m_list, marker='s', linestyle='-', label=PROTOCOL_LWM2M, color='r')
plt.ylabel(f'Energy Consumption ({PROTOCOL_LWM2M})')
plt.legend(loc='upper right')

plt.title('Energy Consumption vs. Number of Nodes')

# Show the combined plot
plt.show()
# Out:
# Node 1 is sending data using Camellia
# Node 1 is sending data using LwM2M
# Node 2 is sending data using Camellia
# Node 2 is sending data using LwM2M
# Node 3 is sending data using Camellia
# Node 3 is sending data using LwM2M
# Node 4 is sending data using Camellia
# Node 4 is sending data using LwM2M
# Node 5 is sending data using Camellia
# Node 5 is sending data using LwM2M
# Node 6 is sending data using Camellia
# Node 6 is sending data using LwM2M
# Node 7 is sending data using Camellia
# Node 7 is sending data using LwM2M
# Node 8 is sending data using Camellia
# Node 8 is sending data using LwM2M
# Node 9 is sending data using Camellia
# Node 9 is sending data using LwM2M
# Node 10 is sending data using Camellia
# Node 10 is sending data using LwM2M
# Node 1 is sending data using Camellia
# Node 1 is sending data using LwM2M
# Node 2 is sending data using Camellia
# Node 2 is sending data using LwM2M
# Node 3 is sending data using Camellia
# Node 3 is sending data using LwM2M
# Node 4 is sending data using Camellia
# Node 4 is sending data using LwM2M
# Node 5 is sending data using Camellia
# Node 5 is sending data using LwM2M
# Node 6 is sending data using Camellia
# Node 6 is sending data using LwM2M
# Node 7 is sending data using Camellia
# Node 7 is sending data using LwM2M
# Node 8 is sending data using Camellia
# Node 8 is sending data using LwM2M
# Node 9 is sending data using Camellia
# Node 9 is sending data using LwM2M
# Node 10 is sending data using Camellia
# Node 10 is sending data using LwM2M
# Node 11 is sending data using Camellia
# Node 11 is sending data using LwM2M
# Node 12 is sending data using Camellia
# Node 12 is sending data using LwM2M
# Node 13 is sending data using Camellia
# Node 13 is sending data using LwM2M
# Node 14 is sending data using Camellia
# Node 14 is sending data using LwM2M
# Node 15 is sending data using Camellia
# Node 15 is sending data using LwM2M
# Node 16 is sending data using Camellia
# Node 16 is sending data using LwM2M
# Node 17 is sending data using Camellia
# Node 17 is sending data using LwM2M
# Node 18 is sending data using Camellia
# Node 18 is sending data using LwM2M
# Node 19 is sending data using Camellia
# Node 19 is sending data using LwM2M
# Node 20 is sending data using Camellia
# Node 20 is sending data using LwM2M
# Node 1 is sending data using Camellia
# Node 1 is sending data using LwM2M
# Node 2 is sending data using Camellia
# Node 2 is sending data using LwM2M
# Node 3 is sending data using Camellia
# Node 3 is sending data using LwM2M
# Node 4 is sending data using Camellia
# Node 4 is sending data using LwM2M
# Node 5 is sending data using Camellia
# Node 5 is sending data using LwM2M
# Node 6 is sending data using Camellia
# Node 6 is sending data using LwM2M
# Node 7 is sending data using Camellia
# Node 7 is sending data using LwM2M
# Node 8 is sending data using Camellia
# Node 8 is sending data using LwM2M
# Node 9 is sending data using Camellia
# Node 9 is sending data using LwM2M
# Node 10 is sending data using Camellia
# Node 10 is sending data using LwM2M
# Node 11 is sending data using Camellia
# Node 11 is sending data using LwM2M
# Node 12 is sending data using Camellia
# Node 12 is sending data using LwM2M
# Node 13 is sending data using Camellia
# Node 13 is sending data using LwM2M
# Node 14 is sending data using Camellia
# Node 14 is sending data using LwM2M
# Node 15 is sending data using Camellia
# Node 15 is sending data using LwM2M
# Node 16 is sending data using Camellia
# Node 16 is sending data using LwM2M
# Node 17 is sending data using Camellia
# Node 17 is sending data using LwM2M
# Node 18 is sending data using Camellia
# Node 18 is sending data using LwM2M
# Node 19 is sending data using Camellia
# Node 19 is sending data using LwM2M
# Node 20 is sending data using Camellia
# Node 20 is sending data using LwM2M
# Node 21 is sending data using Camellia
# Node 21 is sending data using LwM2M
# Node 22 is sending data using Camellia
# Node 22 is sending data using LwM2M
# Node 23 is sending data using Camellia
# Node 23 is sending data using LwM2M
# Node 24 is sending data using Camellia
# Node 24 is sending data using LwM2M
# Node 25 is sending data using Camellia
# Node 25 is sending data using LwM2M
# Node 26 is sending data using Camellia
# Node 26 is sending data using LwM2M
# Node 27 is sending data using Camellia
# Node 27 is sending data using LwM2M
# Node 28 is sending data using Camellia
# Node 28 is sending data using LwM2M
# Node 29 is sending data using Camellia
# Node 29 is sending data using LwM2M
# Node 30 is sending data using Camellia
# Node 30 is sending data using LwM2M
# Node 1 is sending data using Camellia
# Node 1 is sending data using LwM2M
# Node 2 is sending data using Camellia
# Node 2 is sending data using LwM2M
# Node 3 is sending data using Camellia
# Node 3 is sending data using LwM2M
# Node 4 is sending data using Camellia
# Node 4 is sending data using LwM2M
# Node 5 is sending data using Camellia
# Node 5 is sending data using LwM2M
# Node 6 is sending data using Camellia
# Node 6 is sending data using LwM2M
# Node 7 is sending data using Camellia
# Node 7 is sending data using LwM2M
# Node 8 is sending data using Camellia
# Node 8 is sending data using LwM2M
# Node 9 is sending data using Camellia
# Node 9 is sending data using LwM2M
# Node 10 is sending data using Camellia
# Node 10 is sending data using LwM2M
# Node 11 is sending data using Camellia
# Node 11 is sending data using LwM2M
# Node 12 is sending data using Camellia
# Node 12 is sending data using LwM2M
# Node 13 is sending data using Camellia
# Node 13 is sending data using LwM2M
# Node 14 is sending data using Camellia
# Node 14 is sending data using LwM2M
# Node 15 is sending data using Camellia
# Node 15 is sending data using LwM2M
# Node 16 is sending data using Camellia
# Node 16 is sending data using LwM2M
# Node 17 is sending data using Camellia
# Node 17 is sending data using LwM2M
# Node 18 is sending data using Camellia
# Node 18 is sending data using LwM2M
# Node 19 is sending data using Camellia
# Node 19 is sending data using LwM2M
# Node 20 is sending data using Camellia
# Node 20 is sending data using LwM2M
# Node 21 is sending data using Camellia
# Node 21 is sending data using LwM2M
# Node 22 is sending data using Camellia
# Node 22 is sending data using LwM2M
# Node 23 is sending data using Camellia
# Node 23 is sending data using LwM2M
# Node 24 is sending data using Camellia
# Node 24 is sending data using LwM2M
# Node 25 is sending data using Camellia
# Node 25 is sending data using LwM2M
# Node 26 is sending data using Camellia
# Node 26 is sending data using LwM2M
# Node 27 is sending data using Camellia
# Node 27 is sending data using LwM2M
# Node 28 is sending data using Camellia
# Node 28 is sending data using LwM2M
# Node 29 is sending data using Camellia
# Node 29 is sending data using LwM2M
# Node 30 is sending data using Camellia
# Node 30 is sending data using LwM2M
# Node 31 is sending data using Camellia
# Node 31 is sending data using LwM2M
# Node 32 is sending data using Camellia
# Node 32 is sending data using LwM2M
# Node 33 is sending data using Camellia
# Node 33 is sending data using LwM2M
# Node 34 is sending data using Camellia
# Node 34 is sending data using LwM2M
# Node 35 is sending data using Camellia
# Node 35 is sending data using LwM2M
# Node 36 is sending data using Camellia
# Node 36 is sending data using LwM2M
# Node 37 is sending data using Camellia
# Node 37 is sending data using LwM2M
# Node 38 is sending data using Camellia
# Node 38 is sending data using LwM2M
# Node 39 is sending data using Camellia
# Node 39 is sending data using LwM2M
# Node 40 is sending data using Camellia
# Node 40 is sending data using LwM2M
# Node 1 is sending data using Camellia
# Node 1 is sending data using LwM2M
# Node 2 is sending data using Camellia
# Node 2 is sending data using LwM2M
# Node 3 is sending data using Camellia
# Node 3 is sending data using LwM2M
# Node 4 is sending data using Camellia
# Node 4 is sending data using LwM2M
# Node 5 is sending data using Camellia
# Node 5 is sending data using LwM2M
# Node 6 is sending data using Camellia
# Node 6 is sending data using LwM2M
# Node 7 is sending data using Camellia
# Node 7 is sending data using LwM2M
# Node 8 is sending data using Camellia
# Node 8 is sending data using LwM2M
# Node 9 is sending data using Camellia
# Node 9 is sending data using LwM2M
# Node 10 is sending data using Camellia
# Node 10 is sending data using LwM2M
# Node 11 is sending data using Camellia
# Node 11 is sending data using LwM2M
# Node 12 is sending data using Camellia
# Node 12 is sending data using LwM2M
# Node 13 is sending data using Camellia
# Node 13 is sending data using LwM2M
# Node 14 is sending data using Camellia
# Node 14 is sending data using LwM2M
# Node 15 is sending data using Camellia
# Node 15 is sending data using LwM2M
# Node 16 is sending data using Camellia
# Node 16 is sending data using LwM2M
# Node 17 is sending data using Camellia
# Node 17 is sending data using LwM2M
# Node 18 is sending data using Camellia
# Node 18 is sending data using LwM2M
# Node 19 is sending data using Camellia
# Node 19 is sending data using LwM2M
# Node 20 is sending data using Camellia
# Node 20 is sending data using LwM2M
# Node 21 is sending data using Camellia
# Node 21 is sending data using LwM2M
# Node 22 is sending data using Camellia
# Node 22 is sending data using LwM2M
# Node 23 is sending data using Camellia
# Node 23 is sending data using LwM2M
# Node 24 is sending data using Camellia
# Node 24 is sending data using LwM2M
# Node 25 is sending data using Camellia
# Node 25 is sending data using LwM2M
# Node 26 is sending data using Camellia
# Node 26 is sending data using LwM2M
# Node 27 is sending data using Camellia
# Node 27 is sending data using LwM2M
# Node 28 is sending data using Camellia
# Node 28 is sending data using LwM2M
# Node 29 is sending data using Camellia
# Node 29 is sending data using LwM2M
# Node 30 is sending data using Camellia
# Node 30 is sending data using LwM2M
# Node 31 is sending data using Camellia
# Node 31 is sending data using LwM2M
# Node 32 is sending data using Camellia
# Node 32 is sending data using LwM2M
# Node 33 is sending data using Camellia
# Node 33 is sending data using LwM2M
# Node 34 is sending data using Camellia
# Node 34 is sending data using LwM2M
# Node 35 is sending data using Camellia
# Node 35 is sending data using LwM2M
# Node 36 is sending data using Camellia
# Node 36 is sending data using LwM2M
# Node 37 is sending data using Camellia
# Node 37 is sending data using LwM2M
# Node 38 is sending data using Camellia
# Node 38 is sending data using LwM2M
# Node 39 is sending data using Camellia
# Node 39 is sending data using LwM2M
# Node 40 is sending data using Camellia
# Node 40 is sending data using LwM2M
# Node 41 is sending data using Camellia
# Node 41 is sending data using LwM2M
# Node 42 is sending data using Camellia
# Node 42 is sending data using LwM2M
# Node 43 is sending data using Camellia
# Node 43 is sending data using LwM2M
# Node 44 is sending data using Camellia
# Node 44 is sending data using LwM2M
# Node 45 is sending data using Camellia
# Node 45 is sending data using LwM2M
# Node 46 is sending data using Camellia
# Node 46 is sending data using LwM2M
# Node 47 is sending data using Camellia
# Node 47 is sending data using LwM2M
# Node 48 is sending data using Camellia
# Node 48 is sending data using LwM2M
# Node 49 is sending data using Camellia
# Node 49 is sending data using LwM2M
# Node 50 is sending data using Camellia
# Node 50 is sending data using LwM2M
# Node 1 is sending data using Camellia
# Node 1 is sending data using LwM2M
# Node 2 is sending data using Camellia
# Node 2 is sending data using LwM2M
# Node 3 is sending data using Camellia
# Node 3 is sending data using LwM2M
# Node 4 is sending data using Camellia
# Node 4 is sending data using LwM2M
# Node 5 is sending data using Camellia
# Node 5 is sending data using LwM2M
# Node 6 is sending data using Camellia
# Node 6 is sending data using LwM2M
# Node 7 is sending data using Camellia
# Node 7 is sending data using LwM2M
# Node 8 is sending data using Camellia
# Node 8 is sending data using LwM2M
# Node 9 is sending data using Camellia
# Node 9 is sending data using LwM2M
# Node 10 is sending data using Camellia
# Node 10 is sending data using LwM2M
# Node 11 is sending data using Camellia
# Node 11 is sending data using LwM2M
# Node 12 is sending data using Camellia
# Node 12 is sending data using LwM2M
# Node 13 is sending data using Camellia
# Node 13 is sending data using LwM2M
# Node 14 is sending data using Camellia
# Node 14 is sending data using LwM2M
# Node 15 is sending data using Camellia
# Node 15 is sending data using LwM2M
# Node 16 is sending data using Camellia
# Node 16 is sending data using LwM2M
# Node 17 is sending data using Camellia
# Node 17 is sending data using LwM2M
# Node 18 is sending data using Camellia
# Node 18 is sending data using LwM2M
# Node 19 is sending data using Camellia
# Node 19 is sending data using LwM2M
# Node 20 is sending data using Camellia
# Node 20 is sending data using LwM2M
# Node 21 is sending data using Camellia
# Node 21 is sending data using LwM2M
# Node 22 is sending data using Camellia
# Node 22 is sending data using LwM2M
# Node 23 is sending data using Camellia
# Node 23 is sending data using LwM2M
# Node 24 is sending data using Camellia
# Node 24 is sending data using LwM2M
# Node 25 is sending data using Camellia
# Node 25 is sending data using LwM2M
# Node 26 is sending data using Camellia
# Node 26 is sending data using LwM2M
# Node 27 is sending data using Camellia
# Node 27 is sending data using LwM2M
# Node 28 is sending data using Camellia
# Node 28 is sending data using LwM2M
# Node 29 is sending data using Camellia
# Node 29 is sending data using LwM2M
# Node 30 is sending data using Camellia
# Node 30 is sending data using LwM2M
# Node 31 is sending data using Camellia
# Node 31 is sending data using LwM2M
# Node 32 is sending data using Camellia
# Node 32 is sending data using LwM2M
# Node 33 is sending data using Camellia
# Node 33 is sending data using LwM2M
# Node 34 is sending data using Camellia
# Node 34 is sending data using LwM2M
# Node 35 is sending data using Camellia
# Node 35 is sending data using LwM2M
# Node 36 is sending data using Camellia
# Node 36 is sending data using LwM2M
# Node 37 is sending data using Camellia
# Node 37 is sending data using LwM2M
# Node 38 is sending data using Camellia
# Node 38 is sending data using LwM2M
# Node 39 is sending data using Camellia
# Node 39 is sending data using LwM2M
# Node 40 is sending data using Camellia
# Node 40 is sending data using LwM2M
# Node 41 is sending data using Camellia
# Node 41 is sending data using LwM2M
# Node 42 is sending data using Camellia
# Node 42 is sending data using LwM2M
# Node 43 is sending data using Camellia
# Node 43 is sending data using LwM2M
# Node 44 is sending data using Camellia
# Node 44 is sending data using LwM2M
# Node 45 is sending data using Camellia
# Node 45 is sending data using LwM2M
# Node 46 is sending data using Camellia
# Node 46 is sending data using LwM2M
# Node 47 is sending data using Camellia
# Node 47 is sending data using LwM2M
# Node 48 is sending data using Camellia
# Node 48 is sending data using LwM2M
# Node 49 is sending data using Camellia
# Node 49 is sending data using LwM2M
# Node 50 is sending data using Camellia
# Node 50 is sending data using LwM2M
# Node 51 is sending data using Camellia
# Node 51 is sending data using LwM2M
# Node 52 is sending data using Camellia
# Node 52 is sending data using LwM2M
# Node 53 is sending data using Camellia
# Node 53 is sending data using LwM2M
# Node 54 is sending data using Camellia
# Node 54 is sending data using LwM2M
# Node 55 is sending data using Camellia
# Node 55 is sending data using LwM2M
# Node 56 is sending data using Camellia
# Node 56 is sending data using LwM2M
# Node 57 is sending data using Camellia
# Node 57 is sending data using LwM2M
# Node 58 is sending data using Camellia
# Node 58 is sending data using LwM2M
# Node 59 is sending data using Camellia
# Node 59 is sending data using LwM2M
# Node 60 is sending data using Camellia
# Node 60 is sending data using LwM2M
# Node 1 is sending data using Camellia
# Node 1 is sending data using LwM2M
# Node 2 is sending data using Camellia
# Node 2 is sending data using LwM2M
# Node 3 is sending data using Camellia
# Node 3 is sending data using LwM2M
# Node 4 is sending data using Camellia
# Node 4 is sending data using LwM2M
# Node 5 is sending data using Camellia
# Node 5 is sending data using LwM2M
# Node 6 is sending data using Camellia
# Node 6 is sending data using LwM2M
# Node 7 is sending data using Camellia
# Node 7 is sending data using LwM2M
# Node 8 is sending data using Camellia
# Node 8 is sending data using LwM2M
# Node 9 is sending data using Camellia
# Node 9 is sending data using LwM2M
# Node 10 is sending data using Camellia
# Node 10 is sending data using LwM2M
# Node 11 is sending data using Camellia
# Node 11 is sending data using LwM2M
# Node 12 is sending data using Camellia
# Node 12 is sending data using LwM2M
# Node 13 is sending data using Camellia
# Node 13 is sending data using LwM2M
# Node 14 is sending data using Camellia
# Node 14 is sending data using LwM2M
# Node 15 is sending data using Camellia
# Node 15 is sending data using LwM2M
# Node 16 is sending data using Camellia
# Node 16 is sending data using LwM2M
# Node 17 is sending data using Camellia
# Node 17 is sending data using LwM2M
# Node 18 is sending data using Camellia
# Node 18 is sending data using LwM2M
# Node 19 is sending data using Camellia
# Node 19 is sending data using LwM2M
# Node 20 is sending data using Camellia
# Node 20 is sending data using LwM2M
# Node 21 is sending data using Camellia
# Node 21 is sending data using LwM2M
# Node 22 is sending data using Camellia
# Node 22 is sending data using LwM2M
# Node 23 is sending data using Camellia
# Node 23 is sending data using LwM2M
# Node 24 is sending data using Camellia
# Node 24 is sending data using LwM2M
# Node 25 is sending data using Camellia
# Node 25 is sending data using LwM2M
# Node 26 is sending data using Camellia
# Node 26 is sending data using LwM2M
# Node 27 is sending data using Camellia
# Node 27 is sending data using LwM2M
# Node 28 is sending data using Camellia
# Node 28 is sending data using LwM2M
# Node 29 is sending data using Camellia
# Node 29 is sending data using LwM2M
# Node 30 is sending data using Camellia
# Node 30 is sending data using LwM2M
# Node 31 is sending data using Camellia
# Node 31 is sending data using LwM2M
# Node 32 is sending data using Camellia
# Node 32 is sending data using LwM2M
# Node 33 is sending data using Camellia
# Node 33 is sending data using LwM2M
# Node 34 is sending data using Camellia
# Node 34 is sending data using LwM2M
# Node 35 is sending data using Camellia
# Node 35 is sending data using LwM2M
# Node 36 is sending data using Camellia
# Node 36 is sending data using LwM2M
# Node 37 is sending data using Camellia
# Node 37 is sending data using LwM2M
# Node 38 is sending data using Camellia
# Node 38 is sending data using LwM2M
# Node 39 is sending data using Camellia
# Node 39 is sending data using LwM2M
# Node 40 is sending data using Camellia
# Node 40 is sending data using LwM2M
# Node 41 is sending data using Camellia
# Node 41 is sending data using LwM2M
# Node 42 is sending data using Camellia
# Node 42 is sending data using LwM2M
# Node 43 is sending data using Camellia
# Node 43 is sending data using LwM2M
# Node 44 is sending data using Camellia
# Node 44 is sending data using LwM2M
# Node 45 is sending data using Camellia
# Node 45 is sending data using LwM2M
# Node 46 is sending data using Camellia
# Node 46 is sending data using LwM2M
# Node 47 is sending data using Camellia
# Node 47 is sending data using LwM2M
# Node 48 is sending data using Camellia
# Node 48 is sending data using LwM2M
# Node 49 is sending data using Camellia
# Node 49 is sending data using LwM2M
# Node 50 is sending data using Camellia
# Node 50 is sending data using LwM2M
# Node 51 is sending data using Camellia
# Node 51 is sending data using LwM2M
# Node 52 is sending data using Camellia
# Node 52 is sending data using LwM2M
# Node 53 is sending data using Camellia
# Node 53 is sending data using LwM2M
# Node 54 is sending data using Camellia
# Node 54 is sending data using LwM2M
# Node 55 is sending data using Camellia
# Node 55 is sending data using LwM2M
# Node 56 is sending data using Camellia
# Node 56 is sending data using LwM2M
# Node 57 is sending data using Camellia
# Node 57 is sending data using LwM2M
# Node 58 is sending data using Camellia
# Node 58 is sending data using LwM2M
# Node 59 is sending data using Camellia
# Node 59 is sending data using LwM2M
# Node 60 is sending data using Camellia
# Node 60 is sending data using LwM2M
# Node 61 is sending data using Camellia
# Node 61 is sending data using LwM2M
# Node 62 is sending data using Camellia
# Node 62 is sending data using LwM2M
# Node 63 is sending data using Camellia
# Node 63 is sending data using LwM2M
# Node 64 is sending data using Camellia
# Node 64 is sending data using LwM2M
# Node 65 is sending data using Camellia
# Node 65 is sending data using LwM2M
# Node 66 is sending data using Camellia
# Node 66 is sending data using LwM2M
# Node 67 is sending data using Camellia
# Node 67 is sending data using LwM2M
# Node 68 is sending data using Camellia
# Node 68 is sending data using LwM2M
# Node 69 is sending data using Camellia
# Node 69 is sending data using LwM2M
# Node 70 is sending data using Camellia
# Node 70 is sending data using LwM2M
# Node 1 is sending data using Camellia
# Node 1 is sending data using LwM2M
# Node 2 is sending data using Camellia
# Node 2 is sending data using LwM2M
# Node 3 is sending data using Camellia
# Node 3 is sending data using LwM2M
# Node 4 is sending data using Camellia
# Node 4 is sending data using LwM2M
# Node 5 is sending data using Camellia
# Node 5 is sending data using LwM2M
# Node 6 is sending data using Camellia
# Node 6 is sending data using LwM2M
# Node 7 is sending data using Camellia
# Node 7 is sending data using LwM2M
# Node 8 is sending data using Camellia
# Node 8 is sending data using LwM2M
# Node 9 is sending data using Camellia
# Node 9 is sending data using LwM2M
# Node 10 is sending data using Camellia
# Node 10 is sending data using LwM2M
# Node 11 is sending data using Camellia
# Node 11 is sending data using LwM2M
# Node 12 is sending data using Camellia
# Node 12 is sending data using LwM2M
# Node 13 is sending data using Camellia
# Node 13 is sending data using LwM2M
# Node 14 is sending data using Camellia
# Node 14 is sending data using LwM2M
# Node 15 is sending data using Camellia
# Node 15 is sending data using LwM2M
# Node 16 is sending data using Camellia
# Node 16 is sending data using LwM2M
# Node 17 is sending data using Camellia
# Node 17 is sending data using LwM2M
# Node 18 is sending data using Camellia
# Node 18 is sending data using LwM2M
# Node 19 is sending data using Camellia
# Node 19 is sending data using LwM2M
# Node 20 is sending data using Camellia
# Node 20 is sending data using LwM2M
# Node 21 is sending data using Camellia
# Node 21 is sending data using LwM2M
# Node 22 is sending data using Camellia
# Node 22 is sending data using LwM2M
# Node 23 is sending data using Camellia
# Node 23 is sending data using LwM2M
# Node 24 is sending data using Camellia
# Node 24 is sending data using LwM2M
# Node 25 is sending data using Camellia
# Node 25 is sending data using LwM2M
# Node 26 is sending data using Camellia
# Node 26 is sending data using LwM2M
# Node 27 is sending data using Camellia
# Node 27 is sending data using LwM2M
# Node 28 is sending data using Camellia
# Node 28 is sending data using LwM2M
# Node 29 is sending data using Camellia
# Node 29 is sending data using LwM2M
# Node 30 is sending data using Camellia
# Node 30 is sending data using LwM2M
# Node 31 is sending data using Camellia
# Node 31 is sending data using LwM2M
# Node 32 is sending data using Camellia
# Node 32 is sending data using LwM2M
# Node 33 is sending data using Camellia
# Node 33 is sending data using LwM2M
# Node 34 is sending data using Camellia
# Node 34 is sending data using LwM2M
# Node 35 is sending data using Camellia
# Node 35 is sending data using LwM2M
# Node 36 is sending data using Camellia
# Node 36 is sending data using LwM2M
# Node 37 is sending data using Camellia
# Node 37 is sending data using LwM2M
# Node 38 is sending data using Camellia
# Node 38 is sending data using LwM2M
# Node 39 is sending data using Camellia
# Node 39 is sending data using LwM2M
# Node 40 is sending data using Camellia
# Node 40 is sending data using LwM2M
# Node 41 is sending data using Camellia
# Node 41 is sending data using LwM2M
# Node 42 is sending data using Camellia
# Node 42 is sending data using LwM2M
# Node 43 is sending data using Camellia
# Node 43 is sending data using LwM2M
# Node 44 is sending data using Camellia
# Node 44 is sending data using LwM2M
# Node 45 is sending data using Camellia
# Node 45 is sending data using LwM2M
# Node 46 is sending data using Camellia
# Node 46 is sending data using LwM2M
# Node 47 is sending data using Camellia
# Node 47 is sending data using LwM2M
# Node 48 is sending data using Camellia
# Node 48 is sending data using LwM2M
# Node 49 is sending data using Camellia
# Node 49 is sending data using LwM2M
# Node 50 is sending data using Camellia
# Node 50 is sending data using LwM2M
# Node 51 is sending data using Camellia
# Node 51 is sending data using LwM2M
# Node 52 is sending data using Camellia
# Node 52 is sending data using LwM2M
# Node 53 is sending data using Camellia
# Node 53 is sending data using LwM2M
# Node 54 is sending data using Camellia
# Node 54 is sending data using LwM2M
# Node 55 is sending data using Camellia
# Node 55 is sending data using LwM2M
# Node 56 is sending data using Camellia
# Node 56 is sending data using LwM2M
# Node 57 is sending data using Camellia
# Node 57 is sending data using LwM2M
# Node 58 is sending data using Camellia
# Node 58 is sending data using LwM2M
# Node 59 is sending data using Camellia
# Node 59 is sending data using LwM2M
# Node 60 is sending data using Camellia
# Node 60 is sending data using LwM2M
# Node 61 is sending data using Camellia
# Node 61 is sending data using LwM2M
# Node 62 is sending data using Camellia
# Node 62 is sending data using LwM2M
# Node 63 is sending data using Camellia
# Node 63 is sending data using LwM2M
# Node 64 is sending data using Camellia
# Node 64 is sending data using LwM2M
# Node 65 is sending data using Camellia
# Node 65 is sending data using LwM2M
# Node 66 is sending data using Camellia
# Node 66 is sending data using LwM2M
# Node 67 is sending data using Camellia
# Node 67 is sending data using LwM2M
# Node 68 is sending data using Camellia
# Node 68 is sending data using LwM2M
# Node 69 is sending data using Camellia
# Node 69 is sending data using LwM2M
# Node 70 is sending data using Camellia
# Node 70 is sending data using LwM2M
# Node 71 is sending data using Camellia
# Node 71 is sending data using LwM2M
# Node 72 is sending data using Camellia
# Node 72 is sending data using LwM2M
# Node 73 is sending data using Camellia
# Node 73 is sending data using LwM2M
# Node 74 is sending data using Camellia
# Node 74 is sending data using LwM2M
# Node 75 is sending data using Camellia
# Node 75 is sending data using LwM2M
# Node 76 is sending data using Camellia
# Node 76 is sending data using LwM2M
# Node 77 is sending data using Camellia
# Node 77 is sending data using LwM2M
# Node 78 is sending data using Camellia
# Node 78 is sending data using LwM2M
# Node 79 is sending data using Camellia
# Node 79 is sending data using LwM2M
# Node 80 is sending data using Camellia
# Node 80 is sending data using LwM2M
# Node 1 is sending data using Camellia
# Node 1 is sending data using LwM2M
# Node 2 is sending data using Camellia
# Node 2 is sending data using LwM2M
# Node 3 is sending data using Camellia
# Node 3 is sending data using LwM2M
# Node 4 is sending data using Camellia
# Node 4 is sending data using LwM2M
# Node 5 is sending data using Camellia
# Node 5 is sending data using LwM2M
# Node 6 is sending data using Camellia
# Node 6 is sending data using LwM2M
# Node 7 is sending data using Camellia
# Node 7 is sending data using LwM2M
# Node 8 is sending data using Camellia
# Node 8 is sending data using LwM2M
# Node 9 is sending data using Camellia
# Node 9 is sending data using LwM2M
# Node 10 is sending data using Camellia
# Node 10 is sending data using LwM2M
# Node 11 is sending data using Camellia
# Node 11 is sending data using LwM2M
# Node 12 is sending data using Camellia
# Node 12 is sending data using LwM2M
# Node 13 is sending data using Camellia
# Node 13 is sending data using LwM2M
# Node 14 is sending data using Camellia
# Node 14 is sending data using LwM2M
# Node 15 is sending data using Camellia
# Node 15 is sending data using LwM2M
# Node 16 is sending data using Camellia
# Node 16 is sending data using LwM2M
# Node 17 is sending data using Camellia
# Node 17 is sending data using LwM2M
# Node 18 is sending data using Camellia
# Node 18 is sending data using LwM2M
# Node 19 is sending data using Camellia
# Node 19 is sending data using LwM2M
# Node 20 is sending data using Camellia
# Node 20 is sending data using LwM2M
# Node 21 is sending data using Camellia
# Node 21 is sending data using LwM2M
# Node 22 is sending data using Camellia
# Node 22 is sending data using LwM2M
# Node 23 is sending data using Camellia
# Node 23 is sending data using LwM2M
# Node 24 is sending data using Camellia
# Node 24 is sending data using LwM2M
# Node 25 is sending data using Camellia
# Node 25 is sending data using LwM2M
# Node 26 is sending data using Camellia
# Node 26 is sending data using LwM2M
# Node 27 is sending data using Camellia
# Node 27 is sending data using LwM2M
# Node 28 is sending data using Camellia
# Node 28 is sending data using LwM2M
# Node 29 is sending data using Camellia
# Node 29 is sending data using LwM2M
# Node 30 is sending data using Camellia
# Node 30 is sending data using LwM2M
# Node 31 is sending data using Camellia
# Node 31 is sending data using LwM2M
# Node 32 is sending data using Camellia
# Node 32 is sending data using LwM2M
# Node 33 is sending data using Camellia
# Node 33 is sending data using LwM2M
# Node 34 is sending data using Camellia
# Node 34 is sending data using LwM2M
# Node 35 is sending data using Camellia
# Node 35 is sending data using LwM2M
# Node 36 is sending data using Camellia
# Node 36 is sending data using LwM2M
# Node 37 is sending data using Camellia
# Node 37 is sending data using LwM2M
# Node 38 is sending data using Camellia
# Node 38 is sending data using LwM2M
# Node 39 is sending data using Camellia
# Node 39 is sending data using LwM2M
# Node 40 is sending data using Camellia
# Node 40 is sending data using LwM2M
# Node 41 is sending data using Camellia
# Node 41 is sending data using LwM2M
# Node 42 is sending data using Camellia
# Node 42 is sending data using LwM2M
# Node 43 is sending data using Camellia
# Node 43 is sending data using LwM2M
# Node 44 is sending data using Camellia
# Node 44 is sending data using LwM2M
# Node 45 is sending data using Camellia
# Node 45 is sending data using LwM2M
# Node 46 is sending data using Camellia
# Node 46 is sending data using LwM2M
# Node 47 is sending data using Camellia
# Node 47 is sending data using LwM2M
# Node 48 is sending data using Camellia
# Node 48 is sending data using LwM2M
# Node 49 is sending data using Camellia
# Node 49 is sending data using LwM2M
# Node 50 is sending data using Camellia
# Node 50 is sending data using LwM2M
# Node 51 is sending data using Camellia
# Node 51 is sending data using LwM2M
# Node 52 is sending data using Camellia
# Node 52 is sending data using LwM2M
# Node 53 is sending data using Camellia
# Node 53 is sending data using LwM2M
# Node 54 is sending data using Camellia
# Node 54 is sending data using LwM2M
# Node 55 is sending data using Camellia
# Node 55 is sending data using LwM2M
# Node 56 is sending data using Camellia
# Node 56 is sending data using LwM2M
# Node 57 is sending data using Camellia
# Node 57 is sending data using LwM2M
# Node 58 is sending data using Camellia
# Node 58 is sending data using LwM2M
# Node 59 is sending data using Camellia
# Node 59 is sending data using LwM2M
# Node 60 is sending data using Camellia
# Node 60 is sending data using LwM2M
# Node 61 is sending data using Camellia
# Node 61 is sending data using LwM2M
# Node 62 is sending data using Camellia
# Node 62 is sending data using LwM2M
# Node 63 is sending data using Camellia
# Node 63 is sending data using LwM2M
# Node 64 is sending data using Camellia
# Node 64 is sending data using LwM2M
# Node 65 is sending data using Camellia
# Node 65 is sending data using LwM2M
# Node 66 is sending data using Camellia
# Node 66 is sending data using LwM2M
# Node 67 is sending data using Camellia
# Node 67 is sending data using LwM2M
# Node 68 is sending data using Camellia
# Node 68 is sending data using LwM2M
# Node 69 is sending data using Camellia
# Node 69 is sending data using LwM2M
# Node 70 is sending data using Camellia
# Node 70 is sending data using LwM2M
# Node 71 is sending data using Camellia
# Node 71 is sending data using LwM2M
# Node 72 is sending data using Camellia
# Node 72 is sending data using LwM2M
# Node 73 is sending data using Camellia
# Node 73 is sending data using LwM2M
# Node 74 is sending data using Camellia
# Node 74 is sending data using LwM2M
# Node 75 is sending data using Camellia
# Node 75 is sending data using LwM2M
# Node 76 is sending data using Camellia
# Node 76 is sending data using LwM2M
# Node 77 is sending data using Camellia
# Node 77 is sending data using LwM2M
# Node 78 is sending data using Camellia
# Node 78 is sending data using LwM2M
# Node 79 is sending data using Camellia
# Node 79 is sending data using LwM2M
# Node 80 is sending data using Camellia
# Node 80 is sending data using LwM2M
# Node 81 is sending data using Camellia
# Node 81 is sending data using LwM2M
# Node 82 is sending data using Camellia
# Node 82 is sending data using LwM2M
# Node 83 is sending data using Camellia
# Node 83 is sending data using LwM2M
# Node 84 is sending data using Camellia
# Node 84 is sending data using LwM2M
# Node 85 is sending data using Camellia
# Node 85 is sending data using LwM2M
# Node 86 is sending data using Camellia
# Node 86 is sending data using LwM2M
# Node 87 is sending data using Camellia
# Node 87 is sending data using LwM2M
# Node 88 is sending data using Camellia
# Node 88 is sending data using LwM2M
# Node 89 is sending data using Camellia
# Node 89 is sending data using LwM2M
# Node 90 is sending data using Camellia
# Node 90 is sending data using LwM2M
# Node 1 is sending data using Camellia
# Node 1 is sending data using LwM2M
# Node 2 is sending data using Camellia
# Node 2 is sending data using LwM2M
# Node 3 is sending data using Camellia
# Node 3 is sending data using LwM2M
# Node 4 is sending data using Camellia
# Node 4 is sending data using LwM2M
# Node 5 is sending data using Camellia
# Node 5 is sending data using LwM2M
# Node 6 is sending data using Camellia
# Node 6 is sending data using LwM2M
# Node 7 is sending data using Camellia
# Node 7 is sending data using LwM2M
# Node 8 is sending data using Camellia
# Node 8 is sending data using LwM2M
# Node 9 is sending data using Camellia
# Node 9 is sending data using LwM2M
# Node 10 is sending data using Camellia
# Node 10 is sending data using LwM2M
# Node 11 is sending data using Camellia
# Node 11 is sending data using LwM2M
# Node 12 is sending data using Camellia
# Node 12 is sending data using LwM2M
# Node 13 is sending data using Camellia
# Node 13 is sending data using LwM2M
# Node 14 is sending data using Camellia
# Node 14 is sending data using LwM2M
# Node 15 is sending data using Camellia
# Node 15 is sending data using LwM2M
# Node 16 is sending data using Camellia
# Node 16 is sending data using LwM2M
# Node 17 is sending data using Camellia
# Node 17 is sending data using LwM2M
# Node 18 is sending data using Camellia
# Node 18 is sending data using LwM2M
# Node 19 is sending data using Camellia
# Node 19 is sending data using LwM2M
# Node 20 is sending data using Camellia
# Node 20 is sending data using LwM2M
# Node 21 is sending data using Camellia
# Node 21 is sending data using LwM2M
# Node 22 is sending data using Camellia
# Node 22 is sending data using LwM2M
# Node 23 is sending data using Camellia
# Node 23 is sending data using LwM2M
# Node 24 is sending data using Camellia
# Node 24 is sending data using LwM2M
# Node 25 is sending data using Camellia
# Node 25 is sending data using LwM2M
# Node 26 is sending data using Camellia
# Node 26 is sending data using LwM2M
# Node 27 is sending data using Camellia
# Node 27 is sending data using LwM2M
# Node 28 is sending data using Camellia
# Node 28 is sending data using LwM2M
# Node 29 is sending data using Camellia
# Node 29 is sending data using LwM2M
# Node 30 is sending data using Camellia
# Node 30 is sending data using LwM2M
# Node 31 is sending data using Camellia
# Node 31 is sending data using LwM2M
# Node 32 is sending data using Camellia
# Node 32 is sending data using LwM2M
# Node 33 is sending data using Camellia
# Node 33 is sending data using LwM2M
# Node 34 is sending data using Camellia
# Node 34 is sending data using LwM2M
# Node 35 is sending data using Camellia
# Node 35 is sending data using LwM2M
# Node 36 is sending data using Camellia
# Node 36 is sending data using LwM2M
# Node 37 is sending data using Camellia
# Node 37 is sending data using LwM2M
# Node 38 is sending data using Camellia
# Node 38 is sending data using LwM2M
# Node 39 is sending data using Camellia
# Node 39 is sending data using LwM2M
# Node 40 is sending data using Camellia
# Node 40 is sending data using LwM2M
# Node 41 is sending data using Camellia
# Node 41 is sending data using LwM2M
# Node 42 is sending data using Camellia
# Node 42 is sending data using LwM2M
# Node 43 is sending data using Camellia
# Node 43 is sending data using LwM2M
# Node 44 is sending data using Camellia
# Node 44 is sending data using LwM2M
# Node 45 is sending data using Camellia
# Node 45 is sending data using LwM2M
# Node 46 is sending data using Camellia
# Node 46 is sending data using LwM2M
# Node 47 is sending data using Camellia
# Node 47 is sending data using LwM2M
# Node 48 is sending data using Camellia
# Node 48 is sending data using LwM2M
# Node 49 is sending data using Camellia
# Node 49 is sending data using LwM2M
# Node 50 is sending data using Camellia
# Node 50 is sending data using LwM2M
# Node 51 is sending data using Camellia
# Node 51 is sending data using LwM2M
# Node 52 is sending data using Camellia
# Node 52 is sending data using LwM2M
# Node 53 is sending data using Camellia
# Node 53 is sending data using LwM2M
# Node 54 is sending data using Camellia
# Node 54 is sending data using LwM2M
# Node 55 is sending data using Camellia
# Node 55 is sending data using LwM2M
# Node 56 is sending data using Camellia
# Node 56 is sending data using LwM2M
# Node 57 is sending data using Camellia
# Node 57 is sending data using LwM2M
# Node 58 is sending data using Camellia
# Node 58 is sending data using LwM2M
# Node 59 is sending data using Camellia
# Node 59 is sending data using LwM2M
# Node 60 is sending data using Camellia
# Node 60 is sending data using LwM2M
# Node 61 is sending data using Camellia
# Node 61 is sending data using LwM2M
# Node 62 is sending data using Camellia
# Node 62 is sending data using LwM2M
# Node 63 is sending data using Camellia
# Node 63 is sending data using LwM2M
# Node 64 is sending data using Camellia
# Node 64 is sending data using LwM2M
# Node 65 is sending data using Camellia
# Node 65 is sending data using LwM2M
# Node 66 is sending data using Camellia
# Node 66 is sending data using LwM2M
# Node 67 is sending data using Camellia
# Node 67 is sending data using LwM2M
# Node 68 is sending data using Camellia
# Node 68 is sending data using LwM2M
# Node 69 is sending data using Camellia
# Node 69 is sending data using LwM2M
# Node 70 is sending data using Camellia
# Node 70 is sending data using LwM2M
# Node 71 is sending data using Camellia
# Node 71 is sending data using LwM2M
# Node 72 is sending data using Camellia
# Node 72 is sending data using LwM2M
# Node 73 is sending data using Camellia
# Node 73 is sending data using LwM2M
# Node 74 is sending data using Camellia
# Node 74 is sending data using LwM2M
# Node 75 is sending data using Camellia
# Node 75 is sending data using LwM2M
# Node 76 is sending data using Camellia
# Node 76 is sending data using LwM2M
# Node 77 is sending data using Camellia
# Node 77 is sending data using LwM2M
# Node 78 is sending data using Camellia
# Node 78 is sending data using LwM2M
# Node 79 is sending data using Camellia
# Node 79 is sending data using LwM2M
# Node 80 is sending data using Camellia
# Node 80 is sending data using LwM2M
# Node 81 is sending data using Camellia
# Node 81 is sending data using LwM2M
# Node 82 is sending data using Camellia
# Node 82 is sending data using LwM2M
# Node 83 is sending data using Camellia
# Node 83 is sending data using LwM2M
# Node 84 is sending data using Camellia
# Node 84 is sending data using LwM2M
# Node 85 is sending data using Camellia
# Node 85 is sending data using LwM2M
# Node 86 is sending data using Camellia
# Node 86 is sending data using LwM2M
# Node 87 is sending data using Camellia
# Node 87 is sending data using LwM2M
# Node 88 is sending data using Camellia
# Node 88 is sending data using LwM2M
# Node 89 is sending data using Camellia
# Node 89 is sending data using LwM2M
# Node 90 is sending data using Camellia
# Node 90 is sending data using LwM2M
# Node 91 is sending data using Camellia
# Node 91 is sending data using LwM2M
# Node 92 is sending data using Camellia
# Node 92 is sending data using LwM2M
# Node 93 is sending data using Camellia
# Node 93 is sending data using LwM2M
# Node 94 is sending data using Camellia
# Node 94 is sending data using LwM2M
# Node 95 is sending data using Camellia
# Node 95 is sending data using LwM2M
# Node 96 is sending data using Camellia
# Node 96 is sending data using LwM2M
# Node 97 is sending data using Camellia
# Node 97 is sending data using LwM2M
# Node 98 is sending data using Camellia
# Node 98 is sending data using LwM2M
# Node 99 is sending data using Camellia
# Node 99 is sending data using LwM2M
# Node 100 is sending data using Camellia
# Node 100 is sending data using LwM2M

# %%
import random
import matplotlib.pyplot as plt

# Constants for protocols
PROTOCOL_CAMELLIA = "Camellia"
PROTOCOL_LWM2M = "LwM2M"
PROTOCOL_LEACH = "LEACH"
PROTOCOL_SPIN = "SPIN"

# Function to simulate Camellia-specific data transmission
def send_data_camellia(node_id):
    print(f"Node {node_id} is sending data using {PROTOCOL_CAMELLIA}")
    # Simulate energy consumption for Camellia (replace with actual energy calculation)
    energy_consumption_camellia[node_id - 1] += random.uniform(1.0, 3.0)

# Function to simulate LwM2M-specific data transmission
def send_data_lwm2m(node_id):
    print(f"Node {node_id} is sending data using {PROTOCOL_LWM2M}")
    # Simulate energy consumption for LwM2M (replace with actual energy calculation)
    energy_consumption_lwm2m[node_id - 1] += random.uniform(0.5, 2.0)

# Function to simulate LEACH-specific data transmission
def send_data_leach(node_id):
    print(f"Node {node_id} is sending data using {PROTOCOL_LEACH}")
    # Simulate energy consumption for LEACH (replace with actual energy calculation)
    energy_consumption_leach[node_id - 1] += random.uniform(0.7, 2.5)

# Function to simulate SPIN-specific data transmission
def send_data_spin(node_id):
    print(f"Node {node_id} is sending data using {PROTOCOL_SPIN}")
    # Simulate energy consumption for SPIN (replace with actual energy calculation)
    energy_consumption_spin[node_id - 1] += random.uniform(0.6, 2.2)

# Simulated WSN parameters
num_nodes = 10  # Initial number of nodes
max_nodes = 1000  # Maximum number of nodes for the simulation

# Lists to store energy consumption data for each protocol
energy_consumption_camellia = [0] * max_nodes
energy_consumption_lwm2m = [0] * max_nodes
energy_consumption_leach = [0] * max_nodes
energy_consumption_spin = [0] * max_nodes

# Lists to store the number of nodes and energy consumption for each protocol
num_nodes_list = []
energy_consumption_camellia_list = []
energy_consumption_lwm2m_list = []
energy_consumption_leach_list = []
energy_consumption_spin_list = []

# Main simulation loop
while num_nodes <= max_nodes:
    for node_id in range(1, num_nodes + 1):
        # Generate random data for the node
        sensor_data = random.randint(0, 100)

        # Determine which protocol to use based on the number of nodes
        
        send_data_camellia(node_id)
        send_data_lwm2m(node_id)
        send_data_leach(node_id)
        send_data_spin(node_id)

    # Calculate total energy consumption for each protocol
    total_energy_consumed_camellia = sum(energy_consumption_camellia[:num_nodes])
    total_energy_consumed_lwm2m = sum(energy_consumption_lwm2m[:num_nodes])
    total_energy_consumed_leach = sum(energy_consumption_leach[:num_nodes])
    total_energy_consumed_spin = sum(energy_consumption_spin[:num_nodes])

    # Store data for plotting
    num_nodes_list.append(num_nodes)
    energy_consumption_camellia_list.append(total_energy_consumed_camellia)
    energy_consumption_lwm2m_list.append(total_energy_consumed_lwm2m)
    energy_consumption_leach_list.append(total_energy_consumed_leach)
    energy_consumption_spin_list.append(total_energy_consumed_spin)

    # Increase the number of nodes (you can adjust this as needed)
    num_nodes += 10

# Plot energy consumption vs. number of nodes for all protocols
plt.figure(figsize=(12, 6))

# Plot for Camellia
plt.plot(num_nodes_list, energy_consumption_camellia_list, marker='o', linestyle='-', label=PROTOCOL_CAMELLIA, color='b')

# Plot for LwM2M
plt.plot(num_nodes_list, energy_consumption_lwm2m_list, marker='s', linestyle='-', label=PROTOCOL_LWM2M, color='r')

# Plot for LEACH
plt.plot(num_nodes_list, energy_consumption_leach_list, marker='^', linestyle='-', label=PROTOCOL_LEACH, color='g')

# Plot for SPIN
plt.plot(num_nodes_list, energy_consumption_spin_list, marker='x', linestyle='-', label=PROTOCOL_SPIN, color='m')

plt.xlabel('Number of Nodes')
plt.ylabel('Total Energy Consumption')
plt.grid(True)
plt.legend()
plt.title('Energy Consumption vs. Number of Nodes')

# Show the combined plot
plt.show()
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# Node 50 is sending data using Camellia
# Node 50 is sending data using LwM2M
# Node 50 is sending data using LEACH
# Node 50 is sending data using SPIN
# Node 51 is sending data using Camellia
# Node 51 is sending data using LwM2M
# Node 51 is sending data using LEACH
# Node 51 is sending data using SPIN
# Node 52 is sending data using Camellia
# Node 52 is sending data using LwM2M
# Node 52 is sending data using LEACH
# Node 52 is sending data using SPIN
# Node 53 is sending data using Camellia
# Node 53 is sending data using LwM2M
# Node 53 is sending data using LEACH
# Node 53 is sending data using SPIN
# Node 54 is sending data using Camellia
# Node 54 is sending data using LwM2M
# Node 54 is sending data using LEACH
# Node 54 is sending data using SPIN
# Node 55 is sending data using Camellia
# Node 55 is sending data using LwM2M
# Node 55 is sending data using LEACH
# Node 55 is sending data using SPIN
# Node 56 is sending data using Camellia
# Node 56 is sending data using LwM2M
# Node 56 is sending data using LEACH
# Node 56 is sending data using SPIN
# Node 57 is sending data using Camellia
# Node 57 is sending data using LwM2M
# Node 57 is sending data using LEACH
# Node 57 is sending data using SPIN
# Node 58 is sending data using Camellia
# Node 58 is sending data using LwM2M
# Node 58 is sending data using LEACH
# Node 58 is sending data using SPIN
# Node 59 is sending data using Camellia
# Node 59 is sending data using LwM2M
# Node 59 is sending data using LEACH
# Node 59 is sending data using SPIN
# Node 60 is sending data using Camellia
# Node 60 is sending data using LwM2M
# Node 60 is sending data using LEACH
# Node 60 is sending data using SPIN
# Node 61 is sending data using Camellia
# Node 61 is sending data using LwM2M
# Node 61 is sending data using LEACH
# Node 61 is sending data using SPIN
# Node 62 is sending data using Camellia
# Node 62 is sending data using LwM2M
# Node 62 is sending data using LEACH
# Node 62 is sending data using SPIN
# Node 63 is sending data using Camellia
# Node 63 is sending data using LwM2M
# Node 63 is sending data using LEACH
# Node 63 is sending data using SPIN
# Node 64 is sending data using Camellia
# Node 64 is sending data using LwM2M
# Node 64 is sending data using LEACH
# Node 64 is sending data using SPIN
# Node 65 is sending data using Camellia
# Node 65 is sending data using LwM2M
# Node 65 is sending data using LEACH
# Node 65 is sending data using SPIN
# Node 66 is sending data using Camellia
# Node 66 is sending data using LwM2M
# Node 66 is sending data using LEACH
# Node 66 is sending data using SPIN
# Node 67 is sending data using Camellia
# Node 67 is sending data using LwM2M
# Node 67 is sending data using LEACH
# Node 67 is sending data using SPIN
# Node 68 is sending data using Camellia
# Node 68 is sending data using LwM2M
# Node 68 is sending data using LEACH
# Node 68 is sending data using SPIN
# Node 69 is sending data using Camellia
# Node 69 is sending data using LwM2M
# Node 69 is sending data using LEACH
# Node 69 is sending data using SPIN
# Node 70 is sending data using Camellia
# Node 70 is sending data using LwM2M
# Node 70 is sending data using LEACH
# Node 70 is sending data using SPIN
# Node 71 is sending data using Camellia
# Node 71 is sending data using LwM2M
# Node 71 is sending data using LEACH
# Node 71 is sending data using SPIN
# Node 72 is sending data using Camellia
# Node 72 is sending data using LwM2M
# Node 72 is sending data using LEACH
# Node 72 is sending data using SPIN
# Node 73 is sending data using Camellia
# Node 73 is sending data using LwM2M
# Node 73 is sending data using LEACH
# Node 73 is sending data using SPIN
# Node 74 is sending data using Camellia
# Node 74 is sending data using LwM2M
# Node 74 is sending data using LEACH
# Node 74 is sending data using SPIN
# Node 75 is sending data using Camellia
# Node 75 is sending data using LwM2M
# Node 75 is sending data using LEACH
# Node 75 is sending data using SPIN
# Node 76 is sending data using Camellia
# Node 76 is sending data using LwM2M
# Node 76 is sending data using LEACH
# Node 76 is sending data using SPIN
# Node 77 is sending data using Camellia
# Node 77 is sending data using LwM2M
# Node 77 is sending data using LEACH
# Node 77 is sending data using SPIN
# Node 78 is sending data using Camellia
# Node 78 is sending data using LwM2M
# Node 78 is sending data using LEACH
# Node 78 is sending data using SPIN
# Node 79 is sending data using Camellia
# Node 79 is sending data using LwM2M
# Node 79 is sending data using LEACH
# Node 79 is sending data using SPIN
# Node 80 is sending data using Camellia
# Node 80 is sending data using LwM2M
# Node 80 is sending data using LEACH
# Node 80 is sending data using SPIN
# Node 81 is sending data using Camellia
# Node 81 is sending data using LwM2M
# Node 81 is sending data using LEACH
# Node 81 is sending data using SPIN
# Node 82 is sending data using Camellia
# Node 82 is sending data using LwM2M
# Node 82 is sending data using LEACH
# Node 82 is sending data using SPIN
# Node 83 is sending data using Camellia
# Node 83 is sending data using LwM2M
# Node 83 is sending data using LEACH
# Node 83 is sending data using SPIN
# Node 84 is sending data using Camellia
# Node 84 is sending data using LwM2M
# Node 84 is sending data using LEACH
# Node 84 is sending data using SPIN
# Node 85 is sending data using Camellia
# Node 85 is sending data using LwM2M
# Node 85 is sending data using LEACH
# Node 85 is sending data using SPIN
# Node 86 is sending data using Camellia
# Node 86 is sending data using LwM2M
# Node 86 is sending data using LEACH
# Node 86 is sending data using SPIN
# Node 87 is sending data using Camellia
# Node 87 is sending data using LwM2M
# Node 87 is sending data using LEACH
# Node 87 is sending data using SPIN
# Node 88 is sending data using Camellia
# Node 88 is sending data using LwM2M
# Node 88 is sending data using LEACH
# Node 88 is sending data using SPIN
# Node 89 is sending data using Camellia
# Node 89 is sending data using LwM2M
# Node 89 is sending data using LEACH
# Node 89 is sending data using SPIN
# Node 90 is sending data using Camellia
# Node 90 is sending data using LwM2M
# Node 90 is sending data using LEACH
# Node 90 is sending data using SPIN
# Node 91 is sending data using Camellia
# Node 91 is sending data using LwM2M
# Node 91 is sending data using LEACH
# Node 91 is sending data using SPIN
# Node 92 is sending data using Camellia
# Node 92 is sending data using LwM2M
# Node 92 is sending data using LEACH
# Node 92 is sending data using SPIN
# Node 93 is sending data using Camellia
# Node 93 is sending data using LwM2M
# Node 93 is sending data using LEACH
# Node 93 is sending data using SPIN
# Node 94 is sending data using Camellia
# Node 94 is sending data using LwM2M
# Node 94 is sending data using LEACH
# Node 94 is sending data using SPIN
# Node 95 is sending data using Camellia
# Node 95 is sending data using LwM2M
# Node 95 is sending data using LEACH
# Node 95 is sending data using SPIN
# Node 96 is sending data using Camellia
# Node 96 is sending data using LwM2M
# Node 96 is sending data using LEACH
# Node 96 is sending data using SPIN
# Node 97 is sending data using Camellia
# Node 97 is sending data using LwM2M
# Node 97 is sending data using LEACH
# Node 97 is sending data using SPIN
# Node 98 is sending data using Camellia
# Node 98 is sending data using LwM2M
# Node 98 is sending data using LEACH
# Node 98 is sending data using SPIN
# Node 99 is sending data using Camellia
# Node 99 is sending data using LwM2M
# Node 99 is sending data using LEACH
# Node 99 is sending data using SPIN
# Node 100 is sending data using Camellia
# Node 100 is sending data using LwM2M
# Node 100 is sending data using LEACH
# Node 100 is sending data using SPIN
# Node 101 is sending data using Camellia
# Node 101 is sending data using LwM2M
# Node 101 is sending data using LEACH
# Node 101 is sending data using SPIN
# Node 102 is sending data using Camellia
# Node 102 is sending data using LwM2M
# Node 102 is sending data using LEACH
# Node 102 is sending data using SPIN
# Node 103 is sending data using Camellia
# Node 103 is sending data using LwM2M
# Node 103 is sending data using LEACH
# Node 103 is sending data using SPIN
# Node 104 is sending data using Camellia
# Node 104 is sending data using LwM2M
# Node 104 is sending data using LEACH
# Node 104 is sending data using SPIN
# Node 105 is sending data using Camellia
# Node 105 is sending data using LwM2M
# Node 105 is sending data using LEACH
# Node 105 is sending data using SPIN
# Node 106 is sending data using Camellia
# Node 106 is sending data using LwM2M
# Node 106 is sending data using LEACH
# Node 106 is sending data using SPIN
# Node 107 is sending data using Camellia
# Node 107 is sending data using LwM2M
# Node 107 is sending data using LEACH
# Node 107 is sending data using SPIN
# Node 108 is sending data using Camellia
# Node 108 is sending data using LwM2M
# Node 108 is sending data using LEACH
# Node 108 is sending data using SPIN
# Node 109 is sending data using Camellia
# Node 109 is sending data using LwM2M
# Node 109 is sending data using LEACH
# Node 109 is sending data using SPIN
# Node 110 is sending data using Camellia
# Node 110 is sending data using LwM2M
# Node 110 is sending data using LEACH
# Node 110 is sending data using SPIN
# Node 111 is sending data using Camellia
# Node 111 is sending data using LwM2M
# Node 111 is sending data using LEACH
# Node 111 is sending data using SPIN
# Node 112 is sending data using Camellia
# Node 112 is sending data using LwM2M
# Node 112 is sending data using LEACH
# Node 112 is sending data using SPIN
# Node 113 is sending data using Camellia
# Node 113 is sending data using LwM2M
# Node 113 is sending data using LEACH
# Node 113 is sending data using SPIN
# Node 114 is sending data using Camellia
# Node 114 is sending data using LwM2M
# Node 114 is sending data using LEACH
# Node 114 is sending data using SPIN
# Node 115 is sending data using Camellia
# Node 115 is sending data using LwM2M
# Node 115 is sending data using LEACH
# Node 115 is sending data using SPIN
# Node 116 is sending data using Camellia
# Node 116 is sending data using LwM2M
# Node 116 is sending data using LEACH
# Node 116 is sending data using SPIN
# Node 117 is sending data using Camellia
# Node 117 is sending data using LwM2M
# Node 117 is sending data using LEACH
# Node 117 is sending data using SPIN
# Node 118 is sending data using Camellia
# Node 118 is sending data using LwM2M
# Node 118 is sending data using LEACH
# Node 118 is sending data using SPIN
# Node 119 is sending data using Camellia
# Node 119 is sending data using LwM2M
# Node 119 is sending data using LEACH
# Node 119 is sending data using SPIN
# Node 120 is sending data using Camellia
# Node 120 is sending data using LwM2M
# Node 120 is sending data using LEACH
# Node 120 is sending data using SPIN
# Node 121 is sending data using Camellia
# Node 121 is sending data using LwM2M
# Node 121 is sending data using LEACH
# Node 121 is sending data using SPIN
# Node 122 is sending data using Camellia
# Node 122 is sending data using LwM2M
# Node 122 is sending data using LEACH
# Node 122 is sending data using SPIN
# Node 123 is sending data using Camellia
# Node 123 is sending data using LwM2M
# Node 123 is sending data using LEACH
# Node 123 is sending data using SPIN
# Node 124 is sending data using Camellia
# Node 124 is sending data using LwM2M
# Node 124 is sending data using LEACH
# Node 124 is sending data using SPIN
# Node 125 is sending data using Camellia
# Node 125 is sending data using LwM2M
# Node 125 is sending data using LEACH
# Node 125 is sending data using SPIN
# Node 126 is sending data using Camellia
# Node 126 is sending data using LwM2M
# Node 126 is sending data using LEACH
# Node 126 is sending data using SPIN
# Node 127 is sending data using Camellia
# Node 127 is sending data using LwM2M
# Node 127 is sending data using LEACH
# Node 127 is sending data using SPIN
# Node 128 is sending data using Camellia
# Node 128 is sending data using LwM2M
# Node 128 is sending data using LEACH
# Node 128 is sending data using SPIN
# Node 129 is sending data using Camellia
# Node 129 is sending data using LwM2M
# Node 129 is sending data using LEACH
# Node 129 is sending data using SPIN
# Node 130 is sending data using Camellia
# Node 130 is sending data using LwM2M
# Node 130 is sending data using LEACH
# Node 130 is sending data using SPIN
# Node 131 is sending data using Camellia
# Node 131 is sending data using LwM2M
# Node 131 is sending data using LEACH
# Node 131 is sending data using SPIN
# Node 132 is sending data using Camellia
# Node 132 is sending data using LwM2M
# Node 132 is sending data using LEACH
# Node 132 is sending data using SPIN
# Node 133 is sending data using Camellia
# Node 133 is sending data using LwM2M
# Node 133 is sending data using LEACH
# Node 133 is sending data using SPIN
# Node 134 is sending data using Camellia
# Node 134 is sending data using LwM2M
# Node 134 is sending data using LEACH
# Node 134 is sending data using SPIN
# Node 135 is sending data using Camellia
# Node 135 is sending data using LwM2M
# Node 135 is sending data using LEACH
# Node 135 is sending data using SPIN
# Node 136 is sending data using Camellia
# Node 136 is sending data using LwM2M
# Node 136 is sending data using LEACH
# Node 136 is sending data using SPIN
# Node 137 is sending data using Camellia
# Node 137 is sending data using LwM2M
# Node 137 is sending data using LEACH
# Node 137 is sending data using SPIN
# Node 138 is sending data using Camellia
# Node 138 is sending data using LwM2M
# Node 138 is sending data using LEACH
# Node 138 is sending data using SPIN
# Node 139 is sending data using Camellia
# Node 139 is sending data using LwM2M
# Node 139 is sending data using LEACH
# Node 139 is sending data using SPIN
# Node 140 is sending data using Camellia
# Node 140 is sending data using LwM2M
# Node 140 is sending data using LEACH
# Node 140 is sending data using SPIN
# Node 141 is sending data using Camellia
# Node 141 is sending data using LwM2M
# Node 141 is sending data using LEACH
# Node 141 is sending data using SPIN
# Node 142 is sending data using Camellia
# Node 142 is sending data using LwM2M
# Node 142 is sending data using LEACH
# Node 142 is sending data using SPIN
# Node 143 is sending data using Camellia
# Node 143 is sending data using LwM2M
# Node 143 is sending data using LEACH
# Node 143 is sending data using SPIN
# Node 144 is sending data using Camellia
# Node 144 is sending data using LwM2M
# Node 144 is sending data using LEACH
# Node 144 is sending data using SPIN
# Node 145 is sending data using Camellia
# Node 145 is sending data using LwM2M
# Node 145 is sending data using LEACH
# Node 145 is sending data using SPIN
# Node 146 is sending data using Camellia
# Node 146 is sending data using LwM2M
# Node 146 is sending data using LEACH
# Node 146 is sending data using SPIN
# Node 147 is sending data using Camellia
# Node 147 is sending data using LwM2M
# Node 147 is sending data using LEACH
# Node 147 is sending data using SPIN
# Node 148 is sending data using Camellia
# Node 148 is sending data using LwM2M
# Node 148 is sending data using LEACH
# Node 148 is sending data using SPIN
# Node 149 is sending data using Camellia
# Node 149 is sending data using LwM2M
# Node 149 is sending data using LEACH
# Node 149 is sending data using SPIN
# Node 150 is sending data using Camellia
# Node 150 is sending data using LwM2M
# Node 150 is sending data using LEACH
# Node 150 is sending data using SPIN
# Node 151 is sending data using Camellia
# Node 151 is sending data using LwM2M
# Node 151 is sending data using LEACH
# Node 151 is sending data using SPIN
# Node 152 is sending data using Camellia
# Node 152 is sending data using LwM2M
# Node 152 is sending data using LEACH
# Node 152 is sending data using SPIN
# Node 153 is sending data using Camellia
# Node 153 is sending data using LwM2M
# Node 153 is sending data using LEACH
# Node 153 is sending data using SPIN
# Node 154 is sending data using Camellia
# Node 154 is sending data using LwM2M
# Node 154 is sending data using LEACH
# Node 154 is sending data using SPIN
# Node 155 is sending data using Camellia
# Node 155 is sending data using LwM2M
# Node 155 is sending data using LEACH
# Node 155 is sending data using SPIN
# Node 156 is sending data using Camellia
# Node 156 is sending data using LwM2M
# Node 156 is sending data using LEACH
# Node 156 is sending data using SPIN
# Node 157 is sending data using Camellia
# Node 157 is sending data using LwM2M
# Node 157 is sending data using LEACH
# Node 157 is sending data using SPIN
# Node 158 is sending data using Camellia
# Node 158 is sending data using LwM2M
# Node 158 is sending data using LEACH
# Node 158 is sending data using SPIN
# Node 159 is sending data using Camellia
# Node 159 is sending data using LwM2M
# Node 159 is sending data using LEACH
# Node 159 is sending data using SPIN
# Node 160 is sending data using Camellia
# Node 160 is sending data using LwM2M
# Node 160 is sending data using LEACH
# Node 160 is sending data using SPIN
# Node 161 is sending data using Camellia
# Node 161 is sending data using LwM2M
# Node 161 is sending data using LEACH
# Node 161 is sending data using SPIN
# Node 162 is sending data using Camellia
# Node 162 is sending data using LwM2M
# Node 162 is sending data using LEACH
# Node 162 is sending data using SPIN
# Node 163 is sending data using Camellia
# Node 163 is sending data using LwM2M
# Node 163 is sending data using LEACH
# Node 163 is sending data using SPIN
# Node 164 is sending data using Camellia
# Node 164 is sending data using LwM2M
# Node 164 is sending data using LEACH
# Node 164 is sending data using SPIN
# Node 165 is sending data using Camellia
# Node 165 is sending data using LwM2M
# Node 165 is sending data using LEACH
# Node 165 is sending data using SPIN
# Node 166 is sending data using Camellia
# Node 166 is sending data using LwM2M
# Node 166 is sending data using LEACH
# Node 166 is sending data using SPIN
# Node 167 is sending data using Camellia
# Node 167 is sending data using LwM2M
# Node 167 is sending data using LEACH
# Node 167 is sending data using SPIN
# Node 168 is sending data using Camellia
# Node 168 is sending data using LwM2M
# Node 168 is sending data using LEACH
# Node 168 is sending data using SPIN
# Node 169 is sending data using Camellia
# Node 169 is sending data using LwM2M
# Node 169 is sending data using LEACH
# Node 169 is sending data using SPIN
# Node 170 is sending data using Camellia
# Node 170 is sending data using LwM2M
# Node 170 is sending data using LEACH
# Node 170 is sending data using SPIN
# Node 171 is sending data using Camellia
# Node 171 is sending data using LwM2M
# Node 171 is sending data using LEACH
# Node 171 is sending data using SPIN
# Node 172 is sending data using Camellia
# Node 172 is sending data using LwM2M
# Node 172 is sending data using LEACH
# Node 172 is sending data using SPIN
# Node 173 is sending data using Camellia
# Node 173 is sending data using LwM2M
# Node 173 is sending data using LEACH
# Node 173 is sending data using SPIN
# Node 174 is sending data using Camellia
# Node 174 is sending data using LwM2M
# Node 174 is sending data using LEACH
# Node 174 is sending data using SPIN
# Node 175 is sending data using Camellia
# Node 175 is sending data using LwM2M
# Node 175 is sending data using LEACH
# Node 175 is sending data using SPIN
# Node 176 is sending data using Camellia
# Node 176 is sending data using LwM2M
# Node 176 is sending data using LEACH
# Node 176 is sending data using SPIN
# Node 177 is sending data using Camellia
# Node 177 is sending data using LwM2M
# Node 177 is sending data using LEACH
# Node 177 is sending data using SPIN
# Node 178 is sending data using Camellia
# Node 178 is sending data using LwM2M
# Node 178 is sending data using LEACH
# Node 178 is sending data using SPIN
# Node 179 is sending data using Camellia
# Node 179 is sending data using LwM2M
# Node 179 is sending data using LEACH
# Node 179 is sending data using SPIN
# Node 180 is sending data using Camellia
# Node 180 is sending data using LwM2M
# Node 180 is sending data using LEACH
# Node 180 is sending data using SPIN
# Node 181 is sending data using Camellia
# Node 181 is sending data using LwM2M
# Node 181 is sending data using LEACH
# Node 181 is sending data using SPIN
# Node 182 is sending data using Camellia
# Node 182 is sending data using LwM2M
# Node 182 is sending data using LEACH
# Node 182 is sending data using SPIN
# Node 183 is sending data using Camellia
# Node 183 is sending data using LwM2M
# Node 183 is sending data using LEACH
# Node 183 is sending data using SPIN
# Node 184 is sending data using Camellia
# Node 184 is sending data using LwM2M
# Node 184 is sending data using LEACH
# Node 184 is sending data using SPIN
# Node 185 is sending data using Camellia
# Node 185 is sending data using LwM2M
# Node 185 is sending data using LEACH
# Node 185 is sending data using SPIN
# Node 186 is sending data using Camellia
# Node 186 is sending data using LwM2M
# Node 186 is sending data using LEACH
# Node 186 is sending data using SPIN
# Node 187 is sending data using Camellia
# Node 187 is sending data using LwM2M
# Node 187 is sending data using LEACH
# Node 187 is sending data using SPIN
# Node 188 is sending data using Camellia
# Node 188 is sending data using LwM2M
# Node 188 is sending data using LEACH
# Node 188 is sending data using SPIN
# Node 189 is sending data using Camellia
# Node 189 is sending data using LwM2M
# Node 189 is sending data using LEACH
# Node 189 is sending data using SPIN
# Node 190 is sending data using Camellia
# Node 190 is sending data using LwM2M
# Node 190 is sending data using LEACH
# Node 190 is sending data using SPIN
# Node 191 is sending data using Camellia
# Node 191 is sending data using LwM2M
# Node 191 is sending data using LEACH
# Node 191 is sending data using SPIN
# Node 192 is sending data using Camellia
# Node 192 is sending data using LwM2M
# Node 192 is sending data using LEACH
# Node 192 is sending data using SPIN
# Node 193 is sending data using Camellia
# Node 193 is sending data using LwM2M
# Node 193 is sending data using LEACH
# Node 193 is sending data using SPIN
# Node 194 is sending data using Camellia
# Node 194 is sending data using LwM2M
# Node 194 is sending data using LEACH
# Node 194 is sending data using SPIN
# Node 195 is sending data using Camellia
# Node 195 is sending data using LwM2M
# Node 195 is sending data using LEACH
# Node 195 is sending data using SPIN
# Node 196 is sending data using Camellia
# Node 196 is sending data using LwM2M
# Node 196 is sending data using LEACH
# Node 196 is sending data using SPIN
# Node 197 is sending data using Camellia
# Node 197 is sending data using LwM2M
# Node 197 is sending data using LEACH
# Node 197 is sending data using SPIN
# Node 198 is sending data using Camellia
# Node 198 is sending data using LwM2M
# Node 198 is sending data using LEACH
# Node 198 is sending data using SPIN
# Node 199 is sending data using Camellia
# Node 199 is sending data using LwM2M
# Node 199 is sending data using LEACH
# Node 199 is sending data using SPIN
# Node 200 is sending data using Camellia
# Node 200 is sending data using LwM2M
# Node 200 is sending data using LEACH
# Node 200 is sending data using SPIN
# Node 201 is sending data using Camellia
# Node 201 is sending data using LwM2M
# Node 201 is sending data using LEACH
# Node 201 is sending data using SPIN
# Node 202 is sending data using Camellia
# Node 202 is sending data using LwM2M
# Node 202 is sending data using LEACH
# Node 202 is sending data using SPIN
# Node 203 is sending data using Camellia
# Node 203 is sending data using LwM2M
# Node 203 is sending data using LEACH
# Node 203 is sending data using SPIN
# Node 204 is sending data using Camellia
# Node 204 is sending data using LwM2M
# Node 204 is sending data using LEACH
# Node 204 is sending data using SPIN
# Node 205 is sending data using Camellia
# Node 205 is sending data using LwM2M
# Node 205 is sending data using LEACH
# Node 205 is sending data using SPIN
# Node 206 is sending data using Camellia
# Node 206 is sending data using LwM2M
# Node 206 is sending data using LEACH
# Node 206 is sending data using SPIN
# Node 207 is sending data using Camellia
# Node 207 is sending data using LwM2M
# Node 207 is sending data using LEACH
# Node 207 is sending data using SPIN
# Node 208 is sending data using Camellia
# Node 208 is sending data using LwM2M
# Node 208 is sending data using LEACH
# Node 208 is sending data using SPIN
# Node 209 is sending data using Camellia
# Node 209 is sending data using LwM2M
# Node 209 is sending data using LEACH
# Node 209 is sending data using SPIN
# Node 210 is sending data using Camellia
# Node 210 is sending data using LwM2M
# Node 210 is sending data using LEACH
# Node 210 is sending data using SPIN
# Node 211 is sending data using Camellia
# Node 211 is sending data using LwM2M
# Node 211 is sending data using LEACH
# Node 211 is sending data using SPIN
# Node 212 is sending data using Camellia
# Node 212 is sending data using LwM2M
# Node 212 is sending data using LEACH
# Node 212 is sending data using SPIN
# Node 213 is sending data using Camellia
# Node 213 is sending data using LwM2M
# Node 213 is sending data using LEACH
# Node 213 is sending data using SPIN
# Node 214 is sending data using Camellia
# Node 214 is sending data using LwM2M
# Node 214 is sending data using LEACH
# Node 214 is sending data using SPIN
# Node 215 is sending data using Camellia
# Node 215 is sending data using LwM2M
# Node 215 is sending data using LEACH
# Node 215 is sending data using SPIN
# Node 216 is sending data using Camellia
# Node 216 is sending data using LwM2M
# Node 216 is sending data using LEACH
# Node 216 is sending data using SPIN
# Node 217 is sending data using Camellia
# Node 217 is sending data using LwM2M
# Node 217 is sending data using LEACH
# Node 217 is sending data using SPIN
# Node 218 is sending data using Camellia
# Node 218 is sending data using LwM2M
# Node 218 is sending data using LEACH
# Node 218 is sending data using SPIN
# Node 219 is sending data using Camellia
# Node 219 is sending data using LwM2M
# Node 219 is sending data using LEACH
# Node 219 is sending data using SPIN
# Node 220 is sending data using Camellia
# Node 220 is sending data using LwM2M
# Node 220 is sending data using LEACH
# Node 220 is sending data using SPIN
# Node 221 is sending data using Camellia
# Node 221 is sending data using LwM2M
# Node 221 is sending data using LEACH
# Node 221 is sending data using SPIN
# Node 222 is sending data using Camellia
# Node 222 is sending data using LwM2M
# Node 222 is sending data using LEACH
# Node 222 is sending data using SPIN
# Node 223 is sending data using Camellia
# Node 223 is sending data using LwM2M
# Node 223 is sending data using LEACH
# Node 223 is sending data using SPIN
# Node 224 is sending data using Camellia
# Node 224 is sending data using LwM2M
# Node 224 is sending data using LEACH
# Node 224 is sending data using SPIN
# Node 225 is sending data using Camellia
# Node 225 is sending data using LwM2M
# Node 225 is sending data using LEACH
# Node 225 is sending data using SPIN
# Node 226 is sending data using Camellia
# Node 226 is sending data using LwM2M
# Node 226 is sending data using LEACH
# Node 226 is sending data using SPIN
# Node 227 is sending data using Camellia
# Node 227 is sending data using LwM2M
# Node 227 is sending data using LEACH
# Node 227 is sending data using SPIN
# Node 228 is sending data using Camellia
# Node 228 is sending data using LwM2M
# Node 228 is sending data using LEACH
# Node 228 is sending data using SPIN
# Node 229 is sending data using Camellia
# Node 229 is sending data using LwM2M
# Node 229 is sending data using LEACH
# Node 229 is sending data using SPIN
# Node 230 is sending data using Camellia
# Node 230 is sending data using LwM2M
# Node 230 is sending data using LEACH
# Node 230 is sending data using SPIN
# Node 231 is sending data using Camellia
# Node 231 is sending data using LwM2M
# Node 231 is sending data using LEACH
# Node 231 is sending data using SPIN
# Node 232 is sending data using Camellia
# Node 232 is sending data using LwM2M
# Node 232 is sending data using LEACH
# Node 232 is sending data using SPIN
# Node 233 is sending data using Camellia
# Node 233 is sending data using LwM2M
# Node 233 is sending data using LEACH
# Node 233 is sending data using SPIN
# Node 234 is sending data using Camellia
# Node 234 is sending data using LwM2M
# Node 234 is sending data using LEACH
# Node 234 is sending data using SPIN
# Node 235 is sending data using Camellia
# Node 235 is sending data using LwM2M
# Node 235 is sending data using LEACH
# Node 235 is sending data using SPIN
# Node 236 is sending data using Camellia
# Node 236 is sending data using LwM2M
# Node 236 is sending data using LEACH
# Node 236 is sending data using SPIN
# Node 237 is sending data using Camellia
# Node 237 is sending data using LwM2M
# Node 237 is sending data using LEACH
# Node 237 is sending data using SPIN
# Node 238 is sending data using Camellia
# Node 238 is sending data using LwM2M
# Node 238 is sending data using LEACH
# Node 238 is sending data using SPIN
# Node 239 is sending data using Camellia
# Node 239 is sending data using LwM2M
# Node 239 is sending data using LEACH
# Node 239 is sending data using SPIN
# Node 240 is sending data using Camellia
# Node 240 is sending data using LwM2M
# Node 240 is sending data using LEACH
# Node 240 is sending data using SPIN
# Node 241 is sending data using Camellia
# Node 241 is sending data using LwM2M
# Node 241 is sending data using LEACH
# Node 241 is sending data using SPIN
# Node 242 is sending data using Camellia
# Node 242 is sending data using LwM2M
# Node 242 is sending data using LEACH
# Node 242 is sending data using SPIN
# Node 243 is sending data using Camellia
# Node 243 is sending data using LwM2M
# Node 243 is sending data using LEACH
# Node 243 is sending data using SPIN
# Node 244 is sending data using Camellia
# Node 244 is sending data using LwM2M
# Node 244 is sending data using LEACH
# Node 244 is sending data using SPIN
# Node 245 is sending data using Camellia
# Node 245 is sending data using LwM2M
# Node 245 is sending data using LEACH
# Node 245 is sending data using SPIN
# Node 246 is sending data using Camellia
# Node 246 is sending data using LwM2M
# Node 246 is sending data using LEACH
# Node 246 is sending data using SPIN
# Node 247 is sending data using Camellia
# Node 247 is sending data using LwM2M
# Node 247 is sending data using LEACH
# Node 247 is sending data using SPIN
# Node 248 is sending data using Camellia
# Node 248 is sending data using LwM2M
# Node 248 is sending data using LEACH
# Node 248 is sending data using SPIN
# Node 249 is sending data using Camellia
# Node 249 is sending data using LwM2M
# Node 249 is sending data using LEACH
# Node 249 is sending data using SPIN
# Node 250 is sending data using Camellia
# Node 250 is sending data using LwM2M
# Node 250 is sending data using LEACH
# Node 250 is sending data using SPIN
# Node 251 is sending data using Camellia
# Node 251 is sending data using LwM2M
# Node 251 is sending data using LEACH
# Node 251 is sending data using SPIN
# Node 252 is sending data using Camellia
# Node 252 is sending data using LwM2M
# Node 252 is sending data using LEACH
# Node 252 is sending data using SPIN
# Node 253 is sending data using Camellia
# Node 253 is sending data using LwM2M
# Node 253 is sending data using LEACH
# Node 253 is sending data using SPIN
# Node 254 is sending data using Camellia
# Node 254 is sending data using LwM2M
# Node 254 is sending data using LEACH
# Node 254 is sending data using SPIN
# Node 255 is sending data using Camellia
# Node 255 is sending data using LwM2M
# Node 255 is sending data using LEACH
# Node 255 is sending data using SPIN
# Node 256 is sending data using Camellia
# Node 256 is sending data using LwM2M
# Node 256 is sending data using LEACH
# Node 256 is sending data using SPIN
# Node 257 is sending data using Camellia
# Node 257 is sending data using LwM2M
# Node 257 is sending data using LEACH
# Node 257 is sending data using SPIN
# Node 258 is sending data using Camellia
# Node 258 is sending data using LwM2M
# Node 258 is sending data using LEACH
# Node 258 is sending data using SPIN
# Node 259 is sending data using Camellia
# Node 259 is sending data using LwM2M
# Node 259 is sending data using LEACH
# Node 259 is sending data using SPIN
# Node 260 is sending data using Camellia
# Node 260 is sending data using LwM2M
# Node 260 is sending data using LEACH
# Node 260 is sending data using SPIN
# Node 261 is sending data using Camellia
# Node 261 is sending data using LwM2M
# Node 261 is sending data using LEACH
# Node 261 is sending data using SPIN
# Node 262 is sending data using Camellia
# Node 262 is sending data using LwM2M
# Node 262 is sending data using LEACH
# Node 262 is sending data using SPIN
# Node 263 is sending data using Camellia
# Node 263 is sending data using LwM2M
# Node 263 is sending data using LEACH
# Node 263 is sending data using SPIN
# Node 264 is sending data using Camellia
# Node 264 is sending data using LwM2M
# Node 264 is sending data using LEACH
# Node 264 is sending data using SPIN
# Node 265 is sending data using Camellia
# Node 265 is sending data using LwM2M
# Node 265 is sending data using LEACH
# Node 265 is sending data using SPIN
# Node 266 is sending data using Camellia
# Node 266 is sending data using LwM2M
# Node 266 is sending data using LEACH
# Node 266 is sending data using SPIN
# Node 267 is sending data using Camellia
# Node 267 is sending data using LwM2M
# Node 267 is sending data using LEACH
# Node 267 is sending data using SPIN
# Node 268 is sending data using Camellia
# Node 268 is sending data using LwM2M
# Node 268 is sending data using LEACH
# Node 268 is sending data using SPIN
# Node 269 is sending data using Camellia
# Node 269 is sending data using LwM2M
# Node 269 is sending data using LEACH
# Node 269 is sending data using SPIN
# Node 270 is sending data using Camellia
# Node 270 is sending data using LwM2M
# Node 270 is sending data using LEACH
# Node 270 is sending data using SPIN
# Node 271 is sending data using Camellia
# Node 271 is sending data using LwM2M
# Node 271 is sending data using LEACH
# Node 271 is sending data using SPIN
# Node 272 is sending data using Camellia
# Node 272 is sending data using LwM2M
# Node 272 is sending data using LEACH
# Node 272 is sending data using SPIN
# Node 273 is sending data using Camellia
# Node 273 is sending data using LwM2M
# Node 273 is sending data using LEACH
# Node 273 is sending data using SPIN
# Node 274 is sending data using Camellia
# Node 274 is sending data using LwM2M
# Node 274 is sending data using LEACH
# Node 274 is sending data using SPIN
# Node 275 is sending data using Camellia
# Node 275 is sending data using LwM2M
# Node 275 is sending data using LEACH
# Node 275 is sending data using SPIN
# Node 276 is sending data using Camellia
# Node 276 is sending data using LwM2M
# Node 276 is sending data using LEACH
# Node 276 is sending data using SPIN
# Node 277 is sending data using Camellia
# Node 277 is sending data using LwM2M
# Node 277 is sending data using LEACH
# Node 277 is sending data using SPIN
# Node 278 is sending data using Camellia
# Node 278 is sending data using LwM2M
# Node 278 is sending data using LEACH
# Node 278 is sending data using SPIN
# Node 279 is sending data using Camellia
# Node 279 is sending data using LwM2M
# Node 279 is sending data using LEACH
# Node 279 is sending data using SPIN
# Node 280 is sending data using Camellia
# Node 280 is sending data using LwM2M
# Node 280 is sending data using LEACH
# Node 280 is sending data using SPIN
# Node 281 is sending data using Camellia
# Node 281 is sending data using LwM2M
# Node 281 is sending data using LEACH
# Node 281 is sending data using SPIN
# Node 282 is sending data using Camellia
# Node 282 is sending data using LwM2M
# Node 282 is sending data using LEACH
# Node 282 is sending data using SPIN
# Node 283 is sending data using Camellia
# Node 283 is sending data using LwM2M
# Node 283 is sending data using LEACH
# Node 283 is sending data using SPIN
# Node 284 is sending data using Camellia
# Node 284 is sending data using LwM2M
# Node 284 is sending data using LEACH
# Node 284 is sending data using SPIN
# Node 285 is sending data using Camellia
# Node 285 is sending data using LwM2M
# Node 285 is sending data using LEACH
# Node 285 is sending data using SPIN
# Node 286 is sending data using Camellia
# Node 286 is sending data using LwM2M
# Node 286 is sending data using LEACH
# Node 286 is sending data using SPIN
# Node 287 is sending data using Camellia
# Node 287 is sending data using LwM2M
# Node 287 is sending data using LEACH
# Node 287 is sending data using SPIN
# Node 288 is sending data using Camellia
# Node 288 is sending data using LwM2M
# Node 288 is sending data using LEACH
# Node 288 is sending data using SPIN
# Node 289 is sending data using Camellia
# Node 289 is sending data using LwM2M
# Node 289 is sending data using LEACH
# Node 289 is sending data using SPIN
# Node 290 is sending data using Camellia
# Node 290 is sending data using LwM2M
# Node 290 is sending data using LEACH
# Node 290 is sending data using SPIN
# Node 291 is sending data using Camellia
# Node 291 is sending data using LwM2M
# Node 291 is sending data using LEACH
# Node 291 is sending data using SPIN
# Node 292 is sending data using Camellia
# Node 292 is sending data using LwM2M
# Node 292 is sending data using LEACH
# Node 292 is sending data using SPIN
# Node 293 is sending data using Camellia
# Node 293 is sending data using LwM2M
# Node 293 is sending data using LEACH
# Node 293 is sending data using SPIN
# Node 294 is sending data using Camellia
# Node 294 is sending data using LwM2M
# Node 294 is sending data using LEACH
# Node 294 is sending data using SPIN
# Node 295 is sending data using Camellia
# Node 295 is sending data using LwM2M
# Node 295 is sending data using LEACH
# Node 295 is sending data using SPIN
# Node 296 is sending data using Camellia
# Node 296 is sending data using LwM2M
# Node 296 is sending data using LEACH
# Node 296 is sending data using SPIN
# Node 297 is sending data using Camellia
# Node 297 is sending data using LwM2M
# Node 297 is sending data using LEACH
# Node 297 is sending data using SPIN
# Node 298 is sending data using Camellia
# Node 298 is sending data using LwM2M
# Node 298 is sending data using LEACH
# Node 298 is sending data using SPIN
# Node 299 is sending data using Camellia
# Node 299 is sending data using LwM2M
# Node 299 is sending data using LEACH
# Node 299 is sending data using SPIN
# Node 300 is sending data using Camellia
# Node 300 is sending data using LwM2M
# Node 300 is sending data using LEACH
# Node 300 is sending data using SPIN
# Node 301 is sending data using Camellia
# Node 301 is sending data using LwM2M
# Node 301 is sending data using LEACH
# Node 301 is sending data using SPIN
# Node 302 is sending data using Camellia
# Node 302 is sending data using LwM2M
# Node 302 is sending data using LEACH
# Node 302 is sending data using SPIN
# Node 303 is sending data using Camellia
# Node 303 is sending data using LwM2M
# Node 303 is sending data using LEACH
# Node 303 is sending data using SPIN
# Node 304 is sending data using Camellia
# Node 304 is sending data using LwM2M
# Node 304 is sending data using LEACH
# Node 304 is sending data using SPIN
# Node 305 is sending data using Camellia
# Node 305 is sending data using LwM2M
# Node 305 is sending data using LEACH
# Node 305 is sending data using SPIN
# Node 306 is sending data using Camellia
# Node 306 is sending data using LwM2M
# Node 306 is sending data using LEACH
# Node 306 is sending data using SPIN
# Node 307 is sending data using Camellia
# Node 307 is sending data using LwM2M
# Node 307 is sending data using LEACH
# Node 307 is sending data using SPIN
# Node 308 is sending data using Camellia
# Node 308 is sending data using LwM2M
# Node 308 is sending data using LEACH
# Node 308 is sending data using SPIN
# Node 309 is sending data using Camellia
# Node 309 is sending data using LwM2M
# Node 309 is sending data using LEACH
# Node 309 is sending data using SPIN
# Node 310 is sending data using Camellia
# Node 310 is sending data using LwM2M
# Node 310 is sending data using LEACH
# Node 310 is sending data using SPIN
# Node 311 is sending data using Camellia
# Node 311 is sending data using LwM2M
# Node 311 is sending data using LEACH
# Node 311 is sending data using SPIN
# Node 312 is sending data using Camellia
# Node 312 is sending data using LwM2M
# Node 312 is sending data using LEACH
# Node 312 is sending data using SPIN
# Node 313 is sending data using Camellia
# Node 313 is sending data using LwM2M
# Node 313 is sending data using LEACH
# Node 313 is sending data using SPIN
# Node 314 is sending data using Camellia
# Node 314 is sending data using LwM2M
# Node 314 is sending data using LEACH
# Node 314 is sending data using SPIN
# Node 315 is sending data using Camellia
# Node 315 is sending data using LwM2M
# Node 315 is sending data using LEACH
# Node 315 is sending data using SPIN
# Node 316 is sending data using Camellia
# Node 316 is sending data using LwM2M
# Node 316 is sending data using LEACH
# Node 316 is sending data using SPIN
# Node 317 is sending data using Camellia
# Node 317 is sending data using LwM2M
# Node 317 is sending data using LEACH
# Node 317 is sending data using SPIN
# Node 318 is sending data using Camellia
# Node 318 is sending data using LwM2M
# Node 318 is sending data using LEACH
# Node 318 is sending data using SPIN
# Node 319 is sending data using Camellia
# Node 319 is sending data using LwM2M
# Node 319 is sending data using LEACH
# Node 319 is sending data using SPIN
# Node 320 is sending data using Camellia
# Node 320 is sending data using LwM2M
# Node 320 is sending data using LEACH
# Node 320 is sending data using SPIN
# Node 321 is sending data using Camellia
# Node 321 is sending data using LwM2M
# Node 321 is sending data using LEACH
# Node 321 is sending data using SPIN
# Node 322 is sending data using Camellia
# Node 322 is sending data using LwM2M
# Node 322 is sending data using LEACH
# Node 322 is sending data using SPIN
# Node 323 is sending data using Camellia
# Node 323 is sending data using LwM2M
# Node 323 is sending data using LEACH
# Node 323 is sending data using SPIN
# Node 324 is sending data using Camellia
# Node 324 is sending data using LwM2M
# Node 324 is sending data using LEACH
# Node 324 is sending data using SPIN
# Node 325 is sending data using Camellia
# Node 325 is sending data using LwM2M
# Node 325 is sending data using LEACH
# Node 325 is sending data using SPIN
# Node 326 is sending data using Camellia
# Node 326 is sending data using LwM2M
# Node 326 is sending data using LEACH
# Node 326 is sending data using SPIN
# Node 327 is sending data using Camellia
# Node 327 is sending data using LwM2M
# Node 327 is sending data using LEACH
# Node 327 is sending data using SPIN
# Node 328 is sending data using Camellia
# Node 328 is sending data using LwM2M
# Node 328 is sending data using LEACH
# Node 328 is sending data using SPIN
# Node 329 is sending data using Camellia
# Node 329 is sending data using LwM2M
# Node 329 is sending data using LEACH
# Node 329 is sending data using SPIN
# Node 330 is sending data using Camellia
# Node 330 is sending data using LwM2M
# Node 330 is sending data using LEACH
# Node 330 is sending data using SPIN
# Node 331 is sending data using Camellia
# Node 331 is sending data using LwM2M
# Node 331 is sending data using LEACH
# Node 331 is sending data using SPIN
# Node 332 is sending data using Camellia
# Node 332 is sending data using LwM2M
# Node 332 is sending data using LEACH
# Node 332 is sending data using SPIN
# Node 333 is sending data using Camellia
# Node 333 is sending data using LwM2M
# Node 333 is sending data using LEACH
# Node 333 is sending data using SPIN
# Node 334 is sending data using Camellia
# Node 334 is sending data using LwM2M
# Node 334 is sending data using LEACH
# Node 334 is sending data using SPIN
# Node 335 is sending data using Camellia
# Node 335 is sending data using LwM2M
# Node 335 is sending data using LEACH
# Node 335 is sending data using SPIN
# Node 336 is sending data using Camellia
# Node 336 is sending data using LwM2M
# Node 336 is sending data using LEACH
# Node 336 is sending data using SPIN
# Node 337 is sending data using Camellia
# Node 337 is sending data using LwM2M
# Node 337 is sending data using LEACH
# Node 337 is sending data using SPIN
# Node 338 is sending data using Camellia
# Node 338 is sending data using LwM2M
# Node 338 is sending data using LEACH
# Node 338 is sending data using SPIN
# Node 339 is sending data using Camellia
# Node 339 is sending data using LwM2M
# Node 339 is sending data using LEACH
# Node 339 is sending data using SPIN
# Node 340 is sending data using Camellia
# Node 340 is sending data using LwM2M
# Node 340 is sending data using LEACH
# Node 340 is sending data using SPIN
# Node 341 is sending data using Camellia
# Node 341 is sending data using LwM2M
# Node 341 is sending data using LEACH
# Node 341 is sending data using SPIN
# Node 342 is sending data using Camellia
# Node 342 is sending data using LwM2M
# Node 342 is sending data using LEACH
# Node 342 is sending data using SPIN
# Node 343 is sending data using Camellia
# Node 343 is sending data using LwM2M
# Node 343 is sending data using LEACH
# Node 343 is sending data using SPIN
# Node 344 is sending data using Camellia
# Node 344 is sending data using LwM2M
# Node 344 is sending data using LEACH
# Node 344 is sending data using SPIN
# Node 345 is sending data using Camellia
# Node 345 is sending data using LwM2M
# Node 345 is sending data using LEACH
# Node 345 is sending data using SPIN
# Node 346 is sending data using Camellia
# Node 346 is sending data using LwM2M
# Node 346 is sending data using LEACH
# Node 346 is sending data using SPIN
# Node 347 is sending data using Camellia
# Node 347 is sending data using LwM2M
# Node 347 is sending data using LEACH
# Node 347 is sending data using SPIN
# Node 348 is sending data using Camellia
# Node 348 is sending data using LwM2M
# Node 348 is sending data using LEACH
# Node 348 is sending data using SPIN
# Node 349 is sending data using Camellia
# Node 349 is sending data using LwM2M
# Node 349 is sending data using LEACH
# Node 349 is sending data using SPIN
# Node 350 is sending data using Camellia
# Node 350 is sending data using LwM2M
# Node 350 is sending data using LEACH
# Node 350 is sending data using SPIN
# Node 351 is sending data using Camellia
# Node 351 is sending data using LwM2M
# Node 351 is sending data using LEACH
# Node 351 is sending data using SPIN
# Node 352 is sending data using Camellia
# Node 352 is sending data using LwM2M
# Node 352 is sending data using LEACH
# Node 352 is sending data using SPIN
# Node 353 is sending data using Camellia
# Node 353 is sending data using LwM2M
# Node 353 is sending data using LEACH
# Node 353 is sending data using SPIN
# Node 354 is sending data using Camellia
# Node 354 is sending data using LwM2M
# Node 354 is sending data using LEACH
# Node 354 is sending data using SPIN
# Node 355 is sending data using Camellia
# Node 355 is sending data using LwM2M
# Node 355 is sending data using LEACH
# Node 355 is sending data using SPIN
# Node 356 is sending data using Camellia
# Node 356 is sending data using LwM2M
# Node 356 is sending data using LEACH
# Node 356 is sending data using SPIN
# Node 357 is sending data using Camellia
# Node 357 is sending data using LwM2M
# Node 357 is sending data using LEACH
# Node 357 is sending data using SPIN
# Node 358 is sending data using Camellia
# Node 358 is sending data using LwM2M
# Node 358 is sending data using LEACH
# Node 358 is sending data using SPIN
# Node 359 is sending data using Camellia
# Node 359 is sending data using LwM2M
# Node 359 is sending data using LEACH
# Node 359 is sending data using SPIN
# Node 360 is sending data using Camellia
# Node 360 is sending data using LwM2M
# Node 360 is sending data using LEACH
# Node 360 is sending data using SPIN
# Node 361 is sending data using Camellia
# Node 361 is sending data using LwM2M
# Node 361 is sending data using LEACH
# Node 361 is sending data using SPIN
# Node 362 is sending data using Camellia
# Node 362 is sending data using LwM2M
# Node 362 is sending data using LEACH
# Node 362 is sending data using SPIN
# Node 363 is sending data using Camellia
# Node 363 is sending data using LwM2M
# Node 363 is sending data using LEACH
# Node 363 is sending data using SPIN
# Node 364 is sending data using Camellia
# Node 364 is sending data using LwM2M
# Node 364 is sending data using LEACH
# Node 364 is sending data using SPIN
# Node 365 is sending data using Camellia
# Node 365 is sending data using LwM2M
# Node 365 is sending data using LEACH
# Node 365 is sending data using SPIN
# Node 366 is sending data using Camellia
# Node 366 is sending data using LwM2M
# Node 366 is sending data using LEACH
# Node 366 is sending data using SPIN
# Node 367 is sending data using Camellia
# Node 367 is sending data using LwM2M
# Node 367 is sending data using LEACH
# Node 367 is sending data using SPIN
# Node 368 is sending data using Camellia
# Node 368 is sending data using LwM2M
# Node 368 is sending data using LEACH
# Node 368 is sending data using SPIN
# ...
# Node 894 is sending data using LEACH
# Node 894 is sending data using SPIN
# Node 895 is sending data using Camellia
# Node 895 is sending data using LwM2M
# Node 895 is sending data using LEACH
# Node 895 is sending data using SPIN
# Node 896 is sending data using Camellia
# Node 896 is sending data using LwM2M
# Node 896 is sending data using LEACH
# Node 896 is sending data using SPIN
# Node 897 is sending data using Camellia
# Node 897 is sending data using LwM2M
# Node 897 is sending data using LEACH
# Node 897 is sending data using SPIN
# Node 898 is sending data using Camellia
# Node 898 is sending data using LwM2M
# Node 898 is sending data using LEACH
# Node 898 is sending data using SPIN
# Node 899 is sending data using Camellia
# Node 899 is sending data using LwM2M
# Node 899 is sending data using LEACH
# Node 899 is sending data using SPIN
# Node 900 is sending data using Camellia
# Node 900 is sending data using LwM2M
# Node 900 is sending data using LEACH
# Node 900 is sending data using SPIN
# Node 901 is sending data using Camellia
# Node 901 is sending data using LwM2M
# Node 901 is sending data using LEACH
# Node 901 is sending data using SPIN
# Node 902 is sending data using Camellia
# Node 902 is sending data using LwM2M
# Node 902 is sending data using LEACH
# Node 902 is sending data using SPIN
# Node 903 is sending data using Camellia
# Node 903 is sending data using LwM2M
# Node 903 is sending data using LEACH
# Node 903 is sending data using SPIN
# Node 904 is sending data using Camellia
# Node 904 is sending data using LwM2M
# Node 904 is sending data using LEACH
# Node 904 is sending data using SPIN
# Node 905 is sending data using Camellia
# Node 905 is sending data using LwM2M
# Node 905 is sending data using LEACH
# Node 905 is sending data using SPIN
# Node 906 is sending data using Camellia
# Node 906 is sending data using LwM2M
# Node 906 is sending data using LEACH
# Node 906 is sending data using SPIN
# Node 907 is sending data using Camellia
# Node 907 is sending data using LwM2M
# Node 907 is sending data using LEACH
# Node 907 is sending data using SPIN
# Node 908 is sending data using Camellia
# Node 908 is sending data using LwM2M
# Node 908 is sending data using LEACH
# Node 908 is sending data using SPIN
# Node 909 is sending data using Camellia
# Node 909 is sending data using LwM2M
# Node 909 is sending data using LEACH
# Node 909 is sending data using SPIN
# Node 910 is sending data using Camellia
# Node 910 is sending data using LwM2M
# Node 910 is sending data using LEACH
# Node 910 is sending data using SPIN
# Node 911 is sending data using Camellia
# Node 911 is sending data using LwM2M
# Node 911 is sending data using LEACH
# Node 911 is sending data using SPIN
# Node 912 is sending data using Camellia
# Node 912 is sending data using LwM2M
# Node 912 is sending data using LEACH
# Node 912 is sending data using SPIN
# Node 913 is sending data using Camellia
# Node 913 is sending data using LwM2M
# Node 913 is sending data using LEACH
# Node 913 is sending data using SPIN
# Node 914 is sending data using Camellia
# Node 914 is sending data using LwM2M
# Node 914 is sending data using LEACH
# Node 914 is sending data using SPIN
# Node 915 is sending data using Camellia
# Node 915 is sending data using LwM2M
# Node 915 is sending data using LEACH
# Node 915 is sending data using SPIN
# Node 916 is sending data using Camellia
# Node 916 is sending data using LwM2M
# Node 916 is sending data using LEACH
# Node 916 is sending data using SPIN
# Node 917 is sending data using Camellia
# Node 917 is sending data using LwM2M
# Node 917 is sending data using LEACH
# Node 917 is sending data using SPIN
# Node 918 is sending data using Camellia
# Node 918 is sending data using LwM2M
# Node 918 is sending data using LEACH
# Node 918 is sending data using SPIN
# Node 919 is sending data using Camellia
# Node 919 is sending data using LwM2M
# Node 919 is sending data using LEACH
# Node 919 is sending data using SPIN
# Node 920 is sending data using Camellia
# Node 920 is sending data using LwM2M
# Node 920 is sending data using LEACH
# Node 920 is sending data using SPIN
# Node 921 is sending data using Camellia
# Node 921 is sending data using LwM2M
# Node 921 is sending data using LEACH
# Node 921 is sending data using SPIN
# Node 922 is sending data using Camellia
# Node 922 is sending data using LwM2M
# Node 922 is sending data using LEACH
# Node 922 is sending data using SPIN
# Node 923 is sending data using Camellia
# Node 923 is sending data using LwM2M
# Node 923 is sending data using LEACH
# Node 923 is sending data using SPIN
# Node 924 is sending data using Camellia
# Node 924 is sending data using LwM2M
# Node 924 is sending data using LEACH
# Node 924 is sending data using SPIN
# Node 925 is sending data using Camellia
# Node 925 is sending data using LwM2M
# Node 925 is sending data using LEACH
# Node 925 is sending data using SPIN
# Node 926 is sending data using Camellia
# Node 926 is sending data using LwM2M
# Node 926 is sending data using LEACH
# Node 926 is sending data using SPIN
# Node 927 is sending data using Camellia
# Node 927 is sending data using LwM2M
# Node 927 is sending data using LEACH
# Node 927 is sending data using SPIN
# Node 928 is sending data using Camellia
# Node 928 is sending data using LwM2M
# Node 928 is sending data using LEACH
# Node 928 is sending data using SPIN
# Node 929 is sending data using Camellia
# Node 929 is sending data using LwM2M
# Node 929 is sending data using LEACH
# Node 929 is sending data using SPIN
# Node 930 is sending data using Camellia
# Node 930 is sending data using LwM2M
# Node 930 is sending data using LEACH
# Node 930 is sending data using SPIN
# Node 931 is sending data using Camellia
# Node 931 is sending data using LwM2M
# Node 931 is sending data using LEACH
# Node 931 is sending data using SPIN
# Node 932 is sending data using Camellia
# Node 932 is sending data using LwM2M
# Node 932 is sending data using LEACH
# Node 932 is sending data using SPIN
# Node 933 is sending data using Camellia
# Node 933 is sending data using LwM2M
# Node 933 is sending data using LEACH
# Node 933 is sending data using SPIN
# Node 934 is sending data using Camellia
# Node 934 is sending data using LwM2M
# Node 934 is sending data using LEACH
# Node 934 is sending data using SPIN
# Node 935 is sending data using Camellia
# Node 935 is sending data using LwM2M
# Node 935 is sending data using LEACH
# Node 935 is sending data using SPIN
# Node 936 is sending data using Camellia
# Node 936 is sending data using LwM2M
# Node 936 is sending data using LEACH
# Node 936 is sending data using SPIN
# Node 937 is sending data using Camellia
# Node 937 is sending data using LwM2M
# Node 937 is sending data using LEACH
# Node 937 is sending data using SPIN
# Node 938 is sending data using Camellia
# Node 938 is sending data using LwM2M
# Node 938 is sending data using LEACH
# Node 938 is sending data using SPIN
# Node 939 is sending data using Camellia
# Node 939 is sending data using LwM2M
# Node 939 is sending data using LEACH
# Node 939 is sending data using SPIN
# Node 940 is sending data using Camellia
# Node 940 is sending data using LwM2M
# Node 940 is sending data using LEACH
# Node 940 is sending data using SPIN
# Node 941 is sending data using Camellia
# Node 941 is sending data using LwM2M
# Node 941 is sending data using LEACH
# Node 941 is sending data using SPIN
# Node 942 is sending data using Camellia
# Node 942 is sending data using LwM2M
# Node 942 is sending data using LEACH
# Node 942 is sending data using SPIN
# Node 943 is sending data using Camellia
# Node 943 is sending data using LwM2M
# Node 943 is sending data using LEACH
# Node 943 is sending data using SPIN
# Node 944 is sending data using Camellia
# Node 944 is sending data using LwM2M
# Node 944 is sending data using LEACH
# Node 944 is sending data using SPIN
# Node 945 is sending data using Camellia
# Node 945 is sending data using LwM2M
# Node 945 is sending data using LEACH
# Node 945 is sending data using SPIN
# Node 946 is sending data using Camellia
# Node 946 is sending data using LwM2M
# Node 946 is sending data using LEACH
# Node 946 is sending data using SPIN
# Node 947 is sending data using Camellia
# Node 947 is sending data using LwM2M
# Node 947 is sending data using LEACH
# Node 947 is sending data using SPIN
# Node 948 is sending data using Camellia
# Node 948 is sending data using LwM2M
# Node 948 is sending data using LEACH
# Node 948 is sending data using SPIN
# Node 949 is sending data using Camellia
# Node 949 is sending data using LwM2M
# Node 949 is sending data using LEACH
# Node 949 is sending data using SPIN
# Node 950 is sending data using Camellia
# Node 950 is sending data using LwM2M
# Node 950 is sending data using LEACH
# Node 950 is sending data using SPIN
# Node 951 is sending data using Camellia
# Node 951 is sending data using LwM2M
# Node 951 is sending data using LEACH
# Node 951 is sending data using SPIN
# Node 952 is sending data using Camellia
# Node 952 is sending data using LwM2M
# Node 952 is sending data using LEACH
# Node 952 is sending data using SPIN
# Node 953 is sending data using Camellia
# Node 953 is sending data using LwM2M
# Node 953 is sending data using LEACH
# Node 953 is sending data using SPIN
# Node 954 is sending data using Camellia
# Node 954 is sending data using LwM2M
# Node 954 is sending data using LEACH
# Node 954 is sending data using SPIN
# Node 955 is sending data using Camellia
# Node 955 is sending data using LwM2M
# Node 955 is sending data using LEACH
# Node 955 is sending data using SPIN
# Node 956 is sending data using Camellia
# Node 956 is sending data using LwM2M
# Node 956 is sending data using LEACH
# Node 956 is sending data using SPIN
# Node 957 is sending data using Camellia
# Node 957 is sending data using LwM2M
# Node 957 is sending data using LEACH
# Node 957 is sending data using SPIN
# Node 958 is sending data using Camellia
# Node 958 is sending data using LwM2M
# Node 958 is sending data using LEACH
# Node 958 is sending data using SPIN
# Node 959 is sending data using Camellia
# Node 959 is sending data using LwM2M
# Node 959 is sending data using LEACH
# Node 959 is sending data using SPIN
# Node 960 is sending data using Camellia
# Node 960 is sending data using LwM2M
# Node 960 is sending data using LEACH
# Node 960 is sending data using SPIN
# Node 961 is sending data using Camellia
# Node 961 is sending data using LwM2M
# Node 961 is sending data using LEACH
# Node 961 is sending data using SPIN
# Node 962 is sending data using Camellia
# Node 962 is sending data using LwM2M
# Node 962 is sending data using LEACH
# Node 962 is sending data using SPIN
# Node 963 is sending data using Camellia
# Node 963 is sending data using LwM2M
# Node 963 is sending data using LEACH
# Node 963 is sending data using SPIN
# Node 964 is sending data using Camellia
# Node 964 is sending data using LwM2M
# Node 964 is sending data using LEACH
# Node 964 is sending data using SPIN
# Node 965 is sending data using Camellia
# Node 965 is sending data using LwM2M
# Node 965 is sending data using LEACH
# Node 965 is sending data using SPIN
# Node 966 is sending data using Camellia
# Node 966 is sending data using LwM2M
# Node 966 is sending data using LEACH
# Node 966 is sending data using SPIN
# Node 967 is sending data using Camellia
# Node 967 is sending data using LwM2M
# Node 967 is sending data using LEACH
# Node 967 is sending data using SPIN
# Node 968 is sending data using Camellia
# Node 968 is sending data using LwM2M
# Node 968 is sending data using LEACH
# Node 968 is sending data using SPIN
# Node 969 is sending data using Camellia
# Node 969 is sending data using LwM2M
# Node 969 is sending data using LEACH
# Node 969 is sending data using SPIN
# Node 970 is sending data using Camellia
# Node 970 is sending data using LwM2M
# Node 970 is sending data using LEACH
# Node 970 is sending data using SPIN
# Node 971 is sending data using Camellia
# Node 971 is sending data using LwM2M
# Node 971 is sending data using LEACH
# Node 971 is sending data using SPIN
# Node 972 is sending data using Camellia
# Node 972 is sending data using LwM2M
# Node 972 is sending data using LEACH
# Node 972 is sending data using SPIN
# Node 973 is sending data using Camellia
# Node 973 is sending data using LwM2M
# Node 973 is sending data using LEACH
# Node 973 is sending data using SPIN
# Node 974 is sending data using Camellia
# Node 974 is sending data using LwM2M
# Node 974 is sending data using LEACH
# Node 974 is sending data using SPIN
# Node 975 is sending data using Camellia
# Node 975 is sending data using LwM2M
# Node 975 is sending data using LEACH
# Node 975 is sending data using SPIN
# Node 976 is sending data using Camellia
# Node 976 is sending data using LwM2M
# Node 976 is sending data using LEACH
# Node 976 is sending data using SPIN
# Node 977 is sending data using Camellia
# Node 977 is sending data using LwM2M
# Node 977 is sending data using LEACH
# Node 977 is sending data using SPIN
# Node 978 is sending data using Camellia
# Node 978 is sending data using LwM2M
# Node 978 is sending data using LEACH
# Node 978 is sending data using SPIN
# Node 979 is sending data using Camellia
# Node 979 is sending data using LwM2M
# Node 979 is sending data using LEACH
# Node 979 is sending data using SPIN
# Node 980 is sending data using Camellia
# Node 980 is sending data using LwM2M
# Node 980 is sending data using LEACH
# Node 980 is sending data using SPIN
# Node 981 is sending data using Camellia
# Node 981 is sending data using LwM2M
# Node 981 is sending data using LEACH
# Node 981 is sending data using SPIN
# Node 982 is sending data using Camellia
# Node 982 is sending data using LwM2M
# Node 982 is sending data using LEACH
# Node 982 is sending data using SPIN
# Node 983 is sending data using Camellia
# Node 983 is sending data using LwM2M
# Node 983 is sending data using LEACH
# Node 983 is sending data using SPIN
# Node 984 is sending data using Camellia
# Node 984 is sending data using LwM2M
# Node 984 is sending data using LEACH
# Node 984 is sending data using SPIN
# Node 985 is sending data using Camellia
# Node 985 is sending data using LwM2M
# Node 985 is sending data using LEACH
# Node 985 is sending data using SPIN
# Node 986 is sending data using Camellia
# Node 986 is sending data using LwM2M
# Node 986 is sending data using LEACH
# Node 986 is sending data using SPIN
# Node 987 is sending data using Camellia
# Node 987 is sending data using LwM2M
# Node 987 is sending data using LEACH
# Node 987 is sending data using SPIN
# Node 988 is sending data using Camellia
# Node 988 is sending data using LwM2M
# Node 988 is sending data using LEACH
# Node 988 is sending data using SPIN
# Node 989 is sending data using Camellia
# Node 989 is sending data using LwM2M
# Node 989 is sending data using LEACH
# Node 989 is sending data using SPIN
# Node 990 is sending data using Camellia
# Node 990 is sending data using LwM2M
# Node 990 is sending data using LEACH
# Node 990 is sending data using SPIN
# Node 991 is sending data using Camellia
# Node 991 is sending data using LwM2M
# Node 991 is sending data using LEACH
# Node 991 is sending data using SPIN
# Node 992 is sending data using Camellia
# Node 992 is sending data using LwM2M
# Node 992 is sending data using LEACH
# Node 992 is sending data using SPIN
# Node 993 is sending data using Camellia
# Node 993 is sending data using LwM2M
# Node 993 is sending data using LEACH
# Node 993 is sending data using SPIN
# Node 994 is sending data using Camellia
# Node 994 is sending data using LwM2M
# Node 994 is sending data using LEACH
# Node 994 is sending data using SPIN
# Node 995 is sending data using Camellia
# Node 995 is sending data using LwM2M
# Node 995 is sending data using LEACH
# Node 995 is sending data using SPIN
# Node 996 is sending data using Camellia
# Node 996 is sending data using LwM2M
# Node 996 is sending data using LEACH
# Node 996 is sending data using SPIN
# Node 997 is sending data using Camellia
# Node 997 is sending data using LwM2M
# Node 997 is sending data using LEACH
# Node 997 is sending data using SPIN
# Node 998 is sending data using Camellia
# Node 998 is sending data using LwM2M
# Node 998 is sending data using LEACH
# Node 998 is sending data using SPIN
# Node 999 is sending data using Camellia
# Node 999 is sending data using LwM2M
# Node 999 is sending data using LEACH
# Node 999 is sending data using SPIN
# Node 1000 is sending data using Camellia
# Node 1000 is sending data using LwM2M
# Node 1000 is sending data using LEACH
# Node 1000 is sending data using SPIN

# %%
import random
import matplotlib.pyplot as plt

# Constants for protocols
PROTOCOL_CAMELLIA = "Camellia"
PROTOCOL_LWM2M = "LwM2M"
PROTOCOL_LEACH = "LEACH"
PROTOCOL_SPIN = "SPIN"

# Function to simulate Camellia-specific data transmission
def send_data_camellia(node_id):
    print(f"Node {node_id} is sending data using {PROTOCOL_CAMELLIA}")
    # Simulate energy consumption for Camellia (replace with actual energy calculation)
    energy_consumption_camellia[node_id - 1] += random.uniform(1.0, 3.0)

# Function to simulate LwM2M-specific data transmission
def send_data_lwm2m(node_id):
    print(f"Node {node_id} is sending data using {PROTOCOL_LWM2M}")
    # Simulate energy consumption for LwM2M (replace with actual energy calculation)
    energy_consumption_lwm2m[node_id - 1] += random.uniform(0.5, 2.0)

# Function to simulate LEACH-specific data transmission
def send_data_leach(node_id):
    print(f"Node {node_id} is sending data using {PROTOCOL_LEACH}")
    # Simulate energy consumption for LEACH (replace with actual energy calculation)
    energy_consumption_leach[node_id - 1] += random.uniform(0.7, 2.5)

# Function to simulate SPIN-specific data transmission
def send_data_spin(node_id):
    print(f"Node {node_id} is sending data using {PROTOCOL_SPIN}")
    # Simulate energy consumption for SPIN (replace with actual energy calculation)
    energy_consumption_spin[node_id - 1] += random.uniform(0.6, 2.2)

# Simulated WSN parameters
num_nodes = 10  # Initial number of nodes
max_nodes = 100  # Maximum number of nodes for the simulation

# Lists to store energy consumption data for each protocol
energy_consumption_camellia = [0] * max_nodes
energy_consumption_lwm2m = [0] * max_nodes
energy_consumption_leach = [0] * max_nodes
energy_consumption_spin = [0] * max_nodes

# Lists to store the number of nodes and energy consumption for each protocol
num_nodes_list = []
energy_consumption_camellia_list = []
energy_consumption_lwm2m_list = []
energy_consumption_leach_list = []
energy_consumption_spin_list = []

# Main simulation loop
while num_nodes <= max_nodes:
    for node_id in range(1, num_nodes + 1):
        # Generate random data for the node
        sensor_data = random.randint(0, 100)

        # Determine which protocol to use based on the number of nodes
        if num_nodes <= 25:
            send_data_camellia(node_id)
        elif 25 < num_nodes <= 50:
            send_data_lwm2m(node_id)
        elif 50 < num_nodes <= 75:
            send_data_leach(node_id)
        else:
            send_data_spin(node_id)

    # Calculate total energy consumption for each protocol
    total_energy_consumed_camellia = sum(energy_consumption_camellia[:num_nodes])
    total_energy_consumed_lwm2m = sum(energy_consumption_lwm2m[:num_nodes])
    total_energy_consumed_leach = sum(energy_consumption_leach[:num_nodes])
    total_energy_consumed_spin = sum(energy_consumption_spin[:num_nodes])

    # Store data for plotting
    num_nodes_list.append(num_nodes)
    energy_consumption_camellia_list.append(total_energy_consumed_camellia)
    energy_consumption_lwm2m_list.append(total_energy_consumed_lwm2m)
    energy_consumption_leach_list.append(total_energy_consumed_leach)
    energy_consumption_spin_list.append(total_energy_consumed_spin)

    # Increase the number of nodes (you can adjust this as needed)
    num_nodes += 10

# Plot energy consumption vs. number of nodes for all protocols with the same line style
plt.figure(figsize=(12, 6))

# Plot for Camellia
plt.plot(num_nodes_list, energy_consumption_camellia_list, marker='', linestyle='-', label=PROTOCOL_CAMELLIA, color='b')

# Plot for LwM2M
plt.plot(num_nodes_list, energy_consumption_lwm2m_list, marker='', linestyle='-', label=PROTOCOL_LWM2M, color='r')

# Plot for LEACH
plt.plot(num_nodes_list, energy_consumption_leach_list, marker='', linestyle='-', label=PROTOCOL_LEACH, color='g')

# Plot for SPIN
plt.plot(num_nodes_list, energy_consumption_spin_list, marker='', linestyle='-', label=PROTOCOL_SPIN, color='m')

plt.xlabel('Number of Nodes')
plt.ylabel('Total Energy Consumption')
plt.grid(True)
plt.legend()
plt.title('Energy Consumption vs. Number of Nodes')

# Show the combined plot
plt.show()
# Out:
# Node 1 is sending data using Camellia
# Node 2 is sending data using Camellia
# Node 3 is sending data using Camellia
# Node 4 is sending data using Camellia
# Node 5 is sending data using Camellia
# Node 6 is sending data using Camellia
# Node 7 is sending data using Camellia
# Node 8 is sending data using Camellia
# Node 9 is sending data using Camellia
# Node 10 is sending data using Camellia
# Node 1 is sending data using Camellia
# Node 2 is sending data using Camellia
# Node 3 is sending data using Camellia
# Node 4 is sending data using Camellia
# Node 5 is sending data using Camellia
# Node 6 is sending data using Camellia
# Node 7 is sending data using Camellia
# Node 8 is sending data using Camellia
# Node 9 is sending data using Camellia
# Node 10 is sending data using Camellia
# Node 11 is sending data using Camellia
# Node 12 is sending data using Camellia
# Node 13 is sending data using Camellia
# Node 14 is sending data using Camellia
# Node 15 is sending data using Camellia
# Node 16 is sending data using Camellia
# Node 17 is sending data using Camellia
# Node 18 is sending data using Camellia
# Node 19 is sending data using Camellia
# Node 20 is sending data using Camellia
# Node 1 is sending data using LwM2M
# Node 2 is sending data using LwM2M
# Node 3 is sending data using LwM2M
# Node 4 is sending data using LwM2M
# Node 5 is sending data using LwM2M
# Node 6 is sending data using LwM2M
# Node 7 is sending data using LwM2M
# Node 8 is sending data using LwM2M
# Node 9 is sending data using LwM2M
# Node 10 is sending data using LwM2M
# Node 11 is sending data using LwM2M
# Node 12 is sending data using LwM2M
# Node 13 is sending data using LwM2M
# Node 14 is sending data using LwM2M
# Node 15 is sending data using LwM2M
# Node 16 is sending data using LwM2M
# Node 17 is sending data using LwM2M
# Node 18 is sending data using LwM2M
# Node 19 is sending data using LwM2M
# Node 20 is sending data using LwM2M
# Node 21 is sending data using LwM2M
# Node 22 is sending data using LwM2M
# Node 23 is sending data using LwM2M
# Node 24 is sending data using LwM2M
# Node 25 is sending data using LwM2M
# Node 26 is sending data using LwM2M
# Node 27 is sending data using LwM2M
# Node 28 is sending data using LwM2M
# Node 29 is sending data using LwM2M
# Node 30 is sending data using LwM2M
# Node 1 is sending data using LwM2M
# Node 2 is sending data using LwM2M
# Node 3 is sending data using LwM2M
# Node 4 is sending data using LwM2M
# Node 5 is sending data using LwM2M
# Node 6 is sending data using LwM2M
# Node 7 is sending data using LwM2M
# Node 8 is sending data using LwM2M
# Node 9 is sending data using LwM2M
# Node 10 is sending data using LwM2M
# Node 11 is sending data using LwM2M
# Node 12 is sending data using LwM2M
# Node 13 is sending data using LwM2M
# Node 14 is sending data using LwM2M
# Node 15 is sending data using LwM2M
# Node 16 is sending data using LwM2M
# Node 17 is sending data using LwM2M
# Node 18 is sending data using LwM2M
# Node 19 is sending data using LwM2M
# Node 20 is sending data using LwM2M
# Node 21 is sending data using LwM2M
# Node 22 is sending data using LwM2M
# Node 23 is sending data using LwM2M
# Node 24 is sending data using LwM2M
# Node 25 is sending data using LwM2M
# Node 26 is sending data using LwM2M
# Node 27 is sending data using LwM2M
# Node 28 is sending data using LwM2M
# Node 29 is sending data using LwM2M
# Node 30 is sending data using LwM2M
# Node 31 is sending data using LwM2M
# Node 32 is sending data using LwM2M
# Node 33 is sending data using LwM2M
# Node 34 is sending data using LwM2M
# Node 35 is sending data using LwM2M
# Node 36 is sending data using LwM2M
# Node 37 is sending data using LwM2M
# Node 38 is sending data using LwM2M
# Node 39 is sending data using LwM2M
# Node 40 is sending data using LwM2M
# Node 1 is sending data using LwM2M
# Node 2 is sending data using LwM2M
# Node 3 is sending data using LwM2M
# Node 4 is sending data using LwM2M
# Node 5 is sending data using LwM2M
# Node 6 is sending data using LwM2M
# Node 7 is sending data using LwM2M
# Node 8 is sending data using LwM2M
# Node 9 is sending data using LwM2M
# Node 10 is sending data using LwM2M
# Node 11 is sending data using LwM2M
# Node 12 is sending data using LwM2M
# Node 13 is sending data using LwM2M
# Node 14 is sending data using LwM2M
# Node 15 is sending data using LwM2M
# Node 16 is sending data using LwM2M
# Node 17 is sending data using LwM2M
# Node 18 is sending data using LwM2M
# Node 19 is sending data using LwM2M
# Node 20 is sending data using LwM2M
# Node 21 is sending data using LwM2M
# Node 22 is sending data using LwM2M
# Node 23 is sending data using LwM2M
# Node 24 is sending data using LwM2M
# Node 25 is sending data using LwM2M
# Node 26 is sending data using LwM2M
# Node 27 is sending data using LwM2M
# Node 28 is sending data using LwM2M
# Node 29 is sending data using LwM2M
# Node 30 is sending data using LwM2M
# Node 31 is sending data using LwM2M
# Node 32 is sending data using LwM2M
# Node 33 is sending data using LwM2M
# Node 34 is sending data using LwM2M
# Node 35 is sending data using LwM2M
# Node 36 is sending data using LwM2M
# Node 37 is sending data using LwM2M
# Node 38 is sending data using LwM2M
# Node 39 is sending data using LwM2M
# Node 40 is sending data using LwM2M
# Node 41 is sending data using LwM2M
# Node 42 is sending data using LwM2M
# Node 43 is sending data using LwM2M
# Node 44 is sending data using LwM2M
# Node 45 is sending data using LwM2M
# Node 46 is sending data using LwM2M
# Node 47 is sending data using LwM2M
# Node 48 is sending data using LwM2M
# Node 49 is sending data using LwM2M
# Node 50 is sending data using LwM2M
# Node 1 is sending data using LEACH
# Node 2 is sending data using LEACH
# Node 3 is sending data using LEACH
# Node 4 is sending data using LEACH
# Node 5 is sending data using LEACH
# Node 6 is sending data using LEACH
# Node 7 is sending data using LEACH
# Node 8 is sending data using LEACH
# Node 9 is sending data using LEACH
# Node 10 is sending data using LEACH
# Node 11 is sending data using LEACH
# Node 12 is sending data using LEACH
# Node 13 is sending data using LEACH
# Node 14 is sending data using LEACH
# Node 15 is sending data using LEACH
# Node 16 is sending data using LEACH
# Node 17 is sending data using LEACH
# Node 18 is sending data using LEACH
# Node 19 is sending data using LEACH
# Node 20 is sending data using LEACH
# Node 21 is sending data using LEACH
# Node 22 is sending data using LEACH
# Node 23 is sending data using LEACH
# Node 24 is sending data using LEACH
# Node 25 is sending data using LEACH
# Node 26 is sending data using LEACH
# Node 27 is sending data using LEACH
# Node 28 is sending data using LEACH
# Node 29 is sending data using LEACH
# Node 30 is sending data using LEACH
# Node 31 is sending data using LEACH
# Node 32 is sending data using LEACH
# Node 33 is sending data using LEACH
# Node 34 is sending data using LEACH
# Node 35 is sending data using LEACH
# Node 36 is sending data using LEACH
# Node 37 is sending data using LEACH
# Node 38 is sending data using LEACH
# Node 39 is sending data using LEACH
# Node 40 is sending data using LEACH
# Node 41 is sending data using LEACH
# Node 42 is sending data using LEACH
# Node 43 is sending data using LEACH
# Node 44 is sending data using LEACH
# Node 45 is sending data using LEACH
# Node 46 is sending data using LEACH
# Node 47 is sending data using LEACH
# Node 48 is sending data using LEACH
# Node 49 is sending data using LEACH
# Node 50 is sending data using LEACH
# Node 51 is sending data using LEACH
# Node 52 is sending data using LEACH
# Node 53 is sending data using LEACH
# Node 54 is sending data using LEACH
# Node 55 is sending data using LEACH
# Node 56 is sending data using LEACH
# Node 57 is sending data using LEACH
# Node 58 is sending data using LEACH
# Node 59 is sending data using LEACH
# Node 60 is sending data using LEACH
# Node 1 is sending data using LEACH
# Node 2 is sending data using LEACH
# Node 3 is sending data using LEACH
# Node 4 is sending data using LEACH
# Node 5 is sending data using LEACH
# Node 6 is sending data using LEACH
# Node 7 is sending data using LEACH
# Node 8 is sending data using LEACH
# Node 9 is sending data using LEACH
# Node 10 is sending data using LEACH
# Node 11 is sending data using LEACH
# Node 12 is sending data using LEACH
# Node 13 is sending data using LEACH
# Node 14 is sending data using LEACH
# Node 15 is sending data using LEACH
# Node 16 is sending data using LEACH
# Node 17 is sending data using LEACH
# Node 18 is sending data using LEACH
# Node 19 is sending data using LEACH
# Node 20 is sending data using LEACH
# Node 21 is sending data using LEACH
# Node 22 is sending data using LEACH
# Node 23 is sending data using LEACH
# Node 24 is sending data using LEACH
# Node 25 is sending data using LEACH
# Node 26 is sending data using LEACH
# Node 27 is sending data using LEACH
# Node 28 is sending data using LEACH
# Node 29 is sending data using LEACH
# Node 30 is sending data using LEACH
# Node 31 is sending data using LEACH
# Node 32 is sending data using LEACH
# Node 33 is sending data using LEACH
# Node 34 is sending data using LEACH
# Node 35 is sending data using LEACH
# Node 36 is sending data using LEACH
# Node 37 is sending data using LEACH
# Node 38 is sending data using LEACH
# Node 39 is sending data using LEACH
# Node 40 is sending data using LEACH
# Node 41 is sending data using LEACH
# Node 42 is sending data using LEACH
# Node 43 is sending data using LEACH
# Node 44 is sending data using LEACH
# Node 45 is sending data using LEACH
# Node 46 is sending data using LEACH
# Node 47 is sending data using LEACH
# Node 48 is sending data using LEACH
# Node 49 is sending data using LEACH
# Node 50 is sending data using LEACH
# Node 51 is sending data using LEACH
# Node 52 is sending data using LEACH
# Node 53 is sending data using LEACH
# Node 54 is sending data using LEACH
# Node 55 is sending data using LEACH
# Node 56 is sending data using LEACH
# Node 57 is sending data using LEACH
# Node 58 is sending data using LEACH
# Node 59 is sending data using LEACH
# Node 60 is sending data using LEACH
# Node 61 is sending data using LEACH
# Node 62 is sending data using LEACH
# Node 63 is sending data using LEACH
# Node 64 is sending data using LEACH
# Node 65 is sending data using LEACH
# Node 66 is sending data using LEACH
# Node 67 is sending data using LEACH
# Node 68 is sending data using LEACH
# Node 69 is sending data using LEACH
# Node 70 is sending data using LEACH
# Node 1 is sending data using SPIN
# Node 2 is sending data using SPIN
# Node 3 is sending data using SPIN
# Node 4 is sending data using SPIN
# Node 5 is sending data using SPIN
# Node 6 is sending data using SPIN
# Node 7 is sending data using SPIN
# Node 8 is sending data using SPIN
# Node 9 is sending data using SPIN
# Node 10 is sending data using SPIN
# Node 11 is sending data using SPIN
# Node 12 is sending data using SPIN
# Node 13 is sending data using SPIN
# Node 14 is sending data using SPIN
# Node 15 is sending data using SPIN
# Node 16 is sending data using SPIN
# Node 17 is sending data using SPIN
# Node 18 is sending data using SPIN
# Node 19 is sending data using SPIN
# Node 20 is sending data using SPIN
# Node 21 is sending data using SPIN
# Node 22 is sending data using SPIN
# Node 23 is sending data using SPIN
# Node 24 is sending data using SPIN
# Node 25 is sending data using SPIN
# Node 26 is sending data using SPIN
# Node 27 is sending data using SPIN
# Node 28 is sending data using SPIN
# Node 29 is sending data using SPIN
# Node 30 is sending data using SPIN
# Node 31 is sending data using SPIN
# Node 32 is sending data using SPIN
# Node 33 is sending data using SPIN
# Node 34 is sending data using SPIN
# Node 35 is sending data using SPIN
# Node 36 is sending data using SPIN
# Node 37 is sending data using SPIN
# Node 38 is sending data using SPIN
# Node 39 is sending data using SPIN
# Node 40 is sending data using SPIN
# Node 41 is sending data using SPIN
# Node 42 is sending data using SPIN
# Node 43 is sending data using SPIN
# Node 44 is sending data using SPIN
# Node 45 is sending data using SPIN
# Node 46 is sending data using SPIN
# Node 47 is sending data using SPIN
# Node 48 is sending data using SPIN
# Node 49 is sending data using SPIN
# Node 50 is sending data using SPIN
# Node 51 is sending data using SPIN
# Node 52 is sending data using SPIN
# Node 53 is sending data using SPIN
# Node 54 is sending data using SPIN
# Node 55 is sending data using SPIN
# Node 56 is sending data using SPIN
# Node 57 is sending data using SPIN
# Node 58 is sending data using SPIN
# Node 59 is sending data using SPIN
# Node 60 is sending data using SPIN
# Node 61 is sending data using SPIN
# Node 62 is sending data using SPIN
# Node 63 is sending data using SPIN
# Node 64 is sending data using SPIN
# Node 65 is sending data using SPIN
# Node 66 is sending data using SPIN
# Node 67 is sending data using SPIN
# Node 68 is sending data using SPIN
# Node 69 is sending data using SPIN
# Node 70 is sending data using SPIN
# Node 71 is sending data using SPIN
# Node 72 is sending data using SPIN
# Node 73 is sending data using SPIN
# Node 74 is sending data using SPIN
# Node 75 is sending data using SPIN
# Node 76 is sending data using SPIN
# Node 77 is sending data using SPIN
# Node 78 is sending data using SPIN
# Node 79 is sending data using SPIN
# Node 80 is sending data using SPIN
# Node 1 is sending data using SPIN
# Node 2 is sending data using SPIN
# Node 3 is sending data using SPIN
# Node 4 is sending data using SPIN
# Node 5 is sending data using SPIN
# Node 6 is sending data using SPIN
# Node 7 is sending data using SPIN
# Node 8 is sending data using SPIN
# Node 9 is sending data using SPIN
# Node 10 is sending data using SPIN
# Node 11 is sending data using SPIN
# Node 12 is sending data using SPIN
# Node 13 is sending data using SPIN
# Node 14 is sending data using SPIN
# Node 15 is sending data using SPIN
# Node 16 is sending data using SPIN
# Node 17 is sending data using SPIN
# Node 18 is sending data using SPIN
# Node 19 is sending data using SPIN
# Node 20 is sending data using SPIN
# Node 21 is sending data using SPIN
# Node 22 is sending data using SPIN
# Node 23 is sending data using SPIN
# Node 24 is sending data using SPIN
# Node 25 is sending data using SPIN
# Node 26 is sending data using SPIN
# Node 27 is sending data using SPIN
# Node 28 is sending data using SPIN
# Node 29 is sending data using SPIN
# Node 30 is sending data using SPIN
# Node 31 is sending data using SPIN
# Node 32 is sending data using SPIN
# Node 33 is sending data using SPIN
# Node 34 is sending data using SPIN
# Node 35 is sending data using SPIN
# Node 36 is sending data using SPIN
# Node 37 is sending data using SPIN
# Node 38 is sending data using SPIN
# Node 39 is sending data using SPIN
# Node 40 is sending data using SPIN
# Node 41 is sending data using SPIN
# Node 42 is sending data using SPIN
# Node 43 is sending data using SPIN
# Node 44 is sending data using SPIN
# Node 45 is sending data using SPIN
# Node 46 is sending data using SPIN
# Node 47 is sending data using SPIN
# Node 48 is sending data using SPIN
# Node 49 is sending data using SPIN
# Node 50 is sending data using SPIN
# Node 51 is sending data using SPIN
# Node 52 is sending data using SPIN
# Node 53 is sending data using SPIN
# Node 54 is sending data using SPIN
# Node 55 is sending data using SPIN
# Node 56 is sending data using SPIN
# Node 57 is sending data using SPIN
# Node 58 is sending data using SPIN
# Node 59 is sending data using SPIN
# Node 60 is sending data using SPIN
# Node 61 is sending data using SPIN
# Node 62 is sending data using SPIN
# Node 63 is sending data using SPIN
# Node 64 is sending data using SPIN
# Node 65 is sending data using SPIN
# Node 66 is sending data using SPIN
# Node 67 is sending data using SPIN
# Node 68 is sending data using SPIN
# Node 69 is sending data using SPIN
# Node 70 is sending data using SPIN
# Node 71 is sending data using SPIN
# Node 72 is sending data using SPIN
# Node 73 is sending data using SPIN
# Node 74 is sending data using SPIN
# Node 75 is sending data using SPIN
# Node 76 is sending data using SPIN
# Node 77 is sending data using SPIN
# Node 78 is sending data using SPIN
# Node 79 is sending data using SPIN
# Node 80 is sending data using SPIN
# Node 81 is sending data using SPIN
# Node 82 is sending data using SPIN
# Node 83 is sending data using SPIN
# Node 84 is sending data using SPIN
# Node 85 is sending data using SPIN
# Node 86 is sending data using SPIN
# Node 87 is sending data using SPIN
# Node 88 is sending data using SPIN
# Node 89 is sending data using SPIN
# Node 90 is sending data using SPIN
# Node 1 is sending data using SPIN
# Node 2 is sending data using SPIN
# Node 3 is sending data using SPIN
# Node 4 is sending data using SPIN
# Node 5 is sending data using SPIN
# Node 6 is sending data using SPIN
# Node 7 is sending data using SPIN
# Node 8 is sending data using SPIN
# Node 9 is sending data using SPIN
# Node 10 is sending data using SPIN
# Node 11 is sending data using SPIN
# Node 12 is sending data using SPIN
# Node 13 is sending data using SPIN
# Node 14 is sending data using SPIN
# Node 15 is sending data using SPIN
# Node 16 is sending data using SPIN
# Node 17 is sending data using SPIN
# Node 18 is sending data using SPIN
# Node 19 is sending data using SPIN
# Node 20 is sending data using SPIN
# Node 21 is sending data using SPIN
# Node 22 is sending data using SPIN
# Node 23 is sending data using SPIN
# Node 24 is sending data using SPIN
# Node 25 is sending data using SPIN
# Node 26 is sending data using SPIN
# Node 27 is sending data using SPIN
# Node 28 is sending data using SPIN
# Node 29 is sending data using SPIN
# Node 30 is sending data using SPIN
# Node 31 is sending data using SPIN
# Node 32 is sending data using SPIN
# Node 33 is sending data using SPIN
# Node 34 is sending data using SPIN
# Node 35 is sending data using SPIN
# Node 36 is sending data using SPIN
# Node 37 is sending data using SPIN
# Node 38 is sending data using SPIN
# Node 39 is sending data using SPIN
# Node 40 is sending data using SPIN
# Node 41 is sending data using SPIN
# Node 42 is sending data using SPIN
# Node 43 is sending data using SPIN
# Node 44 is sending data using SPIN
# Node 45 is sending data using SPIN
# Node 46 is sending data using SPIN
# Node 47 is sending data using SPIN
# Node 48 is sending data using SPIN
# Node 49 is sending data using SPIN
# Node 50 is sending data using SPIN
# Node 51 is sending data using SPIN
# Node 52 is sending data using SPIN
# Node 53 is sending data using SPIN
# Node 54 is sending data using SPIN
# Node 55 is sending data using SPIN
# Node 56 is sending data using SPIN
# Node 57 is sending data using SPIN
# Node 58 is sending data using SPIN
# Node 59 is sending data using SPIN
# Node 60 is sending data using SPIN
# Node 61 is sending data using SPIN
# Node 62 is sending data using SPIN
# Node 63 is sending data using SPIN
# Node 64 is sending data using SPIN
# Node 65 is sending data using SPIN
# Node 66 is sending data using SPIN
# Node 67 is sending data using SPIN
# Node 68 is sending data using SPIN
# Node 69 is sending data using SPIN
# Node 70 is sending data using SPIN
# Node 71 is sending data using SPIN
# Node 72 is sending data using SPIN
# Node 73 is sending data using SPIN
# Node 74 is sending data using SPIN
# Node 75 is sending data using SPIN
# Node 76 is sending data using SPIN
# Node 77 is sending data using SPIN
# Node 78 is sending data using SPIN
# Node 79 is sending data using SPIN
# Node 80 is sending data using SPIN
# Node 81 is sending data using SPIN
# Node 82 is sending data using SPIN
# Node 83 is sending data using SPIN
# Node 84 is sending data using SPIN
# Node 85 is sending data using SPIN
# Node 86 is sending data using SPIN
# Node 87 is sending data using SPIN
# Node 88 is sending data using SPIN
# Node 89 is sending data using SPIN
# Node 90 is sending data using SPIN
# Node 91 is sending data using SPIN
# Node 92 is sending data using SPIN
# Node 93 is sending data using SPIN
# Node 94 is sending data using SPIN
# Node 95 is sending data using SPIN
# Node 96 is sending data using SPIN
# Node 97 is sending data using SPIN
# Node 98 is sending data using SPIN
# Node 99 is sending data using SPIN
# Node 100 is sending data using SPIN

# %%
import random
import matplotlib.pyplot as plt

# Constants for protocols
PROTOCOL_CAMELLIA = "Camellia"
PROTOCOL_LWM2M = "LwM2M"
PROTOCOL_LEACH = "LEACH"
PROTOCOL_SPIN = "SPIN"

# Function to simulate Camellia-specific data transmission
def send_data_camellia(node_id):
    print(f"Node {node_id} is sending data using {PROTOCOL_CAMELLIA}")
    # Simulate energy consumption for Camellia (replace with actual energy calculation)
    energy_consumption_camellia[node_id - 1] += random.uniform(1.0, 3.0)

# Function to simulate LwM2M-specific data transmission
def send_data_lwm2m(node_id):
    print(f"Node {node_id} is sending data using {PROTOCOL_LWM2M}")
    # Simulate energy consumption for LwM2M (replace with actual energy calculation)
    energy_consumption_lwm2m[node_id - 1] += random.uniform(0.5, 2.0)

# Function to simulate LEACH-specific data transmission
def send_data_leach(node_id):
    print(f"Node {node_id} is sending data using {PROTOCOL_LEACH}")
    # Simulate energy consumption for LEACH (replace with actual energy calculation)
    energy_consumption_leach[node_id - 1] += random.uniform(0.7, 2.5)

# Function to simulate SPIN-specific data transmission
def send_data_spin(node_id):
    print(f"Node {node_id} is sending data using {PROTOCOL_SPIN}")
    # Simulate energy consumption for SPIN (replace with actual energy calculation)
    energy_consumption_spin[node_id - 1] += random.uniform(0.6, 2.2)

# Simulated WSN parameters
num_nodes = 10  # Initial number of nodes
max_nodes = 100  # Maximum number of nodes for the simulation

# Lists to store energy consumption data for each protocol
energy_consumption_camellia = [0] * max_nodes
energy_consumption_lwm2m = [0] * max_nodes
energy_consumption_leach = [0] * max_nodes
energy_consumption_spin = [0] * max_nodes

# Lists to store the number of nodes and energy consumption for each protocol
num_nodes_list = []
energy_consumption_camellia_list = []
energy_consumption_lwm2m_list = []
energy_consumption_leach_list = []
energy_consumption_spin_list = []

# Main simulation loop
while num_nodes <= max_nodes:
    for node_id in range(1, num_nodes + 1):
        # Generate random data for the node
        sensor_data = random.randint(0, 100)

        # Determine which protocol to use based on the number of nodes
        
        send_data_camellia(node_id)
        send_data_lwm2m(node_id)
        send_data_leach(node_id)
        send_data_spin(node_id)

    # Calculate total energy consumption for each protocol
    total_energy_consumed_camellia = sum(energy_consumption_camellia[:num_nodes])
    total_energy_consumed_lwm2m = sum(energy_consumption_lwm2m[:num_nodes])
    total_energy_consumed_leach = sum(energy_consumption_leach[:num_nodes])
    total_energy_consumed_spin = sum(energy_consumption_spin[:num_nodes])

    # Store data for plotting
    num_nodes_list.append(num_nodes)
    energy_consumption_camellia_list.append(total_energy_consumed_camellia)
    energy_consumption_lwm2m_list.append(total_energy_consumed_lwm2m)
    energy_consumption_leach_list.append(total_energy_consumed_leach)
    energy_consumption_spin_list.append(total_energy_consumed_spin)

    # Increase the number of nodes (you can adjust this as needed)
    num_nodes += 10

# Plot energy consumption vs. number of nodes for all protocols
plt.figure(figsize=(12, 6))

# Plot for Camellia
plt.plot(num_nodes_list, energy_consumption_camellia_list, marker='o', linestyle='-', label=PROTOCOL_CAMELLIA, color='b')

# Plot for LwM2M
plt.plot(num_nodes_list, energy_consumption_lwm2m_list, marker='s', linestyle='-', label=PROTOCOL_LWM2M, color='r')

# Plot for LEACH
plt.plot(num_nodes_list, energy_consumption_leach_list, marker='^', linestyle='-', label=PROTOCOL_LEACH, color='g')

# Plot for SPIN
plt.plot(num_nodes_list, energy_consumption_spin_list, marker='x', linestyle='-', label=PROTOCOL_SPIN, color='m')

plt.xlabel('Number of Nodes')
plt.ylabel('Total Energy Consumption')
plt.grid(True)
plt.legend()
plt.title('Energy Consumption vs. Number of Nodes')

# Show the combined plot
plt.show()
# Out:
# Node 1 is sending data using Camellia
# Node 1 is sending data using LwM2M
# Node 1 is sending data using LEACH
# Node 1 is sending data using SPIN
# Node 2 is sending data using Camellia
# Node 2 is sending data using LwM2M
# Node 2 is sending data using LEACH
# Node 2 is sending data using SPIN
# Node 3 is sending data using Camellia
# Node 3 is sending data using LwM2M
# Node 3 is sending data using LEACH
# Node 3 is sending data using SPIN
# Node 4 is sending data using Camellia
# Node 4 is sending data using LwM2M
# Node 4 is sending data using LEACH
# Node 4 is sending data using SPIN
# Node 5 is sending data using Camellia
# Node 5 is sending data using LwM2M
# Node 5 is sending data using LEACH
# Node 5 is sending data using SPIN
# Node 6 is sending data using Camellia
# Node 6 is sending data using LwM2M
# Node 6 is sending data using LEACH
# Node 6 is sending data using SPIN
# Node 7 is sending data using Camellia
# Node 7 is sending data using LwM2M
# Node 7 is sending data using LEACH
# Node 7 is sending data using SPIN
# Node 8 is sending data using Camellia
# Node 8 is sending data using LwM2M
# Node 8 is sending data using LEACH
# Node 8 is sending data using SPIN
# Node 9 is sending data using Camellia
# Node 9 is sending data using LwM2M
# Node 9 is sending data using LEACH
# Node 9 is sending data using SPIN
# Node 10 is sending data using Camellia
# Node 10 is sending data using LwM2M
# Node 10 is sending data using LEACH
# Node 10 is sending data using SPIN
# Node 1 is sending data using Camellia
# Node 1 is sending data using LwM2M
# Node 1 is sending data using LEACH
# Node 1 is sending data using SPIN
# Node 2 is sending data using Camellia
# Node 2 is sending data using LwM2M
# Node 2 is sending data using LEACH
# Node 2 is sending data using SPIN
# Node 3 is sending data using Camellia
# Node 3 is sending data using LwM2M
# Node 3 is sending data using LEACH
# Node 3 is sending data using SPIN
# Node 4 is sending data using Camellia
# Node 4 is sending data using LwM2M
# Node 4 is sending data using LEACH
# Node 4 is sending data using SPIN
# Node 5 is sending data using Camellia
# Node 5 is sending data using LwM2M
# Node 5 is sending data using LEACH
# Node 5 is sending data using SPIN
# Node 6 is sending data using Camellia
# Node 6 is sending data using LwM2M
# Node 6 is sending data using LEACH
# Node 6 is sending data using SPIN
# Node 7 is sending data using Camellia
# Node 7 is sending data using LwM2M
# Node 7 is sending data using LEACH
# Node 7 is sending data using SPIN
# Node 8 is sending data using Camellia
# Node 8 is sending data using LwM2M
# Node 8 is sending data using LEACH
# Node 8 is sending data using SPIN
# Node 9 is sending data using Camellia
# Node 9 is sending data using LwM2M
# Node 9 is sending data using LEACH
# Node 9 is sending data using SPIN
# Node 10 is sending data using Camellia
# Node 10 is sending data using LwM2M
# Node 10 is sending data using LEACH
# Node 10 is sending data using SPIN
# Node 11 is sending data using Camellia
# Node 11 is sending data using LwM2M
# Node 11 is sending data using LEACH
# Node 11 is sending data using SPIN
# Node 12 is sending data using Camellia
# Node 12 is sending data using LwM2M
# Node 12 is sending data using LEACH
# Node 12 is sending data using SPIN
# Node 13 is sending data using Camellia
# Node 13 is sending data using LwM2M
# Node 13 is sending data using LEACH
# Node 13 is sending data using SPIN
# Node 14 is sending data using Camellia
# Node 14 is sending data using LwM2M
# Node 14 is sending data using LEACH
# Node 14 is sending data using SPIN
# Node 15 is sending data using Camellia
# Node 15 is sending data using LwM2M
# Node 15 is sending data using LEACH
# Node 15 is sending data using SPIN
# Node 16 is sending data using Camellia
# Node 16 is sending data using LwM2M
# Node 16 is sending data using LEACH
# Node 16 is sending data using SPIN
# Node 17 is sending data using Camellia
# Node 17 is sending data using LwM2M
# Node 17 is sending data using LEACH
# Node 17 is sending data using SPIN
# Node 18 is sending data using Camellia
# Node 18 is sending data using LwM2M
# Node 18 is sending data using LEACH
# Node 18 is sending data using SPIN
# Node 19 is sending data using Camellia
# Node 19 is sending data using LwM2M
# Node 19 is sending data using LEACH
# Node 19 is sending data using SPIN
# Node 20 is sending data using Camellia
# Node 20 is sending data using LwM2M
# Node 20 is sending data using LEACH
# Node 20 is sending data using SPIN
# Node 1 is sending data using Camellia
# Node 1 is sending data using LwM2M
# Node 1 is sending data using LEACH
# Node 1 is sending data using SPIN
# Node 2 is sending data using Camellia
# Node 2 is sending data using LwM2M
# Node 2 is sending data using LEACH
# Node 2 is sending data using SPIN
# Node 3 is sending data using Camellia
# Node 3 is sending data using LwM2M
# Node 3 is sending data using LEACH
# Node 3 is sending data using SPIN
# Node 4 is sending data using Camellia
# Node 4 is sending data using LwM2M
# Node 4 is sending data using LEACH
# Node 4 is sending data using SPIN
# Node 5 is sending data using Camellia
# Node 5 is sending data using LwM2M
# Node 5 is sending data using LEACH
# Node 5 is sending data using SPIN
# Node 6 is sending data using Camellia
# Node 6 is sending data using LwM2M
# Node 6 is sending data using LEACH
# Node 6 is sending data using SPIN
# Node 7 is sending data using Camellia
# Node 7 is sending data using LwM2M
# Node 7 is sending data using LEACH
# Node 7 is sending data using SPIN
# Node 8 is sending data using Camellia
# Node 8 is sending data using LwM2M
# Node 8 is sending data using LEACH
# Node 8 is sending data using SPIN
# Node 9 is sending data using Camellia
# Node 9 is sending data using LwM2M
# Node 9 is sending data using LEACH
# Node 9 is sending data using SPIN
# Node 10 is sending data using Camellia
# Node 10 is sending data using LwM2M
# Node 10 is sending data using LEACH
# Node 10 is sending data using SPIN
# Node 11 is sending data using Camellia
# Node 11 is sending data using LwM2M
# Node 11 is sending data using LEACH
# Node 11 is sending data using SPIN
# Node 12 is sending data using Camellia
# Node 12 is sending data using LwM2M
# Node 12 is sending data using LEACH
# Node 12 is sending data using SPIN
# Node 13 is sending data using Camellia
# Node 13 is sending data using LwM2M
# Node 13 is sending data using LEACH
# Node 13 is sending data using SPIN
# Node 14 is sending data using Camellia
# Node 14 is sending data using LwM2M
# Node 14 is sending data using LEACH
# Node 14 is sending data using SPIN
# Node 15 is sending data using Camellia
# Node 15 is sending data using LwM2M
# Node 15 is sending data using LEACH
# Node 15 is sending data using SPIN
# Node 16 is sending data using Camellia
# Node 16 is sending data using LwM2M
# Node 16 is sending data using LEACH
# Node 16 is sending data using SPIN
# Node 17 is sending data using Camellia
# Node 17 is sending data using LwM2M
# Node 17 is sending data using LEACH
# Node 17 is sending data using SPIN
# Node 18 is sending data using Camellia
# Node 18 is sending data using LwM2M
# Node 18 is sending data using LEACH
# Node 18 is sending data using SPIN
# Node 19 is sending data using Camellia
# Node 19 is sending data using LwM2M
# Node 19 is sending data using LEACH
# Node 19 is sending data using SPIN
# Node 20 is sending data using Camellia
# Node 20 is sending data using LwM2M
# Node 20 is sending data using LEACH
# Node 20 is sending data using SPIN
# Node 21 is sending data using Camellia
# Node 21 is sending data using LwM2M
# Node 21 is sending data using LEACH
# Node 21 is sending data using SPIN
# Node 22 is sending data using Camellia
# Node 22 is sending data using LwM2M
# Node 22 is sending data using LEACH
# Node 22 is sending data using SPIN
# Node 23 is sending data using Camellia
# Node 23 is sending data using LwM2M
# Node 23 is sending data using LEACH
# Node 23 is sending data using SPIN
# Node 24 is sending data using Camellia
# Node 24 is sending data using LwM2M
# Node 24 is sending data using LEACH
# Node 24 is sending data using SPIN
# Node 25 is sending data using Camellia
# Node 25 is sending data using LwM2M
# Node 25 is sending data using LEACH
# Node 25 is sending data using SPIN
# Node 26 is sending data using Camellia
# Node 26 is sending data using LwM2M
# Node 26 is sending data using LEACH
# Node 26 is sending data using SPIN
# Node 27 is sending data using Camellia
# Node 27 is sending data using LwM2M
# Node 27 is sending data using LEACH
# Node 27 is sending data using SPIN
# Node 28 is sending data using Camellia
# Node 28 is sending data using LwM2M
# Node 28 is sending data using LEACH
# Node 28 is sending data using SPIN
# Node 29 is sending data using Camellia
# Node 29 is sending data using LwM2M
# Node 29 is sending data using LEACH
# Node 29 is sending data using SPIN
# Node 30 is sending data using Camellia
# Node 30 is sending data using LwM2M
# Node 30 is sending data using LEACH
# Node 30 is sending data using SPIN
# Node 1 is sending data using Camellia
# Node 1 is sending data using LwM2M
# Node 1 is sending data using LEACH
# Node 1 is sending data using SPIN
# Node 2 is sending data using Camellia
# Node 2 is sending data using LwM2M
# Node 2 is sending data using LEACH
# Node 2 is sending data using SPIN
# Node 3 is sending data using Camellia
# Node 3 is sending data using LwM2M
# Node 3 is sending data using LEACH
# Node 3 is sending data using SPIN
# Node 4 is sending data using Camellia
# Node 4 is sending data using LwM2M
# Node 4 is sending data using LEACH
# Node 4 is sending data using SPIN
# Node 5 is sending data using Camellia
# Node 5 is sending data using LwM2M
# Node 5 is sending data using LEACH
# Node 5 is sending data using SPIN
# Node 6 is sending data using Camellia
# Node 6 is sending data using LwM2M
# Node 6 is sending data using LEACH
# Node 6 is sending data using SPIN
# Node 7 is sending data using Camellia
# Node 7 is sending data using LwM2M
# Node 7 is sending data using LEACH
# Node 7 is sending data using SPIN
# Node 8 is sending data using Camellia
# Node 8 is sending data using LwM2M
# Node 8 is sending data using LEACH
# Node 8 is sending data using SPIN
# Node 9 is sending data using Camellia
# Node 9 is sending data using LwM2M
# Node 9 is sending data using LEACH
# Node 9 is sending data using SPIN
# Node 10 is sending data using Camellia
# Node 10 is sending data using LwM2M
# Node 10 is sending data using LEACH
# Node 10 is sending data using SPIN
# Node 11 is sending data using Camellia
# Node 11 is sending data using LwM2M
# Node 11 is sending data using LEACH
# Node 11 is sending data using SPIN
# Node 12 is sending data using Camellia
# Node 12 is sending data using LwM2M
# Node 12 is sending data using LEACH
# Node 12 is sending data using SPIN
# Node 13 is sending data using Camellia
# Node 13 is sending data using LwM2M
# Node 13 is sending data using LEACH
# Node 13 is sending data using SPIN
# Node 14 is sending data using Camellia
# Node 14 is sending data using LwM2M
# Node 14 is sending data using LEACH
# Node 14 is sending data using SPIN
# Node 15 is sending data using Camellia
# Node 15 is sending data using LwM2M
# Node 15 is sending data using LEACH
# Node 15 is sending data using SPIN
# Node 16 is sending data using Camellia
# Node 16 is sending data using LwM2M
# Node 16 is sending data using LEACH
# Node 16 is sending data using SPIN
# Node 17 is sending data using Camellia
# Node 17 is sending data using LwM2M
# Node 17 is sending data using LEACH
# Node 17 is sending data using SPIN
# Node 18 is sending data using Camellia
# Node 18 is sending data using LwM2M
# Node 18 is sending data using LEACH
# Node 18 is sending data using SPIN
# Node 19 is sending data using Camellia
# Node 19 is sending data using LwM2M
# Node 19 is sending data using LEACH
# Node 19 is sending data using SPIN
# Node 20 is sending data using Camellia
# Node 20 is sending data using LwM2M
# Node 20 is sending data using LEACH
# Node 20 is sending data using SPIN
# Node 21 is sending data using Camellia
# Node 21 is sending data using LwM2M
# Node 21 is sending data using LEACH
# Node 21 is sending data using SPIN
# Node 22 is sending data using Camellia
# Node 22 is sending data using LwM2M
# Node 22 is sending data using LEACH
# Node 22 is sending data using SPIN
# Node 23 is sending data using Camellia
# Node 23 is sending data using LwM2M
# Node 23 is sending data using LEACH
# Node 23 is sending data using SPIN
# Node 24 is sending data using Camellia
# Node 24 is sending data using LwM2M
# Node 24 is sending data using LEACH
# Node 24 is sending data using SPIN
# Node 25 is sending data using Camellia
# Node 25 is sending data using LwM2M
# Node 25 is sending data using LEACH
# Node 25 is sending data using SPIN
# Node 26 is sending data using Camellia
# Node 26 is sending data using LwM2M
# Node 26 is sending data using LEACH
# Node 26 is sending data using SPIN
# Node 27 is sending data using Camellia
# Node 27 is sending data using LwM2M
# Node 27 is sending data using LEACH
# Node 27 is sending data using SPIN
# Node 28 is sending data using Camellia
# Node 28 is sending data using LwM2M
# Node 28 is sending data using LEACH
# Node 28 is sending data using SPIN
# Node 29 is sending data using Camellia
# Node 29 is sending data using LwM2M
# Node 29 is sending data using LEACH
# Node 29 is sending data using SPIN
# Node 30 is sending data using Camellia
# Node 30 is sending data using LwM2M
# Node 30 is sending data using LEACH
# Node 30 is sending data using SPIN
# Node 31 is sending data using Camellia
# Node 31 is sending data using LwM2M
# Node 31 is sending data using LEACH
# Node 31 is sending data using SPIN
# Node 32 is sending data using Camellia
# Node 32 is sending data using LwM2M
# Node 32 is sending data using LEACH
# Node 32 is sending data using SPIN
# Node 33 is sending data using Camellia
# Node 33 is sending data using LwM2M
# Node 33 is sending data using LEACH
# Node 33 is sending data using SPIN
# Node 34 is sending data using Camellia
# Node 34 is sending data using LwM2M
# Node 34 is sending data using LEACH
# Node 34 is sending data using SPIN
# Node 35 is sending data using Camellia
# Node 35 is sending data using LwM2M
# Node 35 is sending data using LEACH
# Node 35 is sending data using SPIN
# Node 36 is sending data using Camellia
# Node 36 is sending data using LwM2M
# Node 36 is sending data using LEACH
# Node 36 is sending data using SPIN
# Node 37 is sending data using Camellia
# Node 37 is sending data using LwM2M
# Node 37 is sending data using LEACH
# Node 37 is sending data using SPIN
# Node 38 is sending data using Camellia
# Node 38 is sending data using LwM2M
# Node 38 is sending data using LEACH
# Node 38 is sending data using SPIN
# Node 39 is sending data using Camellia
# Node 39 is sending data using LwM2M
# Node 39 is sending data using LEACH
# Node 39 is sending data using SPIN
# Node 40 is sending data using Camellia
# Node 40 is sending data using LwM2M
# Node 40 is sending data using LEACH
# Node 40 is sending data using SPIN
# Node 1 is sending data using Camellia
# Node 1 is sending data using LwM2M
# Node 1 is sending data using LEACH
# Node 1 is sending data using SPIN
# Node 2 is sending data using Camellia
# Node 2 is sending data using LwM2M
# Node 2 is sending data using LEACH
# Node 2 is sending data using SPIN
# Node 3 is sending data using Camellia
# Node 3 is sending data using LwM2M
# Node 3 is sending data using LEACH
# Node 3 is sending data using SPIN
# Node 4 is sending data using Camellia
# Node 4 is sending data using LwM2M
# Node 4 is sending data using LEACH
# Node 4 is sending data using SPIN
# Node 5 is sending data using Camellia
# Node 5 is sending data using LwM2M
# Node 5 is sending data using LEACH
# Node 5 is sending data using SPIN
# Node 6 is sending data using Camellia
# Node 6 is sending data using LwM2M
# Node 6 is sending data using LEACH
# Node 6 is sending data using SPIN
# Node 7 is sending data using Camellia
# Node 7 is sending data using LwM2M
# Node 7 is sending data using LEACH
# Node 7 is sending data using SPIN
# Node 8 is sending data using Camellia
# Node 8 is sending data using LwM2M
# Node 8 is sending data using LEACH
# Node 8 is sending data using SPIN
# Node 9 is sending data using Camellia
# Node 9 is sending data using LwM2M
# Node 9 is sending data using LEACH
# Node 9 is sending data using SPIN
# Node 10 is sending data using Camellia
# Node 10 is sending data using LwM2M
# Node 10 is sending data using LEACH
# Node 10 is sending data using SPIN
# Node 11 is sending data using Camellia
# Node 11 is sending data using LwM2M
# Node 11 is sending data using LEACH
# Node 11 is sending data using SPIN
# Node 12 is sending data using Camellia
# Node 12 is sending data using LwM2M
# Node 12 is sending data using LEACH
# Node 12 is sending data using SPIN
# Node 13 is sending data using Camellia
# Node 13 is sending data using LwM2M
# Node 13 is sending data using LEACH
# Node 13 is sending data using SPIN
# Node 14 is sending data using Camellia
# Node 14 is sending data using LwM2M
# Node 14 is sending data using LEACH
# Node 14 is sending data using SPIN
# Node 15 is sending data using Camellia
# Node 15 is sending data using LwM2M
# Node 15 is sending data using LEACH
# Node 15 is sending data using SPIN
# Node 16 is sending data using Camellia
# Node 16 is sending data using LwM2M
# Node 16 is sending data using LEACH
# Node 16 is sending data using SPIN
# Node 17 is sending data using Camellia
# Node 17 is sending data using LwM2M
# Node 17 is sending data using LEACH
# Node 17 is sending data using SPIN
# Node 18 is sending data using Camellia
# Node 18 is sending data using LwM2M
# Node 18 is sending data using LEACH
# Node 18 is sending data using SPIN
# Node 19 is sending data using Camellia
# Node 19 is sending data using LwM2M
# Node 19 is sending data using LEACH
# Node 19 is sending data using SPIN
# Node 20 is sending data using Camellia
# Node 20 is sending data using LwM2M
# Node 20 is sending data using LEACH
# Node 20 is sending data using SPIN
# Node 21 is sending data using Camellia
# Node 21 is sending data using LwM2M
# Node 21 is sending data using LEACH
# Node 21 is sending data using SPIN
# Node 22 is sending data using Camellia
# Node 22 is sending data using LwM2M
# Node 22 is sending data using LEACH
# Node 22 is sending data using SPIN
# Node 23 is sending data using Camellia
# Node 23 is sending data using LwM2M
# Node 23 is sending data using LEACH
# Node 23 is sending data using SPIN
# Node 24 is sending data using Camellia
# Node 24 is sending data using LwM2M
# Node 24 is sending data using LEACH
# Node 24 is sending data using SPIN
# Node 25 is sending data using Camellia
# Node 25 is sending data using LwM2M
# Node 25 is sending data using LEACH
# Node 25 is sending data using SPIN
# Node 26 is sending data using Camellia
# Node 26 is sending data using LwM2M
# Node 26 is sending data using LEACH
# Node 26 is sending data using SPIN
# Node 27 is sending data using Camellia
# Node 27 is sending data using LwM2M
# Node 27 is sending data using LEACH
# Node 27 is sending data using SPIN
# Node 28 is sending data using Camellia
# Node 28 is sending data using LwM2M
# Node 28 is sending data using LEACH
# Node 28 is sending data using SPIN
# Node 29 is sending data using Camellia
# Node 29 is sending data using LwM2M
# Node 29 is sending data using LEACH
# Node 29 is sending data using SPIN
# Node 30 is sending data using Camellia
# Node 30 is sending data using LwM2M
# Node 30 is sending data using LEACH
# Node 30 is sending data using SPIN
# Node 31 is sending data using Camellia
# Node 31 is sending data using LwM2M
# Node 31 is sending data using LEACH
# Node 31 is sending data using SPIN
# Node 32 is sending data using Camellia
# Node 32 is sending data using LwM2M
# Node 32 is sending data using LEACH
# Node 32 is sending data using SPIN
# Node 33 is sending data using Camellia
# Node 33 is sending data using LwM2M
# Node 33 is sending data using LEACH
# Node 33 is sending data using SPIN
# Node 34 is sending data using Camellia
# Node 34 is sending data using LwM2M
# Node 34 is sending data using LEACH
# Node 34 is sending data using SPIN
# Node 35 is sending data using Camellia
# Node 35 is sending data using LwM2M
# Node 35 is sending data using LEACH
# Node 35 is sending data using SPIN
# Node 36 is sending data using Camellia
# Node 36 is sending data using LwM2M
# Node 36 is sending data using LEACH
# Node 36 is sending data using SPIN
# Node 37 is sending data using Camellia
# Node 37 is sending data using LwM2M
# Node 37 is sending data using LEACH
# Node 37 is sending data using SPIN
# Node 38 is sending data using Camellia
# Node 38 is sending data using LwM2M
# Node 38 is sending data using LEACH
# Node 38 is sending data using SPIN
# Node 39 is sending data using Camellia
# Node 39 is sending data using LwM2M
# Node 39 is sending data using LEACH
# Node 39 is sending data using SPIN
# Node 40 is sending data using Camellia
# Node 40 is sending data using LwM2M
# Node 40 is sending data using LEACH
# Node 40 is sending data using SPIN
# Node 41 is sending data using Camellia
# Node 41 is sending data using LwM2M
# Node 41 is sending data using LEACH
# Node 41 is sending data using SPIN
# Node 42 is sending data using Camellia
# Node 42 is sending data using LwM2M
# Node 42 is sending data using LEACH
# Node 42 is sending data using SPIN
# Node 43 is sending data using Camellia
# Node 43 is sending data using LwM2M
# Node 43 is sending data using LEACH
# Node 43 is sending data using SPIN
# Node 44 is sending data using Camellia
# Node 44 is sending data using LwM2M
# Node 44 is sending data using LEACH
# Node 44 is sending data using SPIN
# Node 45 is sending data using Camellia
# Node 45 is sending data using LwM2M
# Node 45 is sending data using LEACH
# Node 45 is sending data using SPIN
# Node 46 is sending data using Camellia
# Node 46 is sending data using LwM2M
# Node 46 is sending data using LEACH
# Node 46 is sending data using SPIN
# Node 47 is sending data using Camellia
# Node 47 is sending data using LwM2M
# Node 47 is sending data using LEACH
# Node 47 is sending data using SPIN
# Node 48 is sending data using Camellia
# Node 48 is sending data using LwM2M
# Node 48 is sending data using LEACH
# Node 48 is sending data using SPIN
# Node 49 is sending data using Camellia
# Node 49 is sending data using LwM2M
# Node 49 is sending data using LEACH
# Node 49 is sending data using SPIN
# Node 50 is sending data using Camellia
# Node 50 is sending data using LwM2M
# Node 50 is sending data using LEACH
# Node 50 is sending data using SPIN
# Node 1 is sending data using Camellia
# Node 1 is sending data using LwM2M
# Node 1 is sending data using LEACH
# Node 1 is sending data using SPIN
# Node 2 is sending data using Camellia
# Node 2 is sending data using LwM2M
# Node 2 is sending data using LEACH
# Node 2 is sending data using SPIN
# Node 3 is sending data using Camellia
# Node 3 is sending data using LwM2M
# Node 3 is sending data using LEACH
# Node 3 is sending data using SPIN
# Node 4 is sending data using Camellia
# Node 4 is sending data using LwM2M
# Node 4 is sending data using LEACH
# Node 4 is sending data using SPIN
# Node 5 is sending data using Camellia
# Node 5 is sending data using LwM2M
# Node 5 is sending data using LEACH
# Node 5 is sending data using SPIN
# Node 6 is sending data using Camellia
# Node 6 is sending data using LwM2M
# Node 6 is sending data using LEACH
# Node 6 is sending data using SPIN
# Node 7 is sending data using Camellia
# Node 7 is sending data using LwM2M
# Node 7 is sending data using LEACH
# Node 7 is sending data using SPIN
# Node 8 is sending data using Camellia
# Node 8 is sending data using LwM2M
# Node 8 is sending data using LEACH
# Node 8 is sending data using SPIN
# Node 9 is sending data using Camellia
# Node 9 is sending data using LwM2M
# Node 9 is sending data using LEACH
# Node 9 is sending data using SPIN
# Node 10 is sending data using Camellia
# Node 10 is sending data using LwM2M
# Node 10 is sending data using LEACH
# Node 10 is sending data using SPIN
# Node 11 is sending data using Camellia
# Node 11 is sending data using LwM2M
# Node 11 is sending data using LEACH
# Node 11 is sending data using SPIN
# Node 12 is sending data using Camellia
# Node 12 is sending data using LwM2M
# Node 12 is sending data using LEACH
# Node 12 is sending data using SPIN
# Node 13 is sending data using Camellia
# Node 13 is sending data using LwM2M
# Node 13 is sending data using LEACH
# Node 13 is sending data using SPIN
# Node 14 is sending data using Camellia
# Node 14 is sending data using LwM2M
# Node 14 is sending data using LEACH
# Node 14 is sending data using SPIN
# Node 15 is sending data using Camellia
# Node 15 is sending data using LwM2M
# Node 15 is sending data using LEACH
# Node 15 is sending data using SPIN
# Node 16 is sending data using Camellia
# Node 16 is sending data using LwM2M
# Node 16 is sending data using LEACH
# Node 16 is sending data using SPIN
# Node 17 is sending data using Camellia
# Node 17 is sending data using LwM2M
# Node 17 is sending data using LEACH
# Node 17 is sending data using SPIN
# Node 18 is sending data using Camellia
# Node 18 is sending data using LwM2M
# Node 18 is sending data using LEACH
# Node 18 is sending data using SPIN
# Node 19 is sending data using Camellia
# Node 19 is sending data using LwM2M
# Node 19 is sending data using LEACH
# Node 19 is sending data using SPIN
# Node 20 is sending data using Camellia
# Node 20 is sending data using LwM2M
# Node 20 is sending data using LEACH
# Node 20 is sending data using SPIN
# Node 21 is sending data using Camellia
# Node 21 is sending data using LwM2M
# Node 21 is sending data using LEACH
# Node 21 is sending data using SPIN
# Node 22 is sending data using Camellia
# Node 22 is sending data using LwM2M
# Node 22 is sending data using LEACH
# Node 22 is sending data using SPIN
# Node 23 is sending data using Camellia
# Node 23 is sending data using LwM2M
# Node 23 is sending data using LEACH
# Node 23 is sending data using SPIN
# Node 24 is sending data using Camellia
# Node 24 is sending data using LwM2M
# Node 24 is sending data using LEACH
# Node 24 is sending data using SPIN
# Node 25 is sending data using Camellia
# Node 25 is sending data using LwM2M
# Node 25 is sending data using LEACH
# Node 25 is sending data using SPIN
# Node 26 is sending data using Camellia
# Node 26 is sending data using LwM2M
# Node 26 is sending data using LEACH
# Node 26 is sending data using SPIN
# Node 27 is sending data using Camellia
# Node 27 is sending data using LwM2M
# Node 27 is sending data using LEACH
# Node 27 is sending data using SPIN
# Node 28 is sending data using Camellia
# Node 28 is sending data using LwM2M
# Node 28 is sending data using LEACH
# Node 28 is sending data using SPIN
# Node 29 is sending data using Camellia
# Node 29 is sending data using LwM2M
# Node 29 is sending data using LEACH
# Node 29 is sending data using SPIN
# Node 30 is sending data using Camellia
# Node 30 is sending data using LwM2M
# Node 30 is sending data using LEACH
# Node 30 is sending data using SPIN
# Node 31 is sending data using Camellia
# Node 31 is sending data using LwM2M
# Node 31 is sending data using LEACH
# Node 31 is sending data using SPIN
# Node 32 is sending data using Camellia
# Node 32 is sending data using LwM2M
# Node 32 is sending data using LEACH
# Node 32 is sending data using SPIN
# Node 33 is sending data using Camellia
# Node 33 is sending data using LwM2M
# Node 33 is sending data using LEACH
# Node 33 is sending data using SPIN
# Node 34 is sending data using Camellia
# Node 34 is sending data using LwM2M
# Node 34 is sending data using LEACH
# Node 34 is sending data using SPIN
# Node 35 is sending data using Camellia
# Node 35 is sending data using LwM2M
# Node 35 is sending data using LEACH
# Node 35 is sending data using SPIN
# Node 36 is sending data using Camellia
# Node 36 is sending data using LwM2M
# Node 36 is sending data using LEACH
# Node 36 is sending data using SPIN
# Node 37 is sending data using Camellia
# Node 37 is sending data using LwM2M
# Node 37 is sending data using LEACH
# Node 37 is sending data using SPIN
# Node 38 is sending data using Camellia
# Node 38 is sending data using LwM2M
# Node 38 is sending data using LEACH
# Node 38 is sending data using SPIN
# Node 39 is sending data using Camellia
# Node 39 is sending data using LwM2M
# Node 39 is sending data using LEACH
# Node 39 is sending data using SPIN
# Node 40 is sending data using Camellia
# Node 40 is sending data using LwM2M
# Node 40 is sending data using LEACH
# Node 40 is sending data using SPIN
# Node 41 is sending data using Camellia
# Node 41 is sending data using LwM2M
# Node 41 is sending data using LEACH
# Node 41 is sending data using SPIN
# Node 42 is sending data using Camellia
# Node 42 is sending data using LwM2M
# Node 42 is sending data using LEACH
# Node 42 is sending data using SPIN
# Node 43 is sending data using Camellia
# Node 43 is sending data using LwM2M
# Node 43 is sending data using LEACH
# Node 43 is sending data using SPIN
# Node 44 is sending data using Camellia
# Node 44 is sending data using LwM2M
# Node 44 is sending data using LEACH
# Node 44 is sending data using SPIN
# Node 45 is sending data using Camellia
# Node 45 is sending data using LwM2M
# Node 45 is sending data using LEACH
# Node 45 is sending data using SPIN
# Node 46 is sending data using Camellia
# Node 46 is sending data using LwM2M
# Node 46 is sending data using LEACH
# Node 46 is sending data using SPIN
# Node 47 is sending data using Camellia
# Node 47 is sending data using LwM2M
# Node 47 is sending data using LEACH
# Node 47 is sending data using SPIN
# Node 48 is sending data using Camellia
# Node 48 is sending data using LwM2M
# Node 48 is sending data using LEACH
# Node 48 is sending data using SPIN
# Node 49 is sending data using Camellia
# Node 49 is sending data using LwM2M
# Node 49 is sending data using LEACH
# Node 49 is sending data using SPIN
# Node 50 is sending data using Camellia
# Node 50 is sending data using LwM2M
# Node 50 is sending data using LEACH
# Node 50 is sending data using SPIN
# Node 51 is sending data using Camellia
# Node 51 is sending data using LwM2M
# Node 51 is sending data using LEACH
# Node 51 is sending data using SPIN
# Node 52 is sending data using Camellia
# Node 52 is sending data using LwM2M
# Node 52 is sending data using LEACH
# Node 52 is sending data using SPIN
# Node 53 is sending data using Camellia
# Node 53 is sending data using LwM2M
# Node 53 is sending data using LEACH
# Node 53 is sending data using SPIN
# Node 54 is sending data using Camellia
# Node 54 is sending data using LwM2M
# Node 54 is sending data using LEACH
# Node 54 is sending data using SPIN
# Node 55 is sending data using Camellia
# Node 55 is sending data using LwM2M
# Node 55 is sending data using LEACH
# Node 55 is sending data using SPIN
# Node 56 is sending data using Camellia
# Node 56 is sending data using LwM2M
# Node 56 is sending data using LEACH
# Node 56 is sending data using SPIN
# Node 57 is sending data using Camellia
# Node 57 is sending data using LwM2M
# Node 57 is sending data using LEACH
# Node 57 is sending data using SPIN
# Node 58 is sending data using Camellia
# Node 58 is sending data using LwM2M
# Node 58 is sending data using LEACH
# Node 58 is sending data using SPIN
# Node 59 is sending data using Camellia
# Node 59 is sending data using LwM2M
# Node 59 is sending data using LEACH
# Node 59 is sending data using SPIN
# Node 60 is sending data using Camellia
# Node 60 is sending data using LwM2M
# Node 60 is sending data using LEACH
# Node 60 is sending data using SPIN
# Node 1 is sending data using Camellia
# Node 1 is sending data using LwM2M
# Node 1 is sending data using LEACH
# Node 1 is sending data using SPIN
# Node 2 is sending data using Camellia
# Node 2 is sending data using LwM2M
# Node 2 is sending data using LEACH
# Node 2 is sending data using SPIN
# Node 3 is sending data using Camellia
# Node 3 is sending data using LwM2M
# Node 3 is sending data using LEACH
# Node 3 is sending data using SPIN
# Node 4 is sending data using Camellia
# Node 4 is sending data using LwM2M
# Node 4 is sending data using LEACH
# Node 4 is sending data using SPIN
# Node 5 is sending data using Camellia
# Node 5 is sending data using LwM2M
# Node 5 is sending data using LEACH
# Node 5 is sending data using SPIN
# Node 6 is sending data using Camellia
# Node 6 is sending data using LwM2M
# Node 6 is sending data using LEACH
# Node 6 is sending data using SPIN
# Node 7 is sending data using Camellia
# Node 7 is sending data using LwM2M
# Node 7 is sending data using LEACH
# Node 7 is sending data using SPIN
# Node 8 is sending data using Camellia
# Node 8 is sending data using LwM2M
# Node 8 is sending data using LEACH
# Node 8 is sending data using SPIN
# Node 9 is sending data using Camellia
# Node 9 is sending data using LwM2M
# Node 9 is sending data using LEACH
# Node 9 is sending data using SPIN
# Node 10 is sending data using Camellia
# Node 10 is sending data using LwM2M
# Node 10 is sending data using LEACH
# Node 10 is sending data using SPIN
# Node 11 is sending data using Camellia
# Node 11 is sending data using LwM2M
# Node 11 is sending data using LEACH
# Node 11 is sending data using SPIN
# Node 12 is sending data using Camellia
# Node 12 is sending data using LwM2M
# Node 12 is sending data using LEACH
# Node 12 is sending data using SPIN
# Node 13 is sending data using Camellia
# Node 13 is sending data using LwM2M
# Node 13 is sending data using LEACH
# Node 13 is sending data using SPIN
# Node 14 is sending data using Camellia
# Node 14 is sending data using LwM2M
# Node 14 is sending data using LEACH
# Node 14 is sending data using SPIN
# Node 15 is sending data using Camellia
# Node 15 is sending data using LwM2M
# Node 15 is sending data using LEACH
# Node 15 is sending data using SPIN
# Node 16 is sending data using Camellia
# Node 16 is sending data using LwM2M
# Node 16 is sending data using LEACH
# Node 16 is sending data using SPIN
# Node 17 is sending data using Camellia
# Node 17 is sending data using LwM2M
# Node 17 is sending data using LEACH
# Node 17 is sending data using SPIN
# Node 18 is sending data using Camellia
# Node 18 is sending data using LwM2M
# Node 18 is sending data using LEACH
# Node 18 is sending data using SPIN
# Node 19 is sending data using Camellia
# Node 19 is sending data using LwM2M
# Node 19 is sending data using LEACH
# Node 19 is sending data using SPIN
# Node 20 is sending data using Camellia
# Node 20 is sending data using LwM2M
# Node 20 is sending data using LEACH
# Node 20 is sending data using SPIN
# Node 21 is sending data using Camellia
# Node 21 is sending data using LwM2M
# Node 21 is sending data using LEACH
# Node 21 is sending data using SPIN
# Node 22 is sending data using Camellia
# Node 22 is sending data using LwM2M
# Node 22 is sending data using LEACH
# Node 22 is sending data using SPIN
# Node 23 is sending data using Camellia
# Node 23 is sending data using LwM2M
# Node 23 is sending data using LEACH
# Node 23 is sending data using SPIN
# Node 24 is sending data using Camellia
# Node 24 is sending data using LwM2M
# Node 24 is sending data using LEACH
# Node 24 is sending data using SPIN
# Node 25 is sending data using Camellia
# Node 25 is sending data using LwM2M
# Node 25 is sending data using LEACH
# Node 25 is sending data using SPIN
# Node 26 is sending data using Camellia
# Node 26 is sending data using LwM2M
# Node 26 is sending data using LEACH
# Node 26 is sending data using SPIN
# Node 27 is sending data using Camellia
# Node 27 is sending data using LwM2M
# Node 27 is sending data using LEACH
# Node 27 is sending data using SPIN
# Node 28 is sending data using Camellia
# Node 28 is sending data using LwM2M
# Node 28 is sending data using LEACH
# Node 28 is sending data using SPIN
# Node 29 is sending data using Camellia
# Node 29 is sending data using LwM2M
# Node 29 is sending data using LEACH
# Node 29 is sending data using SPIN
# Node 30 is sending data using Camellia
# Node 30 is sending data using LwM2M
# Node 30 is sending data using LEACH
# Node 30 is sending data using SPIN
# Node 31 is sending data using Camellia
# Node 31 is sending data using LwM2M
# Node 31 is sending data using LEACH
# Node 31 is sending data using SPIN
# Node 32 is sending data using Camellia
# Node 32 is sending data using LwM2M
# Node 32 is sending data using LEACH
# Node 32 is sending data using SPIN
# Node 33 is sending data using Camellia
# Node 33 is sending data using LwM2M
# Node 33 is sending data using LEACH
# Node 33 is sending data using SPIN
# Node 34 is sending data using Camellia
# Node 34 is sending data using LwM2M
# Node 34 is sending data using LEACH
# Node 34 is sending data using SPIN
# Node 35 is sending data using Camellia
# Node 35 is sending data using LwM2M
# Node 35 is sending data using LEACH
# Node 35 is sending data using SPIN
# Node 36 is sending data using Camellia
# Node 36 is sending data using LwM2M
# Node 36 is sending data using LEACH
# Node 36 is sending data using SPIN
# Node 37 is sending data using Camellia
# Node 37 is sending data using LwM2M
# Node 37 is sending data using LEACH
# Node 37 is sending data using SPIN
# Node 38 is sending data using Camellia
# Node 38 is sending data using LwM2M
# Node 38 is sending data using LEACH
# Node 38 is sending data using SPIN
# Node 39 is sending data using Camellia
# Node 39 is sending data using LwM2M
# Node 39 is sending data using LEACH
# Node 39 is sending data using SPIN
# Node 40 is sending data using Camellia
# Node 40 is sending data using LwM2M
# Node 40 is sending data using LEACH
# Node 40 is sending data using SPIN
# Node 41 is sending data using Camellia
# Node 41 is sending data using LwM2M
# Node 41 is sending data using LEACH
# Node 41 is sending data using SPIN
# Node 42 is sending data using Camellia
# Node 42 is sending data using LwM2M
# Node 42 is sending data using LEACH
# Node 42 is sending data using SPIN
# Node 43 is sending data using Camellia
# Node 43 is sending data using LwM2M
# Node 43 is sending data using LEACH
# Node 43 is sending data using SPIN
# Node 44 is sending data using Camellia
# Node 44 is sending data using LwM2M
# Node 44 is sending data using LEACH
# Node 44 is sending data using SPIN
# Node 45 is sending data using Camellia
# Node 45 is sending data using LwM2M
# Node 45 is sending data using LEACH
# Node 45 is sending data using SPIN
# Node 46 is sending data using Camellia
# Node 46 is sending data using LwM2M
# Node 46 is sending data using LEACH
# Node 46 is sending data using SPIN
# Node 47 is sending data using Camellia
# Node 47 is sending data using LwM2M
# Node 47 is sending data using LEACH
# Node 47 is sending data using SPIN
# Node 48 is sending data using Camellia
# Node 48 is sending data using LwM2M
# Node 48 is sending data using LEACH
# Node 48 is sending data using SPIN
# Node 49 is sending data using Camellia
# Node 49 is sending data using LwM2M
# Node 49 is sending data using LEACH
# Node 49 is sending data using SPIN
# Node 50 is sending data using Camellia
# Node 50 is sending data using LwM2M
# Node 50 is sending data using LEACH
# Node 50 is sending data using SPIN
# Node 51 is sending data using Camellia
# Node 51 is sending data using LwM2M
# Node 51 is sending data using LEACH
# Node 51 is sending data using SPIN
# Node 52 is sending data using Camellia
# Node 52 is sending data using LwM2M
# Node 52 is sending data using LEACH
# Node 52 is sending data using SPIN
# Node 53 is sending data using Camellia
# Node 53 is sending data using LwM2M
# Node 53 is sending data using LEACH
# Node 53 is sending data using SPIN
# Node 54 is sending data using Camellia
# Node 54 is sending data using LwM2M
# Node 54 is sending data using LEACH
# Node 54 is sending data using SPIN
# Node 55 is sending data using Camellia
# Node 55 is sending data using LwM2M
# Node 55 is sending data using LEACH
# Node 55 is sending data using SPIN
# Node 56 is sending data using Camellia
# Node 56 is sending data using LwM2M
# Node 56 is sending data using LEACH
# Node 56 is sending data using SPIN
# Node 57 is sending data using Camellia
# Node 57 is sending data using LwM2M
# Node 57 is sending data using LEACH
# Node 57 is sending data using SPIN
# Node 58 is sending data using Camellia
# Node 58 is sending data using LwM2M
# Node 58 is sending data using LEACH
# Node 58 is sending data using SPIN
# Node 59 is sending data using Camellia
# Node 59 is sending data using LwM2M
# Node 59 is sending data using LEACH
# Node 59 is sending data using SPIN
# Node 60 is sending data using Camellia
# Node 60 is sending data using LwM2M
# Node 60 is sending data using LEACH
# Node 60 is sending data using SPIN
# Node 61 is sending data using Camellia
# Node 61 is sending data using LwM2M
# Node 61 is sending data using LEACH
# Node 61 is sending data using SPIN
# Node 62 is sending data using Camellia
# Node 62 is sending data using LwM2M
# Node 62 is sending data using LEACH
# Node 62 is sending data using SPIN
# Node 63 is sending data using Camellia
# Node 63 is sending data using LwM2M
# Node 63 is sending data using LEACH
# Node 63 is sending data using SPIN
# Node 64 is sending data using Camellia
# Node 64 is sending data using LwM2M
# Node 64 is sending data using LEACH
# Node 64 is sending data using SPIN
# Node 65 is sending data using Camellia
# Node 65 is sending data using LwM2M
# Node 65 is sending data using LEACH
# Node 65 is sending data using SPIN
# Node 66 is sending data using Camellia
# Node 66 is sending data using LwM2M
# Node 66 is sending data using LEACH
# Node 66 is sending data using SPIN
# Node 67 is sending data using Camellia
# Node 67 is sending data using LwM2M
# Node 67 is sending data using LEACH
# Node 67 is sending data using SPIN
# Node 68 is sending data using Camellia
# Node 68 is sending data using LwM2M
# Node 68 is sending data using LEACH
# Node 68 is sending data using SPIN
# Node 69 is sending data using Camellia
# Node 69 is sending data using LwM2M
# Node 69 is sending data using LEACH
# Node 69 is sending data using SPIN
# Node 70 is sending data using Camellia
# Node 70 is sending data using LwM2M
# Node 70 is sending data using LEACH
# Node 70 is sending data using SPIN
# Node 1 is sending data using Camellia
# Node 1 is sending data using LwM2M
# Node 1 is sending data using LEACH
# Node 1 is sending data using SPIN
# Node 2 is sending data using Camellia
# Node 2 is sending data using LwM2M
# Node 2 is sending data using LEACH
# Node 2 is sending data using SPIN
# Node 3 is sending data using Camellia
# Node 3 is sending data using LwM2M
# Node 3 is sending data using LEACH
# Node 3 is sending data using SPIN
# Node 4 is sending data using Camellia
# Node 4 is sending data using LwM2M
# Node 4 is sending data using LEACH
# Node 4 is sending data using SPIN
# Node 5 is sending data using Camellia
# Node 5 is sending data using LwM2M
# Node 5 is sending data using LEACH
# Node 5 is sending data using SPIN
# Node 6 is sending data using Camellia
# Node 6 is sending data using LwM2M
# Node 6 is sending data using LEACH
# Node 6 is sending data using SPIN
# Node 7 is sending data using Camellia
# Node 7 is sending data using LwM2M
# Node 7 is sending data using LEACH
# Node 7 is sending data using SPIN
# Node 8 is sending data using Camellia
# Node 8 is sending data using LwM2M
# Node 8 is sending data using LEACH
# Node 8 is sending data using SPIN
# Node 9 is sending data using Camellia
# Node 9 is sending data using LwM2M
# Node 9 is sending data using LEACH
# Node 9 is sending data using SPIN
# Node 10 is sending data using Camellia
# Node 10 is sending data using LwM2M
# Node 10 is sending data using LEACH
# Node 10 is sending data using SPIN
# Node 11 is sending data using Camellia
# Node 11 is sending data using LwM2M
# Node 11 is sending data using LEACH
# Node 11 is sending data using SPIN
# Node 12 is sending data using Camellia
# Node 12 is sending data using LwM2M
# Node 12 is sending data using LEACH
# Node 12 is sending data using SPIN
# Node 13 is sending data using Camellia
# Node 13 is sending data using LwM2M
# Node 13 is sending data using LEACH
# Node 13 is sending data using SPIN
# Node 14 is sending data using Camellia
# Node 14 is sending data using LwM2M
# Node 14 is sending data using LEACH
# Node 14 is sending data using SPIN
# Node 15 is sending data using Camellia
# Node 15 is sending data using LwM2M
# Node 15 is sending data using LEACH
# Node 15 is sending data using SPIN
# Node 16 is sending data using Camellia
# Node 16 is sending data using LwM2M
# Node 16 is sending data using LEACH
# Node 16 is sending data using SPIN
# Node 17 is sending data using Camellia
# Node 17 is sending data using LwM2M
# Node 17 is sending data using LEACH
# Node 17 is sending data using SPIN
# Node 18 is sending data using Camellia
# Node 18 is sending data using LwM2M
# Node 18 is sending data using LEACH
# Node 18 is sending data using SPIN
# Node 19 is sending data using Camellia
# Node 19 is sending data using LwM2M
# Node 19 is sending data using LEACH
# Node 19 is sending data using SPIN
# Node 20 is sending data using Camellia
# Node 20 is sending data using LwM2M
# Node 20 is sending data using LEACH
# Node 20 is sending data using SPIN
# Node 21 is sending data using Camellia
# Node 21 is sending data using LwM2M
# Node 21 is sending data using LEACH
# Node 21 is sending data using SPIN
# Node 22 is sending data using Camellia
# Node 22 is sending data using LwM2M
# Node 22 is sending data using LEACH
# Node 22 is sending data using SPIN
# Node 23 is sending data using Camellia
# Node 23 is sending data using LwM2M
# Node 23 is sending data using LEACH
# Node 23 is sending data using SPIN
# Node 24 is sending data using Camellia
# Node 24 is sending data using LwM2M
# Node 24 is sending data using LEACH
# Node 24 is sending data using SPIN
# Node 25 is sending data using Camellia
# Node 25 is sending data using LwM2M
# Node 25 is sending data using LEACH
# Node 25 is sending data using SPIN
# Node 26 is sending data using Camellia
# Node 26 is sending data using LwM2M
# Node 26 is sending data using LEACH
# Node 26 is sending data using SPIN
# Node 27 is sending data using Camellia
# Node 27 is sending data using LwM2M
# Node 27 is sending data using LEACH
# Node 27 is sending data using SPIN
# Node 28 is sending data using Camellia
# Node 28 is sending data using LwM2M
# Node 28 is sending data using LEACH
# Node 28 is sending data using SPIN
# Node 29 is sending data using Camellia
# Node 29 is sending data using LwM2M
# Node 29 is sending data using LEACH
# Node 29 is sending data using SPIN
# Node 30 is sending data using Camellia
# Node 30 is sending data using LwM2M
# Node 30 is sending data using LEACH
# Node 30 is sending data using SPIN
# Node 31 is sending data using Camellia
# Node 31 is sending data using LwM2M
# Node 31 is sending data using LEACH
# Node 31 is sending data using SPIN
# Node 32 is sending data using Camellia
# Node 32 is sending data using LwM2M
# Node 32 is sending data using LEACH
# Node 32 is sending data using SPIN
# Node 33 is sending data using Camellia
# Node 33 is sending data using LwM2M
# Node 33 is sending data using LEACH
# Node 33 is sending data using SPIN
# Node 34 is sending data using Camellia
# Node 34 is sending data using LwM2M
# Node 34 is sending data using LEACH
# Node 34 is sending data using SPIN
# Node 35 is sending data using Camellia
# Node 35 is sending data using LwM2M
# Node 35 is sending data using LEACH
# Node 35 is sending data using SPIN
# Node 36 is sending data using Camellia
# Node 36 is sending data using LwM2M
# Node 36 is sending data using LEACH
# Node 36 is sending data using SPIN
# Node 37 is sending data using Camellia
# Node 37 is sending data using LwM2M
# Node 37 is sending data using LEACH
# Node 37 is sending data using SPIN
# Node 38 is sending data using Camellia
# Node 38 is sending data using LwM2M
# Node 38 is sending data using LEACH
# Node 38 is sending data using SPIN
# Node 39 is sending data using Camellia
# Node 39 is sending data using LwM2M
# Node 39 is sending data using LEACH
# Node 39 is sending data using SPIN
# Node 40 is sending data using Camellia
# Node 40 is sending data using LwM2M
# Node 40 is sending data using LEACH
# Node 40 is sending data using SPIN
# Node 41 is sending data using Camellia
# Node 41 is sending data using LwM2M
# Node 41 is sending data using LEACH
# Node 41 is sending data using SPIN
# Node 42 is sending data using Camellia
# Node 42 is sending data using LwM2M
# Node 42 is sending data using LEACH
# Node 42 is sending data using SPIN
# Node 43 is sending data using Camellia
# Node 43 is sending data using LwM2M
# Node 43 is sending data using LEACH
# Node 43 is sending data using SPIN
# Node 44 is sending data using Camellia
# Node 44 is sending data using LwM2M
# Node 44 is sending data using LEACH
# Node 44 is sending data using SPIN
# Node 45 is sending data using Camellia
# Node 45 is sending data using LwM2M
# Node 45 is sending data using LEACH
# Node 45 is sending data using SPIN
# Node 46 is sending data using Camellia
# Node 46 is sending data using LwM2M
# Node 46 is sending data using LEACH
# Node 46 is sending data using SPIN
# Node 47 is sending data using Camellia
# Node 47 is sending data using LwM2M
# Node 47 is sending data using LEACH
# Node 47 is sending data using SPIN
# Node 48 is sending data using Camellia
# Node 48 is sending data using LwM2M
# Node 48 is sending data using LEACH
# Node 48 is sending data using SPIN
# Node 49 is sending data using Camellia
# Node 49 is sending data using LwM2M
# Node 49 is sending data using LEACH
# Node 49 is sending data using SPIN
# Node 50 is sending data using Camellia
# Node 50 is sending data using LwM2M
# Node 50 is sending data using LEACH
# Node 50 is sending data using SPIN
# Node 51 is sending data using Camellia
# Node 51 is sending data using LwM2M
# ...
# Node 81 is sending data using LwM2M
# Node 81 is sending data using LEACH
# Node 81 is sending data using SPIN
# Node 82 is sending data using Camellia
# Node 82 is sending data using LwM2M
# Node 82 is sending data using LEACH
# Node 82 is sending data using SPIN
# Node 83 is sending data using Camellia
# Node 83 is sending data using LwM2M
# Node 83 is sending data using LEACH
# Node 83 is sending data using SPIN
# Node 84 is sending data using Camellia
# Node 84 is sending data using LwM2M
# Node 84 is sending data using LEACH
# Node 84 is sending data using SPIN
# Node 85 is sending data using Camellia
# Node 85 is sending data using LwM2M
# Node 85 is sending data using LEACH
# Node 85 is sending data using SPIN
# Node 86 is sending data using Camellia
# Node 86 is sending data using LwM2M
# Node 86 is sending data using LEACH
# Node 86 is sending data using SPIN
# Node 87 is sending data using Camellia
# Node 87 is sending data using LwM2M
# Node 87 is sending data using LEACH
# Node 87 is sending data using SPIN
# Node 88 is sending data using Camellia
# Node 88 is sending data using LwM2M
# Node 88 is sending data using LEACH
# Node 88 is sending data using SPIN
# Node 89 is sending data using Camellia
# Node 89 is sending data using LwM2M
# Node 89 is sending data using LEACH
# Node 89 is sending data using SPIN
# Node 90 is sending data using Camellia
# Node 90 is sending data using LwM2M
# Node 90 is sending data using LEACH
# Node 90 is sending data using SPIN
# Node 1 is sending data using Camellia
# Node 1 is sending data using LwM2M
# Node 1 is sending data using LEACH
# Node 1 is sending data using SPIN
# Node 2 is sending data using Camellia
# Node 2 is sending data using LwM2M
# Node 2 is sending data using LEACH
# Node 2 is sending data using SPIN
# Node 3 is sending data using Camellia
# Node 3 is sending data using LwM2M
# Node 3 is sending data using LEACH
# Node 3 is sending data using SPIN
# Node 4 is sending data using Camellia
# Node 4 is sending data using LwM2M
# Node 4 is sending data using LEACH
# Node 4 is sending data using SPIN
# Node 5 is sending data using Camellia
# Node 5 is sending data using LwM2M
# Node 5 is sending data using LEACH
# Node 5 is sending data using SPIN
# Node 6 is sending data using Camellia
# Node 6 is sending data using LwM2M
# Node 6 is sending data using LEACH
# Node 6 is sending data using SPIN
# Node 7 is sending data using Camellia
# Node 7 is sending data using LwM2M
# Node 7 is sending data using LEACH
# Node 7 is sending data using SPIN
# Node 8 is sending data using Camellia
# Node 8 is sending data using LwM2M
# Node 8 is sending data using LEACH
# Node 8 is sending data using SPIN
# Node 9 is sending data using Camellia
# Node 9 is sending data using LwM2M
# Node 9 is sending data using LEACH
# Node 9 is sending data using SPIN
# Node 10 is sending data using Camellia
# Node 10 is sending data using LwM2M
# Node 10 is sending data using LEACH
# Node 10 is sending data using SPIN
# Node 11 is sending data using Camellia
# Node 11 is sending data using LwM2M
# Node 11 is sending data using LEACH
# Node 11 is sending data using SPIN
# Node 12 is sending data using Camellia
# Node 12 is sending data using LwM2M
# Node 12 is sending data using LEACH
# Node 12 is sending data using SPIN
# Node 13 is sending data using Camellia
# Node 13 is sending data using LwM2M
# Node 13 is sending data using LEACH
# Node 13 is sending data using SPIN
# Node 14 is sending data using Camellia
# Node 14 is sending data using LwM2M
# Node 14 is sending data using LEACH
# Node 14 is sending data using SPIN
# Node 15 is sending data using Camellia
# Node 15 is sending data using LwM2M
# Node 15 is sending data using LEACH
# Node 15 is sending data using SPIN
# Node 16 is sending data using Camellia
# Node 16 is sending data using LwM2M
# Node 16 is sending data using LEACH
# Node 16 is sending data using SPIN
# Node 17 is sending data using Camellia
# Node 17 is sending data using LwM2M
# Node 17 is sending data using LEACH
# Node 17 is sending data using SPIN
# Node 18 is sending data using Camellia
# Node 18 is sending data using LwM2M
# Node 18 is sending data using LEACH
# Node 18 is sending data using SPIN
# Node 19 is sending data using Camellia
# Node 19 is sending data using LwM2M
# Node 19 is sending data using LEACH
# Node 19 is sending data using SPIN
# Node 20 is sending data using Camellia
# Node 20 is sending data using LwM2M
# Node 20 is sending data using LEACH
# Node 20 is sending data using SPIN
# Node 21 is sending data using Camellia
# Node 21 is sending data using LwM2M
# Node 21 is sending data using LEACH
# Node 21 is sending data using SPIN
# Node 22 is sending data using Camellia
# Node 22 is sending data using LwM2M
# Node 22 is sending data using LEACH
# Node 22 is sending data using SPIN
# Node 23 is sending data using Camellia
# Node 23 is sending data using LwM2M
# Node 23 is sending data using LEACH
# Node 23 is sending data using SPIN
# Node 24 is sending data using Camellia
# Node 24 is sending data using LwM2M
# Node 24 is sending data using LEACH
# Node 24 is sending data using SPIN
# Node 25 is sending data using Camellia
# Node 25 is sending data using LwM2M
# Node 25 is sending data using LEACH
# Node 25 is sending data using SPIN
# Node 26 is sending data using Camellia
# Node 26 is sending data using LwM2M
# Node 26 is sending data using LEACH
# Node 26 is sending data using SPIN
# Node 27 is sending data using Camellia
# Node 27 is sending data using LwM2M
# Node 27 is sending data using LEACH
# Node 27 is sending data using SPIN
# Node 28 is sending data using Camellia
# Node 28 is sending data using LwM2M
# Node 28 is sending data using LEACH
# Node 28 is sending data using SPIN
# Node 29 is sending data using Camellia
# Node 29 is sending data using LwM2M
# Node 29 is sending data using LEACH
# Node 29 is sending data using SPIN
# Node 30 is sending data using Camellia
# Node 30 is sending data using LwM2M
# Node 30 is sending data using LEACH
# Node 30 is sending data using SPIN
# Node 31 is sending data using Camellia
# Node 31 is sending data using LwM2M
# Node 31 is sending data using LEACH
# Node 31 is sending data using SPIN
# Node 32 is sending data using Camellia
# Node 32 is sending data using LwM2M
# Node 32 is sending data using LEACH
# Node 32 is sending data using SPIN
# Node 33 is sending data using Camellia
# Node 33 is sending data using LwM2M
# Node 33 is sending data using LEACH
# Node 33 is sending data using SPIN
# Node 34 is sending data using Camellia
# Node 34 is sending data using LwM2M
# Node 34 is sending data using LEACH
# Node 34 is sending data using SPIN
# Node 35 is sending data using Camellia
# Node 35 is sending data using LwM2M
# Node 35 is sending data using LEACH
# Node 35 is sending data using SPIN
# Node 36 is sending data using Camellia
# Node 36 is sending data using LwM2M
# Node 36 is sending data using LEACH
# Node 36 is sending data using SPIN
# Node 37 is sending data using Camellia
# Node 37 is sending data using LwM2M
# Node 37 is sending data using LEACH
# Node 37 is sending data using SPIN
# Node 38 is sending data using Camellia
# Node 38 is sending data using LwM2M
# Node 38 is sending data using LEACH
# Node 38 is sending data using SPIN
# Node 39 is sending data using Camellia
# Node 39 is sending data using LwM2M
# Node 39 is sending data using LEACH
# Node 39 is sending data using SPIN
# Node 40 is sending data using Camellia
# Node 40 is sending data using LwM2M
# Node 40 is sending data using LEACH
# Node 40 is sending data using SPIN
# Node 41 is sending data using Camellia
# Node 41 is sending data using LwM2M
# Node 41 is sending data using LEACH
# Node 41 is sending data using SPIN
# Node 42 is sending data using Camellia
# Node 42 is sending data using LwM2M
# Node 42 is sending data using LEACH
# Node 42 is sending data using SPIN
# Node 43 is sending data using Camellia
# Node 43 is sending data using LwM2M
# Node 43 is sending data using LEACH
# Node 43 is sending data using SPIN
# Node 44 is sending data using Camellia
# Node 44 is sending data using LwM2M
# Node 44 is sending data using LEACH
# Node 44 is sending data using SPIN
# Node 45 is sending data using Camellia
# Node 45 is sending data using LwM2M
# Node 45 is sending data using LEACH
# Node 45 is sending data using SPIN
# Node 46 is sending data using Camellia
# Node 46 is sending data using LwM2M
# Node 46 is sending data using LEACH
# Node 46 is sending data using SPIN
# Node 47 is sending data using Camellia
# Node 47 is sending data using LwM2M
# Node 47 is sending data using LEACH
# Node 47 is sending data using SPIN
# Node 48 is sending data using Camellia
# Node 48 is sending data using LwM2M
# Node 48 is sending data using LEACH
# Node 48 is sending data using SPIN
# Node 49 is sending data using Camellia
# Node 49 is sending data using LwM2M
# Node 49 is sending data using LEACH
# Node 49 is sending data using SPIN
# Node 50 is sending data using Camellia
# Node 50 is sending data using LwM2M
# Node 50 is sending data using LEACH
# Node 50 is sending data using SPIN
# Node 51 is sending data using Camellia
# Node 51 is sending data using LwM2M
# Node 51 is sending data using LEACH
# Node 51 is sending data using SPIN
# Node 52 is sending data using Camellia
# Node 52 is sending data using LwM2M
# Node 52 is sending data using LEACH
# Node 52 is sending data using SPIN
# Node 53 is sending data using Camellia
# Node 53 is sending data using LwM2M
# Node 53 is sending data using LEACH
# Node 53 is sending data using SPIN
# Node 54 is sending data using Camellia
# Node 54 is sending data using LwM2M
# Node 54 is sending data using LEACH
# Node 54 is sending data using SPIN
# Node 55 is sending data using Camellia
# Node 55 is sending data using LwM2M
# Node 55 is sending data using LEACH
# Node 55 is sending data using SPIN
# Node 56 is sending data using Camellia
# Node 56 is sending data using LwM2M
# Node 56 is sending data using LEACH
# Node 56 is sending data using SPIN
# Node 57 is sending data using Camellia
# Node 57 is sending data using LwM2M
# Node 57 is sending data using LEACH
# Node 57 is sending data using SPIN
# Node 58 is sending data using Camellia
# Node 58 is sending data using LwM2M
# Node 58 is sending data using LEACH
# Node 58 is sending data using SPIN
# Node 59 is sending data using Camellia
# Node 59 is sending data using LwM2M
# Node 59 is sending data using LEACH
# Node 59 is sending data using SPIN
# Node 60 is sending data using Camellia
# Node 60 is sending data using LwM2M
# Node 60 is sending data using LEACH
# Node 60 is sending data using SPIN
# Node 61 is sending data using Camellia
# Node 61 is sending data using LwM2M
# Node 61 is sending data using LEACH
# Node 61 is sending data using SPIN
# Node 62 is sending data using Camellia
# Node 62 is sending data using LwM2M
# Node 62 is sending data using LEACH
# Node 62 is sending data using SPIN
# Node 63 is sending data using Camellia
# Node 63 is sending data using LwM2M
# Node 63 is sending data using LEACH
# Node 63 is sending data using SPIN
# Node 64 is sending data using Camellia
# Node 64 is sending data using LwM2M
# Node 64 is sending data using LEACH
# Node 64 is sending data using SPIN
# Node 65 is sending data using Camellia
# Node 65 is sending data using LwM2M
# Node 65 is sending data using LEACH
# Node 65 is sending data using SPIN
# Node 66 is sending data using Camellia
# Node 66 is sending data using LwM2M
# Node 66 is sending data using LEACH
# Node 66 is sending data using SPIN
# Node 67 is sending data using Camellia
# Node 67 is sending data using LwM2M
# Node 67 is sending data using LEACH
# Node 67 is sending data using SPIN
# Node 68 is sending data using Camellia
# Node 68 is sending data using LwM2M
# Node 68 is sending data using LEACH
# Node 68 is sending data using SPIN
# Node 69 is sending data using Camellia
# Node 69 is sending data using LwM2M
# Node 69 is sending data using LEACH
# Node 69 is sending data using SPIN
# Node 70 is sending data using Camellia
# Node 70 is sending data using LwM2M
# Node 70 is sending data using LEACH
# Node 70 is sending data using SPIN
# Node 71 is sending data using Camellia
# Node 71 is sending data using LwM2M
# Node 71 is sending data using LEACH
# Node 71 is sending data using SPIN
# Node 72 is sending data using Camellia
# Node 72 is sending data using LwM2M
# Node 72 is sending data using LEACH
# Node 72 is sending data using SPIN
# Node 73 is sending data using Camellia
# Node 73 is sending data using LwM2M
# Node 73 is sending data using LEACH
# Node 73 is sending data using SPIN
# Node 74 is sending data using Camellia
# Node 74 is sending data using LwM2M
# Node 74 is sending data using LEACH
# Node 74 is sending data using SPIN
# Node 75 is sending data using Camellia
# Node 75 is sending data using LwM2M
# Node 75 is sending data using LEACH
# Node 75 is sending data using SPIN
# Node 76 is sending data using Camellia
# Node 76 is sending data using LwM2M
# Node 76 is sending data using LEACH
# Node 76 is sending data using SPIN
# Node 77 is sending data using Camellia
# Node 77 is sending data using LwM2M
# Node 77 is sending data using LEACH
# Node 77 is sending data using SPIN
# Node 78 is sending data using Camellia
# Node 78 is sending data using LwM2M
# Node 78 is sending data using LEACH
# Node 78 is sending data using SPIN
# Node 79 is sending data using Camellia
# Node 79 is sending data using LwM2M
# Node 79 is sending data using LEACH
# Node 79 is sending data using SPIN
# Node 80 is sending data using Camellia
# Node 80 is sending data using LwM2M
# Node 80 is sending data using LEACH
# Node 80 is sending data using SPIN
# Node 81 is sending data using Camellia
# Node 81 is sending data using LwM2M
# Node 81 is sending data using LEACH
# Node 81 is sending data using SPIN
# Node 82 is sending data using Camellia
# Node 82 is sending data using LwM2M
# Node 82 is sending data using LEACH
# Node 82 is sending data using SPIN
# Node 83 is sending data using Camellia
# Node 83 is sending data using LwM2M
# Node 83 is sending data using LEACH
# Node 83 is sending data using SPIN
# Node 84 is sending data using Camellia
# Node 84 is sending data using LwM2M
# Node 84 is sending data using LEACH
# Node 84 is sending data using SPIN
# Node 85 is sending data using Camellia
# Node 85 is sending data using LwM2M
# Node 85 is sending data using LEACH
# Node 85 is sending data using SPIN
# Node 86 is sending data using Camellia
# Node 86 is sending data using LwM2M
# Node 86 is sending data using LEACH
# Node 86 is sending data using SPIN
# Node 87 is sending data using Camellia
# Node 87 is sending data using LwM2M
# Node 87 is sending data using LEACH
# Node 87 is sending data using SPIN
# Node 88 is sending data using Camellia
# Node 88 is sending data using LwM2M
# Node 88 is sending data using LEACH
# Node 88 is sending data using SPIN
# Node 89 is sending data using Camellia
# Node 89 is sending data using LwM2M
# Node 89 is sending data using LEACH
# Node 89 is sending data using SPIN
# Node 90 is sending data using Camellia
# Node 90 is sending data using LwM2M
# Node 90 is sending data using LEACH
# Node 90 is sending data using SPIN
# Node 91 is sending data using Camellia
# Node 91 is sending data using LwM2M
# Node 91 is sending data using LEACH
# Node 91 is sending data using SPIN
# Node 92 is sending data using Camellia
# Node 92 is sending data using LwM2M
# Node 92 is sending data using LEACH
# Node 92 is sending data using SPIN
# Node 93 is sending data using Camellia
# Node 93 is sending data using LwM2M
# Node 93 is sending data using LEACH
# Node 93 is sending data using SPIN
# Node 94 is sending data using Camellia
# Node 94 is sending data using LwM2M
# Node 94 is sending data using LEACH
# Node 94 is sending data using SPIN
# Node 95 is sending data using Camellia
# Node 95 is sending data using LwM2M
# Node 95 is sending data using LEACH
# Node 95 is sending data using SPIN
# Node 96 is sending data using Camellia
# Node 96 is sending data using LwM2M
# Node 96 is sending data using LEACH
# Node 96 is sending data using SPIN
# Node 97 is sending data using Camellia
# Node 97 is sending data using LwM2M
# Node 97 is sending data using LEACH
# Node 97 is sending data using SPIN
# Node 98 is sending data using Camellia
# Node 98 is sending data using LwM2M
# Node 98 is sending data using LEACH
# Node 98 is sending data using SPIN
# Node 99 is sending data using Camellia
# Node 99 is sending data using LwM2M
# Node 99 is sending data using LEACH
# Node 99 is sending data using SPIN
# Node 100 is sending data using Camellia
# Node 100 is sending data using LwM2M
# Node 100 is sending data using LEACH
# Node 100 is sending data using SPIN
